# %% [markdown]
# Layers A and B have the thicknesses  $d_A = 200 nm$  and  $d_B = 300 nm$ , and the dielectric constants $ϵ_A = 12$ and $ϵ_B = 3$. Compute and plot T vs ω for structure of 10 repeated AB followed by 10 repeated BA.(300 < ω < 600 THz)

# %% [markdown]
# ### 參數設定

# %%
import numpy as np
#頻率相關參數
f = 1.4
omega = 2 * np.pi * f

# %%
#結構重複次數
num_pairs = 10
#晶體厚度
d_single = [0.2, 0.3]
d_list = []
for i in range(num_pairs):
    for j in range(len(d_single)-1):
        d_list.append(d_single[1])
        d_list.append(d_single[0])
for i in range(num_pairs):
    for j in range(len(d_single)-1):
        d_list.append(d_single[0])
        d_list.append(d_single[1])
d = sum(d_list)
d_pair = sum(d_single)
#材料介電常數
epsi_single = [12, 3]
epsi_list = []
for i in range(num_pairs):
    for j in range(len(epsi_single)-1):
        epsi_list.append(epsi_single[1])
        epsi_list.append(epsi_single[0])
for i in range(num_pairs):
    for j in range(len(epsi_single)-1):
        epsi_list.append(epsi_single[0])
        epsi_list.append(epsi_single[1])

# %%
#材料相位差
delta_list = []
for epsi, a in zip(epsi_list, d_list):
    delta = 2 * omega * a * np.sqrt(epsi)
    delta_list.append(delta)
delta_array = np.array(delta_list)

# %%
epsi_all = epsi_list.copy()  
epsi_all.insert(0, 1)
epsi_all.append(1)

# %% [markdown]
# ### 轉移矩陣數值分析

# %%
#介面反射係數
r_list = []
for i in range(len(epsi_all)-1):
    r = (np.sqrt(epsi_all[i]) - np.sqrt(epsi_all[i+1])) / \
        (np.sqrt(epsi_all[i]) + np.sqrt(epsi_all[i+1]))
    r_list.append(r)
r_array = np.array(r_list)
#介面透射係數
t_list = []
for i in range(len(epsi_all)-1):
    t = 2 * (np.sqrt(epsi_all[i])) / \
        (np.sqrt(epsi_all[i]) + np.sqrt(epsi_all[i+1]))
    t_list.append(t)
t_array = np.array(t_list)

# %%
#介面反透射矩陣
i = 1j
D_list = []
for idx, t in enumerate(t_array):
    r_num = r_array[idx]
    D = (1 / t) * np.array([[1, r_num],
                            [r_num, 1]])
    D_list.append(D)
D_array = np.array(D_list)

# %%
#材料傳遞矩陣
P_list = []
for deltas in delta_array:
    P_11 = np.exp(-i * deltas * 0.5)
    P_22 = np.exp(i * deltas * 0.5)
    P = np.array([[P_11, 0],
                  [0, P_22]])
    P_list.append(P)
P_array = np.array(P_list)

# %%
#轉換矩陣
M_temp = np.eye(2, 2)
for k in range(len(epsi_list)):
    M_temp = M_temp @ np.array(D_array[k])
    M_temp = M_temp @ np.array(P_array[k])
M = M_temp @ np.array(D_array[-1])

# %%
#反射與透射
Er = M[1,0] / M[0,0]
R_tmat = np.abs(Er**2)
T_tmat = 1 - R_tmat
print(T_tmat)
# Out:
# 0.6895007024571698

# %% [markdown]
# ### 散射矩陣數值分析

# %%
detM = M[0,0]*M[1,1] - M[0,1]*M[1,0]
S11 = -M[1,0] / M[1,1]
S21 = detM / M[1,1]
R_smat = np.abs(S11)**2
T_smat = np.abs(S21)**2
print(T_smat)
# Out:
# 0.6895007024571697

# %%
import meep as mp
#模擬空間參數
resolution = 500
dpml = 1.0
sz = (d_pair * 30.0) + (dpml * 2.0)
cell_size = mp.Vector3(z=sz)
pml_layers = [mp.PML(dpml)]
dimensions = 1

# %%
#電磁波源(平面波)
sour_z = - (d / 2) - 0.3 
sources = [mp.Source(src=mp.ContinuousSource(frequency=f),
                     component=mp.Ex,
                     center=mp.Vector3(z=sour_z))
          ]

# %%
#整體模擬流程(真空場)
sim_vac = mp.Simulation(cell_size=cell_size,
                        boundary_layers=pml_layers,
                        sources=sources,
                        dimensions=dimensions,
                        resolution=resolution)
#數據偵測(真空場)
tran_z = (d / 2) + 0.3
tran_vac_fr = mp.FluxRegion(center=mp.Vector3(z = tran_z))
tran_vac = sim_vac.add_flux(f, 0, 1, tran_vac_fr)
#數據模擬(真空場)  
sim_vac.run(until=20000)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000414848 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 17 with resolution 500
# time for set_epsilon = 0.00183511 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=20000.0)
# Meep progress: 191.008/20000.0 = 1.0% done in 4.0s, 414.8s to go
# on time step 191358 (time=191.358), 2.09033e-05 s/step
# Meep progress: 433.757/20000.0 = 2.2% done in 8.0s, 360.9s to go
# on time step 434187 (time=434.187), 1.64725e-05 s/step
# Meep progress: 677.1750000000001/20000.0 = 3.4% done in 12.0s, 342.4s to go
# on time step 677633 (time=677.633), 1.64308e-05 s/step
# Meep progress: 919.95/20000.0 = 4.6% done in 16.0s, 331.8s to go
# on time step 920559 (time=920.559), 1.64659e-05 s/step
# Meep progress: 1160.986/20000.0 = 5.8% done in 20.0s, 324.5s to go
# on time step 1161712 (time=1161.71), 1.6587e-05 s/step
# Meep progress: 1404.724/20000.0 = 7.0% done in 24.0s, 317.7s to go
# on time step 1405534 (time=1405.53), 1.64054e-05 s/step
# Meep progress: 1648.067/20000.0 = 8.2% done in 28.0s, 311.8s to go
# on time step 1648949 (time=1648.95), 1.64329e-05 s/step
# Meep progress: 1890.723/20000.0 = 9.5% done in 32.0s, 306.5s to go
# on time step 1891758 (time=1891.76), 1.64739e-05 s/step
# Meep progress: 2132.823/20000.0 = 10.7% done in 36.0s, 301.6s to go
# on time step 2133951 (time=2133.95), 1.65158e-05 s/step
# Meep progress: 2373.637/20000.0 = 11.9% done in 40.0s, 297.0s to go
# on time step 2374859 (time=2374.86), 1.66039e-05 s/step
# Meep progress: 2617.288/20000.0 = 13.1% done in 44.0s, 292.2s to go
# on time step 2618600 (time=2618.6), 1.64109e-05 s/step
# Meep progress: 2860.619/20000.0 = 14.3% done in 48.0s, 287.6s to go
# on time step 2861977 (time=2861.98), 1.64355e-05 s/step
# Meep progress: 3104.289/20000.0 = 15.5% done in 52.0s, 283.0s to go
# on time step 3105781 (time=3105.78), 1.64067e-05 s/step
# Meep progress: 3347.587/20000.0 = 16.7% done in 56.0s, 278.6s to go
# on time step 3349191 (time=3349.19), 1.64332e-05 s/step
# Meep progress: 3591.1240000000003/20000.0 = 18.0% done in 60.0s, 274.2s to go
# on time step 3592823 (time=3592.82), 1.64182e-05 s/step
# Meep progress: 3834.297/20000.0 = 19.2% done in 64.0s, 269.8s to go
# on time step 3836085 (time=3836.09), 1.64432e-05 s/step
# Meep progress: 4077.742/20000.0 = 20.4% done in 68.0s, 265.5s to go
# on time step 4079616 (time=4079.62), 1.64251e-05 s/step
# Meep progress: 4321.086/20000.0 = 21.6% done in 72.0s, 261.2s to go
# on time step 4323066 (time=4323.07), 1.64305e-05 s/step
# Meep progress: 4564.5960000000005/20000.0 = 22.8% done in 76.0s, 257.0s to go
# on time step 4566570 (time=4566.57), 1.64269e-05 s/step
# Meep progress: 4807.877/20000.0 = 24.0% done in 80.0s, 252.8s to go
# on time step 4809991 (time=4809.99), 1.64325e-05 s/step
# Meep progress: 5051.542/20000.0 = 25.3% done in 84.0s, 248.6s to go
# on time step 5053771 (time=5053.77), 1.64083e-05 s/step
# Meep progress: 5294.9890000000005/20000.0 = 26.5% done in 88.0s, 244.4s to go
# on time step 5297310 (time=5297.31), 1.64245e-05 s/step
# Meep progress: 5538.526/20000.0 = 27.7% done in 92.0s, 240.2s to go
# on time step 5540935 (time=5540.94), 1.64187e-05 s/step
# Meep progress: 5781.92/20000.0 = 28.9% done in 96.0s, 236.1s to go
# on time step 5784396 (time=5784.4), 1.64302e-05 s/step
# Meep progress: 6025.801/20000.0 = 30.1% done in 100.0s, 231.9s to go
# on time step 6028341 (time=6028.34), 1.63972e-05 s/step
# Meep progress: 6269.304/20000.0 = 31.3% done in 104.0s, 227.8s to go
# on time step 6271973 (time=6271.97), 1.64183e-05 s/step
# Meep progress: 6511.527/20000.0 = 32.6% done in 108.0s, 223.7s to go
# on time step 6514233 (time=6514.23), 1.65112e-05 s/step
# Meep progress: 6754.947/20000.0 = 33.8% done in 112.0s, 219.6s to go
# on time step 6757781 (time=6757.78), 1.64239e-05 s/step
# Meep progress: 6998.512/20000.0 = 35.0% done in 116.0s, 215.5s to go
# on time step 7001468 (time=7001.47), 1.64145e-05 s/step
# Meep progress: 7242.082/20000.0 = 36.2% done in 120.0s, 211.4s to go
# on time step 7245122 (time=7245.12), 1.64168e-05 s/step
# Meep progress: 7485.615/20000.0 = 37.4% done in 124.0s, 207.3s to go
# on time step 7488738 (time=7488.74), 1.64193e-05 s/step
# Meep progress: 7728.8240000000005/20000.0 = 38.6% done in 128.0s, 203.2s to go
# on time step 7732030 (time=7732.03), 1.64412e-05 s/step
# Meep progress: 7972.4310000000005/20000.0 = 39.9% done in 132.0s, 199.1s to go
# on time step 7975720 (time=7975.72), 1.64144e-05 s/step
# Meep progress: 8215.712/20000.0 = 41.1% done in 136.0s, 195.1s to go
# on time step 8219091 (time=8219.09), 1.64358e-05 s/step
# Meep progress: 8459.3/20000.0 = 42.3% done in 140.0s, 191.0s to go
# on time step 8462753 (time=8462.75), 1.64162e-05 s/step
# Meep progress: 8702.775/20000.0 = 43.5% done in 144.0s, 186.9s to go
# on time step 8706311 (time=8706.31), 1.64232e-05 s/step
# Meep progress: 8946.354/20000.0 = 44.7% done in 148.0s, 182.9s to go
# on time step 8949973 (time=8949.97), 1.64162e-05 s/step
# Meep progress: 9189.921/20000.0 = 45.9% done in 152.0s, 178.8s to go
# on time step 9193580 (time=9193.58), 1.64199e-05 s/step
# Meep progress: 9433.433/20000.0 = 47.2% done in 156.0s, 174.7s to go
# on time step 9437246 (time=9437.25), 1.64159e-05 s/step
# Meep progress: 9677.06/20000.0 = 48.4% done in 160.0s, 170.7s to go
# on time step 9680934 (time=9680.93), 1.64144e-05 s/step
# Meep progress: 9920.807/20000.0 = 49.6% done in 164.0s, 166.6s to go
# on time step 9924785 (time=9924.78), 1.64035e-05 s/step
# Meep progress: 10164.507/20000.0 = 50.8% done in 168.0s, 162.6s to go
# on time step 10168565 (time=10168.6), 1.64083e-05 s/step
# Meep progress: 10408.101/20000.0 = 52.0% done in 172.0s, 158.5s to go
# on time step 10412242 (time=10412.2), 1.64152e-05 s/step
# Meep progress: 10648.748/20000.0 = 53.2% done in 176.0s, 154.6s to go
# on time step 10652971 (time=10653), 1.66162e-05 s/step
# Meep progress: 10891.855/20000.0 = 54.5% done in 180.0s, 150.5s to go
# on time step 10896164 (time=10896.2), 1.64478e-05 s/step
# Meep progress: 11136.031/20000.0 = 55.7% done in 184.0s, 146.5s to go
# on time step 11140423 (time=11140.4), 1.63761e-05 s/step
# Meep progress: 11380.03/20000.0 = 56.9% done in 188.0s, 142.4s to go
# on time step 11384501 (time=11384.5), 1.63883e-05 s/step
# Meep progress: 11624.073/20000.0 = 58.1% done in 192.0s, 138.3s to go
# on time step 11628620 (time=11628.6), 1.63855e-05 s/step
# Meep progress: 11867.89/20000.0 = 59.3% done in 196.0s, 134.3s to go
# on time step 11872520 (time=11872.5), 1.64002e-05 s/step
# Meep progress: 12111.837/20000.0 = 60.6% done in 200.0s, 130.3s to go
# on time step 12116504 (time=12116.5), 1.63946e-05 s/step
# Meep progress: 12349.194/20000.0 = 61.7% done in 204.0s, 126.4s to go
# on time step 12353926 (time=12353.9), 1.68477e-05 s/step
# Meep progress: 12592.835000000001/20000.0 = 63.0% done in 208.0s, 122.3s to go
# on time step 12597568 (time=12597.6), 1.64176e-05 s/step
# Meep progress: 12836.565/20000.0 = 64.2% done in 212.0s, 118.3s to go
# on time step 12841430 (time=12841.4), 1.64027e-05 s/step
# Meep progress: 13080.601/20000.0 = 65.4% done in 216.0s, 114.3s to go
# on time step 13085514 (time=13085.5), 1.63878e-05 s/step
# Meep progress: 13324.029/20000.0 = 66.6% done in 220.0s, 110.2s to go
# on time step 13329047 (time=13329), 1.64249e-05 s/step
# Meep progress: 13568.098/20000.0 = 67.8% done in 224.0s, 106.2s to go
# on time step 13573184 (time=13573.2), 1.63843e-05 s/step
# Meep progress: 13811.971/20000.0 = 69.1% done in 228.0s, 102.1s to go
# on time step 13817131 (time=13817.1), 1.6397e-05 s/step
# Meep progress: 14051.878/20000.0 = 70.3% done in 232.0s, 98.2s to go
# on time step 14057095 (time=14057.1), 1.66692e-05 s/step
# Meep progress: 14295.612000000001/20000.0 = 71.5% done in 236.0s, 94.2s to go
# on time step 14300898 (time=14300.9), 1.64067e-05 s/step
# Meep progress: 14539.441/20000.0 = 72.7% done in 240.0s, 90.1s to go
# on time step 14544814 (time=14544.8), 1.63991e-05 s/step
# Meep progress: 14783.399/20000.0 = 73.9% done in 244.0s, 86.1s to go
# on time step 14788842 (time=14788.8), 1.63916e-05 s/step
# Meep progress: 15027.283/20000.0 = 75.1% done in 248.0s, 82.1s to go
# on time step 15032801 (time=15032.8), 1.63962e-05 s/step
# Meep progress: 15271.251/20000.0 = 76.4% done in 252.0s, 78.0s to go
# on time step 15276823 (time=15276.8), 1.6392e-05 s/step
# Meep progress: 15515.103000000001/20000.0 = 77.6% done in 256.0s, 74.0s to go
# on time step 15520759 (time=15520.8), 1.63978e-05 s/step
# Meep progress: 15759.088/20000.0 = 78.8% done in 260.0s, 70.0s to go
# on time step 15764785 (time=15764.8), 1.63917e-05 s/step
# Meep progress: 16002.655/20000.0 = 80.0% done in 264.0s, 65.9s to go
# on time step 16008426 (time=16008.4), 1.64176e-05 s/step
# Meep progress: 16245.917/20000.0 = 81.2% done in 268.0s, 61.9s to go
# on time step 16251758 (time=16251.8), 1.64385e-05 s/step
# Meep progress: 16489.645/20000.0 = 82.4% done in 272.0s, 57.9s to go
# on time step 16495555 (time=16495.6), 1.64071e-05 s/step
# Meep progress: 16733.483/20000.0 = 83.7% done in 276.0s, 53.9s to go
# on time step 16739482 (time=16739.5), 1.63984e-05 s/step
# Meep progress: 16977.229/20000.0 = 84.9% done in 280.0s, 49.9s to go
# on time step 16983295 (time=16983.3), 1.6406e-05 s/step
# Meep progress: 17220.999/20000.0 = 86.1% done in 284.0s, 45.8s to go
# on time step 17227067 (time=17227.1), 1.64088e-05 s/step
# Meep progress: 17464.565/20000.0 = 87.3% done in 288.0s, 41.8s to go
# on time step 17470779 (time=17470.8), 1.64128e-05 s/step
# Meep progress: 17708.432/20000.0 = 88.5% done in 292.0s, 37.8s to go
# on time step 17714691 (time=17714.7), 1.63994e-05 s/step
# Meep progress: 17951.945/20000.0 = 89.8% done in 296.0s, 33.8s to go
# on time step 17958301 (time=17958.3), 1.64197e-05 s/step
# Meep progress: 18195.817/20000.0 = 91.0% done in 300.0s, 29.7s to go
# on time step 18202250 (time=18202.2), 1.63969e-05 s/step
# Meep progress: 18439.684/20000.0 = 92.2% done in 304.0s, 25.7s to go
# on time step 18446187 (time=18446.2), 1.63977e-05 s/step
# Meep progress: 18683.257/20000.0 = 93.4% done in 308.0s, 21.7s to go
# on time step 18689841 (time=18689.8), 1.64167e-05 s/step
# Meep progress: 18927.016/20000.0 = 94.6% done in 312.0s, 17.7s to go
# on time step 18933649 (time=18933.6), 1.64064e-05 s/step
# Meep progress: 19170.614/20000.0 = 95.9% done in 316.0s, 13.7s to go
# on time step 19177318 (time=19177.3), 1.64157e-05 s/step
# Meep progress: 19414.165/20000.0 = 97.1% done in 320.0s, 9.7s to go
# on time step 19420935 (time=19420.9), 1.64193e-05 s/step
# Meep progress: 19657.9/20000.0 = 98.3% done in 324.0s, 5.6s to go
# on time step 19664753 (time=19664.8), 1.64057e-05 s/step
# Meep progress: 19901.586/20000.0 = 99.5% done in 328.0s, 1.6s to go
# on time step 19908502 (time=19908.5), 1.64103e-05 s/step
# run 0 finished at t = 20000.0 (20000000 timesteps)

# %%
#紀錄通量(真空場)
T_vac = np.array(mp.get_fluxes(tran_vac))

# %%
#晶體(結構場)
geometry = []
z_start = - (d / 2)
for i in range(len(epsi_list)):
    center_z = z_start + (d_list[i] / 2)
    geometry.append(mp.Block(size=mp.Vector3(mp.inf, mp.inf, d_list[i]),
                             center=mp.Vector3(z=center_z),
                             material=mp.Medium(epsilon=epsi_list[i])
                            )
                 )
    z_start += d_list[i]

# %%
#整體模擬流程(結構場)
sim_poyn = mp.Simulation(cell_size=cell_size,
                         geometry=geometry,
                         boundary_layers=pml_layers,
                         sources=sources,
                         dimensions=dimensions,
                         resolution=resolution)
#數據偵測(結構場)
tran_z = (d / 2) + 0.3
tran_fr = mp.FluxRegion(center=mp.Vector3(z = tran_z))
tran = sim_poyn.add_flux(f, 0, 1, tran_fr)
#數據模擬(結構場)  
sim_poyn.run(until=20000)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000290155 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 17 with resolution 500
#      block, center = (0,0,-4.85)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-4.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-4.35)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-4.1)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-3.85)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-3.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-3.35)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-3.1)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-2.85)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-2.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      ...(+ 30 objects not shown)...
# time for set_epsilon = 0.00260115 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=20000.0)
# Meep progress: 238.266/20000.0 = 1.2% done in 4.0s, 331.8s to go
# on time step 238512 (time=238.512), 1.67707e-05 s/step
# Meep progress: 476.719/20000.0 = 2.4% done in 8.0s, 327.6s to go
# on time step 477041 (time=477.041), 1.67695e-05 s/step
# Meep progress: 715.355/20000.0 = 3.6% done in 12.0s, 323.5s to go
# on time step 715766 (time=715.766), 1.67557e-05 s/step
# Meep progress: 953.894/20000.0 = 4.8% done in 16.0s, 319.5s to go
# on time step 954392 (time=954.392), 1.67626e-05 s/step
# Meep progress: 1192.4180000000001/20000.0 = 6.0% done in 20.0s, 315.5s to go
# on time step 1193010 (time=1193.01), 1.67632e-05 s/step
# Meep progress: 1431.325/20000.0 = 7.2% done in 24.0s, 311.4s to go
# on time step 1432002 (time=1432), 1.6737e-05 s/step
# Meep progress: 1670.058/20000.0 = 8.4% done in 28.0s, 307.3s to go
# on time step 1670854 (time=1670.85), 1.67468e-05 s/step
# Meep progress: 1908.8120000000001/20000.0 = 9.5% done in 32.0s, 303.3s to go
# on time step 1909695 (time=1909.69), 1.67476e-05 s/step
# Meep progress: 2147.029/20000.0 = 10.7% done in 36.0s, 299.3s to go
# on time step 2147994 (time=2147.99), 1.67857e-05 s/step
# Meep progress: 2385.324/20000.0 = 11.9% done in 40.0s, 295.4s to go
# on time step 2386383 (time=2386.38), 1.67793e-05 s/step
# Meep progress: 2623.366/20000.0 = 13.1% done in 44.0s, 291.4s to go
# on time step 2624510 (time=2624.51), 1.67978e-05 s/step
# Meep progress: 2861.617/20000.0 = 14.3% done in 48.0s, 287.5s to go
# on time step 2862801 (time=2862.8), 1.67862e-05 s/step
# Meep progress: 3099.603/20000.0 = 15.5% done in 52.0s, 283.5s to go
# on time step 3100937 (time=3100.94), 1.67972e-05 s/step
# Meep progress: 3337.695/20000.0 = 16.7% done in 56.0s, 279.6s to go
# on time step 3339119 (time=3339.12), 1.67939e-05 s/step
# Meep progress: 3575.718/20000.0 = 17.9% done in 60.0s, 275.6s to go
# on time step 3577228 (time=3577.23), 1.67991e-05 s/step
# Meep progress: 3813.9390000000003/20000.0 = 19.1% done in 64.0s, 271.6s to go
# on time step 3815508 (time=3815.51), 1.6787e-05 s/step
# Meep progress: 4052.147/20000.0 = 20.3% done in 68.0s, 267.6s to go
# on time step 4053826 (time=4053.83), 1.67844e-05 s/step
# Meep progress: 4290.473/20000.0 = 21.5% done in 72.0s, 263.6s to go
# on time step 4292241 (time=4292.24), 1.67775e-05 s/step
# Meep progress: 4528.776/20000.0 = 22.6% done in 76.0s, 259.6s to go
# on time step 4530626 (time=4530.63), 1.67797e-05 s/step
# Meep progress: 4767.1230000000005/20000.0 = 23.8% done in 80.0s, 255.6s to go
# on time step 4769064 (time=4769.06), 1.67759e-05 s/step
# Meep progress: 5005.327/20000.0 = 25.0% done in 84.0s, 251.6s to go
# on time step 5007353 (time=5007.35), 1.67864e-05 s/step
# Meep progress: 5243.95/20000.0 = 26.2% done in 88.0s, 247.6s to go
# on time step 5246065 (time=5246.07), 1.67566e-05 s/step
# Meep progress: 5482.442/20000.0 = 27.4% done in 92.0s, 243.6s to go
# on time step 5484635 (time=5484.64), 1.67666e-05 s/step
# Meep progress: 5720.865/20000.0 = 28.6% done in 96.0s, 239.6s to go
# on time step 5723148 (time=5723.15), 1.67706e-05 s/step
# Meep progress: 5959.406/20000.0 = 29.8% done in 100.0s, 235.6s to go
# on time step 5961772 (time=5961.77), 1.67628e-05 s/step
# Meep progress: 6197.582/20000.0 = 31.0% done in 104.0s, 231.6s to go
# on time step 6200037 (time=6200.04), 1.67881e-05 s/step
# Meep progress: 6435.838/20000.0 = 32.2% done in 108.0s, 227.6s to go
# on time step 6438370 (time=6438.37), 1.67833e-05 s/step
# Meep progress: 6674.331/20000.0 = 33.4% done in 112.0s, 223.6s to go
# on time step 6676958 (time=6676.96), 1.67654e-05 s/step
# Meep progress: 6912.702/20000.0 = 34.6% done in 116.0s, 219.6s to go
# on time step 6915411 (time=6915.41), 1.67748e-05 s/step
# Meep progress: 7151.461/20000.0 = 35.8% done in 120.0s, 215.6s to go
# on time step 7154247 (time=7154.25), 1.67479e-05 s/step
# Meep progress: 7389.898/20000.0 = 36.9% done in 124.0s, 211.6s to go
# on time step 7392770 (time=7392.77), 1.67699e-05 s/step
# Meep progress: 7628.475/20000.0 = 38.1% done in 128.0s, 207.6s to go
# on time step 7631426 (time=7631.43), 1.67606e-05 s/step
# Meep progress: 7866.89/20000.0 = 39.3% done in 132.0s, 203.6s to go
# on time step 7869923 (time=7869.92), 1.67718e-05 s/step
# Meep progress: 8105.505/20000.0 = 40.5% done in 136.0s, 199.6s to go
# on time step 8108610 (time=8108.61), 1.67584e-05 s/step
# Meep progress: 8344.303/20000.0 = 41.7% done in 140.0s, 195.6s to go
# on time step 8347498 (time=8347.5), 1.67443e-05 s/step
# Meep progress: 8583.529/20000.0 = 42.9% done in 144.0s, 191.5s to go
# on time step 8586812 (time=8586.81), 1.67145e-05 s/step
# Meep progress: 8822.228000000001/20000.0 = 44.1% done in 148.0s, 187.5s to go
# on time step 8825587 (time=8825.59), 1.67522e-05 s/step
# Meep progress: 9061.144/20000.0 = 45.3% done in 152.0s, 183.5s to go
# on time step 9064579 (time=9064.58), 1.6737e-05 s/step
# Meep progress: 9299.869/20000.0 = 46.5% done in 156.0s, 179.5s to go
# on time step 9303387 (time=9303.39), 1.67499e-05 s/step
# Meep progress: 9538.844000000001/20000.0 = 47.7% done in 160.0s, 175.5s to go
# on time step 9542446 (time=9542.45), 1.67323e-05 s/step
# Meep progress: 9777.351/20000.0 = 48.9% done in 164.0s, 171.5s to go
# on time step 9781034 (time=9781.03), 1.67654e-05 s/step
# Meep progress: 10016.163/20000.0 = 50.1% done in 168.0s, 167.5s to go
# on time step 10019920 (time=10019.9), 1.67445e-05 s/step
# Meep progress: 10254.758/20000.0 = 51.3% done in 172.0s, 163.5s to go
# on time step 10258547 (time=10258.5), 1.67626e-05 s/step
# Meep progress: 10493.717/20000.0 = 52.5% done in 176.0s, 159.4s to go
# on time step 10497657 (time=10497.7), 1.67287e-05 s/step
# Meep progress: 10732.249/20000.0 = 53.7% done in 180.0s, 155.4s to go
# on time step 10736267 (time=10736.3), 1.67638e-05 s/step
# Meep progress: 10971.092/20000.0 = 54.9% done in 184.0s, 151.4s to go
# on time step 10975185 (time=10975.2), 1.67422e-05 s/step
# Meep progress: 11209.908/20000.0 = 56.0% done in 188.0s, 147.4s to go
# on time step 11214086 (time=11214.1), 1.67434e-05 s/step
# Meep progress: 11448.717/20000.0 = 57.2% done in 192.0s, 143.4s to go
# on time step 11452947 (time=11452.9), 1.67461e-05 s/step
# Meep progress: 11687.394/20000.0 = 58.4% done in 196.0s, 139.4s to go
# on time step 11691738 (time=11691.7), 1.67511e-05 s/step
# Meep progress: 11926.235/20000.0 = 59.6% done in 200.0s, 135.4s to go
# on time step 11930642 (time=11930.6), 1.67431e-05 s/step
# Meep progress: 12164.941/20000.0 = 60.8% done in 204.0s, 131.4s to go
# on time step 12169425 (time=12169.4), 1.67516e-05 s/step
# Meep progress: 12403.446/20000.0 = 62.0% done in 208.0s, 127.4s to go
# on time step 12408004 (time=12408), 1.67682e-05 s/step
# Meep progress: 12642.308/20000.0 = 63.2% done in 212.0s, 123.4s to go
# on time step 12646914 (time=12646.9), 1.67428e-05 s/step
# Meep progress: 12880.93/20000.0 = 64.4% done in 216.0s, 119.4s to go
# on time step 12885594 (time=12885.6), 1.67588e-05 s/step
# Meep progress: 13119.401/20000.0 = 65.6% done in 220.0s, 115.4s to go
# on time step 13124136 (time=13124.1), 1.67686e-05 s/step
# Meep progress: 13358.059000000001/20000.0 = 66.8% done in 224.0s, 111.4s to go
# on time step 13362867 (time=13362.9), 1.67553e-05 s/step
# Meep progress: 13596.786/20000.0 = 68.0% done in 228.0s, 107.4s to go
# on time step 13601670 (time=13601.7), 1.67503e-05 s/step
# Meep progress: 13835.463/20000.0 = 69.2% done in 232.0s, 103.4s to go
# on time step 13840407 (time=13840.4), 1.67549e-05 s/step
# Meep progress: 14074.237000000001/20000.0 = 70.4% done in 236.0s, 99.4s to go
# on time step 14079262 (time=14079.3), 1.67466e-05 s/step
# Meep progress: 14312.755000000001/20000.0 = 71.6% done in 240.0s, 95.4s to go
# on time step 14317840 (time=14317.8), 1.67661e-05 s/step
# Meep progress: 14551.505000000001/20000.0 = 72.8% done in 244.0s, 91.4s to go
# on time step 14556649 (time=14556.6), 1.67499e-05 s/step
# Meep progress: 14790.309000000001/20000.0 = 74.0% done in 248.0s, 87.4s to go
# on time step 14795528 (time=14795.5), 1.67449e-05 s/step
# Meep progress: 15029.084/20000.0 = 75.1% done in 252.0s, 83.3s to go
# on time step 15034386 (time=15034.4), 1.67464e-05 s/step
# Meep progress: 15267.537/20000.0 = 76.3% done in 256.0s, 79.4s to go
# on time step 15272889 (time=15272.9), 1.67713e-05 s/step
# Meep progress: 15506.188/20000.0 = 77.5% done in 260.0s, 75.4s to go
# on time step 15511616 (time=15511.6), 1.67556e-05 s/step
# Meep progress: 15744.771/20000.0 = 78.7% done in 264.0s, 71.3s to go
# on time step 15750272 (time=15750.3), 1.67605e-05 s/step
# Meep progress: 15983.163/20000.0 = 79.9% done in 268.0s, 67.4s to go
# on time step 15988725 (time=15988.7), 1.67748e-05 s/step
# Meep progress: 16221.86/20000.0 = 81.1% done in 272.0s, 63.4s to go
# on time step 16227485 (time=16227.5), 1.67533e-05 s/step
# Meep progress: 16460.739/20000.0 = 82.3% done in 276.0s, 59.3s to go
# on time step 16466429 (time=16466.4), 1.67404e-05 s/step
# Meep progress: 16699.564000000002/20000.0 = 83.5% done in 280.0s, 55.3s to go
# on time step 16705336 (time=16705.3), 1.6743e-05 s/step
# Meep progress: 16938.415/20000.0 = 84.7% done in 284.0s, 51.3s to go
# on time step 16944245 (time=16944.2), 1.67428e-05 s/step
# Meep progress: 17177.125/20000.0 = 85.9% done in 288.0s, 47.3s to go
# on time step 17183033 (time=17183), 1.67513e-05 s/step
# Meep progress: 17415.786/20000.0 = 87.1% done in 292.0s, 43.3s to go
# on time step 17421760 (time=17421.8), 1.67555e-05 s/step
# Meep progress: 17654.767/20000.0 = 88.3% done in 296.0s, 39.3s to go
# on time step 17660819 (time=17660.8), 1.67323e-05 s/step
# Meep progress: 17893.607/20000.0 = 89.5% done in 300.0s, 35.3s to go
# on time step 17899722 (time=17899.7), 1.67432e-05 s/step
# Meep progress: 18132.449/20000.0 = 90.7% done in 304.0s, 31.3s to go
# on time step 18138629 (time=18138.6), 1.6743e-05 s/step
# Meep progress: 18371.438000000002/20000.0 = 91.9% done in 308.0s, 27.3s to go
# on time step 18377682 (time=18377.7), 1.67327e-05 s/step
# Meep progress: 18610.39/20000.0 = 93.1% done in 312.0s, 23.3s to go
# on time step 18616697 (time=18616.7), 1.67354e-05 s/step
# Meep progress: 18849.039/20000.0 = 94.2% done in 316.0s, 19.3s to go
# on time step 18855420 (time=18855.4), 1.67559e-05 s/step
# Meep progress: 19087.974000000002/20000.0 = 95.4% done in 320.0s, 15.3s to go
# on time step 19094427 (time=19094.4), 1.67359e-05 s/step
# Meep progress: 19326.734/20000.0 = 96.6% done in 324.0s, 11.3s to go
# on time step 19333257 (time=19333.3), 1.67483e-05 s/step
# Meep progress: 19565.565/20000.0 = 97.8% done in 328.0s, 7.3s to go
# on time step 19572153 (time=19572.2), 1.67437e-05 s/step
# Meep progress: 19804.127/20000.0 = 99.0% done in 332.0s, 3.3s to go
# on time step 19810787 (time=19810.8), 1.67621e-05 s/step
# run 0 finished at t = 20000.0 (20000000 timesteps)

# %%
#紀錄通量(真空場)
T_str = np.array(mp.get_fluxes(tran))
T_meep = T_str / T_vac
print(T_meep)
# Out:
# [0.64587159]

# %%
#電場分布
from matplotlib import pyplot as plt 
z_points = np.linspace(-sz/2, sz/2, int(resolution * sz))
ex_data = []
eps_data = []
for z in z_points:
    ex = sim_poyn.get_field_point(mp.Ex, mp.Vector3(z=z))
    eps = sim_poyn.get_epsilon_point(mp.Vector3(z=z))
    ex_data.append(ex)
    eps_data.append(eps)
ex_data = np.array(ex_data)
eps_data = np.array(eps_data)
#場分布+介電常數分布
fig, ax1 = plt.subplots(1, 1, figsize=(12, 4))
#電場 Ex
ax1.plot(z_points, np.real(ex_data), 'b-', label='Real(Ex)', linewidth=1)
ax1.set_xlabel('z position')
ax1.set_ylabel('Ex field')
ax1.grid(True, alpha=0.3)
#介電常數
ax2 = ax1.twinx()
ax2.plot(z_points, eps_data, 'r-', label='epsilon(z)', linewidth=1, alpha=0.6)
ax2.set_ylabel('epsilon')
#Source 與 Detector 位置
ax1.axvline(sour_z, color='green', linestyle='--', linewidth=1)
ax1.text(sour_z, np.max(np.real(ex_data))*0.8, 'Source', color='green', 
         rotation=90, verticalalignment='center')
ax1.axvline(tran_z, color='purple', linestyle='--', linewidth=1)
ax1.text(tran_z, np.max(np.real(ex_data))*0.8, 'Detector', color='purple',
         rotation=90, verticalalignment='center')
#繪圖
lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='upper right')
ax1.set_title('Electric Field & Dielectric Distribution with Source/Detector')
plt.show()
# Out:
# /home/xin_314514066/miniconda/envs/mp/lib/python3.9/site-packages/matplotlib/cbook.py:1762: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/xin_314514066/miniconda/envs/mp/lib/python3.9/site-packages/matplotlib/cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
