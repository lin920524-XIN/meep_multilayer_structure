# %% [markdown]
# Layers A and B have the thicknesses  $d_A$ = 200 nm  and  $d_B$ = 300 nm , and the dielectric constants $ϵ_A$ = 12 and $ϵ_B$ = 3. Compute and plot the single-frequency electric field distribution for a structure consisting of 15 repeated AB layers (ABABAB…).

# %% [markdown]
# =========================================
# #在穿透率近似於0的頻率(f=1.2)
# =========================================

# %%
#=======================數值計算=======================
import numpy as np
#頻率相關參數
f = 1.2
omega = 2 * np.pi * f
#結構重複次數
num_pairs = 15
#etalon厚度
d_single = [0.2, 0.3]
d_list = []
for i in range(num_pairs):
    for j in range(len(d_single)-1):
        d_list.append(d_single[0])
        d_list.append(d_single[1])
d = sum(d_list)
d_pair = sum(d_single)
#材料介電常數
epsi_single = [12, 3]
epsi_list = []
for i in range(num_pairs):
    for j in range(len(epsi_single)-1):
        epsi_list.append(epsi_single[0])
        epsi_list.append(epsi_single[1])
#材料相位差
delta_list = []
for epsi, a in zip(epsi_list, d_list):
    delta = 2 * omega * a * np.sqrt(epsi)
    delta_list.append(delta)
delta_array = np.array(delta_list)
epsi_all = epsi_list.copy()  
epsi_all.insert(0, 1)
epsi_all.append(1)
#=======================meep模擬=======================
import meep as mp
resolution = 125
dpml = 1.0
sz = (d_pair * 30.0) + (dpml * 2.0)
cell_size = mp.Vector3(z=sz)
pml_layers = [mp.PML(dpml)]
dimensions = 1
#電磁波源(平面波)
sour_z = - (sz / 4) - 0.3 
sources = [mp.Source(src=mp.ContinuousSource(frequency=f),
                     component=mp.Ex,
                     center=mp.Vector3(z=sour_z))
]
#真空
sim_vac = mp.Simulation(cell_size=cell_size,
                        boundary_layers=pml_layers,
                        sources=sources,
                        dimensions=dimensions,
                        resolution=resolution)
#數據偵測(真空場)
tran_z = -(sz / 4) + d + 0.3
tran_vac_fr = mp.FluxRegion(center=mp.Vector3(z = tran_z))
tran_vac = sim_vac.add_flux(f, 0, 1, tran_vac_fr)
#數據模擬(真空場)
sim_vac.run(until=20000)
#紀錄通量(真空場)
T_vac = np.array(mp.get_fluxes(tran_vac))
#結構
geometry = []
z_start = - (sz / 4)
for i in range(num_pairs * 2):
    center_z = z_start + (d_list[i] / 2)
    geometry.append(mp.Block(size=mp.Vector3(mp.inf, mp.inf, d_list[i]),
                             center=mp.Vector3(z=center_z),
                             material=mp.Medium(epsilon=epsi_list[i])
                            )
                 )
    z_start += d_list[i]
#整體模擬流程(結構場)
sim_poyn = mp.Simulation(cell_size=cell_size,
                         geometry=geometry,
                         boundary_layers=pml_layers,
                         sources=sources,
                         dimensions=dimensions,
                         resolution=resolution)
#數據偵測(結構場)
tran_z = -(sz / 4) + d + 0.3
tran_fr = mp.FluxRegion(center=mp.Vector3(z = tran_z))
tran = sim_poyn.add_flux(f, 0, 1, tran_fr)
#數據模擬(結構場)
sim_poyn.run(until=20000)
#紀錄通量(真空場)
T_str = np.array(mp.get_fluxes(tran))
T_meep = T_str / T_vac
print("R =",1-T_meep)
print("T =",T_meep)
#電場分布
from matplotlib import pyplot as plt 
z_points = np.linspace(-sz/2, sz/2, int(resolution * sz))
ex_data = []
eps_data = []
for z in z_points:
    ex = sim_poyn.get_field_point(mp.Ex, mp.Vector3(z=z))
    eps = sim_poyn.get_epsilon_point(mp.Vector3(z=z))
    ex_data.append(ex)
    eps_data.append(eps)
ex_data = np.array(ex_data)
eps_data = np.array(eps_data)
#場分布+介電常數分布
fig, ax1 = plt.subplots(1, 1, figsize=(12, 4))
#電場 Ex
ax1.plot(z_points, np.real(ex_data), 'b-', label='Real(Ex)', linewidth=1)
ax1.set_xlabel('z position')
ax1.set_ylabel('Ex field')
ax1.grid(True, alpha=0.3)
#介電常數
ax2 = ax1.twinx()
ax2.plot(z_points, eps_data, 'r-', label='epsilon(z)', linewidth=1, alpha=0.6)
ax2.set_ylabel('epsilon')
#Source 與 Detector 位置
ax1.axvline(sour_z, color='green', linestyle='--', linewidth=1)
ax1.text(sour_z, np.max(np.real(ex_data))*0.8, 'Source', color='green', 
         rotation=90, verticalalignment='center')
ax1.axvline(tran_z, color='purple', linestyle='--', linewidth=1)
ax1.text(tran_z, np.max(np.real(ex_data))*0.8, 'Detector', color='purple',
         rotation=90, verticalalignment='center')
#繪圖
lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='upper right')
ax1.set_title('Electric Field & Dielectric Distribution with Source/Detector')
plt.show()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.39369e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 17 with resolution 125
# time for set_epsilon = 0.000350952 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=20000.0)
# Meep progress: 1261.496/20000.0 = 6.3% done in 4.0s, 59.4s to go
# on time step 315544 (time=1262.18), 1.26765e-05 s/step
# Meep progress: 2522.964/20000.0 = 12.6% done in 8.0s, 55.4s to go
# on time step 630960 (time=2523.84), 1.26817e-05 s/step
# Meep progress: 3785.48/20000.0 = 18.9% done in 12.0s, 51.4s to go
# on time step 946635 (time=3786.54), 1.26713e-05 s/step
# Meep progress: 5045.236/20000.0 = 25.2% done in 16.0s, 47.4s to go
# on time step 1261708 (time=5046.83), 1.26955e-05 s/step
# Meep progress: 6310.416/20000.0 = 31.6% done in 20.0s, 43.4s to go
# on time step 1578222 (time=6312.89), 1.26377e-05 s/step
# Meep progress: 7575.488/20000.0 = 37.9% done in 24.0s, 39.4s to go
# on time step 1894600 (time=7578.4), 1.26431e-05 s/step
# Meep progress: 8835.888/20000.0 = 44.2% done in 28.0s, 35.4s to go
# on time step 2209840 (time=8839.36), 1.26888e-05 s/step
# Meep progress: 10097.1/20000.0 = 50.5% done in 32.0s, 31.4s to go
# on time step 2525275 (time=10101.1), 1.26809e-05 s/step
# Meep progress: 11357.092/20000.0 = 56.8% done in 36.0s, 27.4s to go
# on time step 2840371 (time=11361.5), 1.26946e-05 s/step
# Meep progress: 12610.408/20000.0 = 63.1% done in 40.0s, 23.4s to go
# on time step 3153872 (time=12615.5), 1.27591e-05 s/step
# Meep progress: 13855.124/20000.0 = 69.3% done in 44.0s, 19.5s to go
# on time step 3465091 (time=13860.4), 1.28527e-05 s/step
# Meep progress: 15093.604000000001/20000.0 = 75.5% done in 48.0s, 15.6s to go
# on time step 3774763 (time=15099.1), 1.29169e-05 s/step
# Meep progress: 16331.512/20000.0 = 81.7% done in 52.0s, 11.7s to go
# on time step 4084282 (time=16337.1), 1.29233e-05 s/step
# Meep progress: 17570.036/20000.0 = 87.9% done in 56.0s, 7.7s to go
# on time step 4393919 (time=17575.7), 1.29184e-05 s/step
# Meep progress: 18810.752/20000.0 = 94.1% done in 60.0s, 3.8s to go
# on time step 4704206 (time=18816.8), 1.28913e-05 s/step
# run 0 finished at t = 20000.0 (5000000 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000152111 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 17 with resolution 125
#      block, center = (0,0,-4.15)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-3.9)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-3.65)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-3.4)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-3.15)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-2.9)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-2.65)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-2.4)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-2.15)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-1.9)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      ...(+ 20 objects not shown)...
# time for set_epsilon = 0.00107789 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=20000.0)
# Meep progress: 1216.128/20000.0 = 6.1% done in 4.0s, 61.8s to go
# on time step 304237 (time=1216.95), 1.31477e-05 s/step
# Meep progress: 2434.516/20000.0 = 12.2% done in 8.0s, 57.7s to go
# on time step 608893 (time=2435.57), 1.31296e-05 s/step
# Meep progress: 3651.676/20000.0 = 18.3% done in 12.0s, 53.7s to go
# on time step 913226 (time=3652.9), 1.31435e-05 s/step
# Meep progress: 4870.868/20000.0 = 24.4% done in 16.0s, 49.7s to go
# on time step 1218069 (time=4872.28), 1.31215e-05 s/step
# Meep progress: 6088.084/20000.0 = 30.4% done in 20.0s, 45.7s to go
# on time step 1522416 (time=6089.66), 1.31429e-05 s/step
# Meep progress: 7305.876/20000.0 = 36.5% done in 24.0s, 41.7s to go
# on time step 1826898 (time=7307.59), 1.31371e-05 s/step
# Meep progress: 8521.94/20000.0 = 42.6% done in 28.0s, 37.7s to go
# on time step 2130971 (time=8523.88), 1.31548e-05 s/step
# Meep progress: 9734.804/20000.0 = 48.7% done in 32.0s, 33.7s to go
# on time step 2434228 (time=9736.91), 1.31902e-05 s/step
# Meep progress: 10945.736/20000.0 = 54.7% done in 36.0s, 29.8s to go
# on time step 2737015 (time=10948.1), 1.32106e-05 s/step
# Meep progress: 12159.216/20000.0 = 60.8% done in 40.0s, 25.8s to go
# on time step 3040376 (time=12161.5), 1.31857e-05 s/step
# Meep progress: 13375.588/20000.0 = 66.9% done in 44.0s, 21.8s to go
# on time step 3344579 (time=13378.3), 1.31491e-05 s/step
# Meep progress: 14591.464/20000.0 = 73.0% done in 48.0s, 17.8s to go
# on time step 3648558 (time=14594.2), 1.31588e-05 s/step
# Meep progress: 15808.128/20000.0 = 79.0% done in 52.0s, 13.8s to go
# on time step 3952795 (time=15811.2), 1.31478e-05 s/step
# Meep progress: 17027.048/20000.0 = 85.1% done in 56.0s, 9.8s to go
# on time step 4257585 (time=17030.3), 1.31238e-05 s/step
# Meep progress: 18246.608/20000.0 = 91.2% done in 60.0s, 5.8s to go
# on time step 4562508 (time=18250), 1.31181e-05 s/step
# Meep progress: 19464.596/20000.0 = 97.3% done in 64.0s, 1.8s to go
# on time step 4867037 (time=19468.1), 1.3135e-05 s/step
# run 0 finished at t = 20000.0 (5000000 timesteps)
# R = [0.9999992]
# T = [7.98894813e-07]

# %% [markdown]
# =========================================
# #在穿透率不為0的頻率(f=1.5)
# =========================================

# %%
#=======================數值計算=======================
import numpy as np
#頻率相關參數
f = 1.5
omega = 2 * np.pi * f
#結構重複次數
num_pairs = 15
#etalon厚度
d_single = [0.2, 0.3]
d_list = []
for i in range(num_pairs):
    for j in range(len(d_single)-1):
        d_list.append(d_single[0])
        d_list.append(d_single[1])
d = sum(d_list)
d_pair = sum(d_single)
#材料介電常數
epsi_single = [12, 3]
epsi_list = []
for i in range(num_pairs):
    for j in range(len(epsi_single)-1):
        epsi_list.append(epsi_single[0])
        epsi_list.append(epsi_single[1])
#材料相位差
delta_list = []
for epsi, a in zip(epsi_list, d_list):
    delta = 2 * omega * a * np.sqrt(epsi)
    delta_list.append(delta)
delta_array = np.array(delta_list)
epsi_all = epsi_list.copy()  
epsi_all.insert(0, 1)
epsi_all.append(1)
#=======================meep模擬=======================
import meep as mp
resolution = 125
dpml = 1.0
sz = (d_pair * 30.0) + (dpml * 2.0)
cell_size = mp.Vector3(z=sz)
pml_layers = [mp.PML(dpml)]
dimensions = 1
#電磁波源(平面波)
sour_z = - (sz / 4) - 0.3 
sources = [mp.Source(src=mp.ContinuousSource(frequency=f),
                     component=mp.Ex,
                     center=mp.Vector3(z=sour_z))
]
#真空
sim_vac = mp.Simulation(cell_size=cell_size,
                        boundary_layers=pml_layers,
                        sources=sources,
                        dimensions=dimensions,
                        resolution=resolution)
#數據偵測(真空場)
tran_z = -(sz / 4) + d + 0.3
tran_vac_fr = mp.FluxRegion(center=mp.Vector3(z = tran_z))
tran_vac = sim_vac.add_flux(f, 0, 1, tran_vac_fr)
#數據模擬(真空場)
sim_vac.run(until=20000)
#紀錄通量(真空場)
T_vac = np.array(mp.get_fluxes(tran_vac))
#結構
geometry = []
z_start = - (sz / 4)
for i in range(num_pairs * 2):
    center_z = z_start + (d_list[i] / 2)
    geometry.append(mp.Block(size=mp.Vector3(mp.inf, mp.inf, d_list[i]),
                             center=mp.Vector3(z=center_z),
                             material=mp.Medium(epsilon=epsi_list[i])
                            )
                 )
    z_start += d_list[i]
#整體模擬流程(結構場)
sim_poyn = mp.Simulation(cell_size=cell_size,
                         geometry=geometry,
                         boundary_layers=pml_layers,
                         sources=sources,
                         dimensions=dimensions,
                         resolution=resolution)
#數據偵測(結構場)
tran_z = -(sz / 4) + d + 0.3
tran_fr = mp.FluxRegion(center=mp.Vector3(z = tran_z))
tran = sim_poyn.add_flux(f, 0, 1, tran_fr)
#數據模擬(結構場)
sim_poyn.run(until=20000)
#紀錄通量(真空場)
T_str = np.array(mp.get_fluxes(tran))
T_meep = T_str / T_vac
print("R =",1-T_meep)
print("T =",T_meep)
#電場分布
from matplotlib import pyplot as plt 
z_points = np.linspace(-sz/2, sz/2, int(resolution * sz))
ex_data = []
eps_data = []
for z in z_points:
    ex = sim_poyn.get_field_point(mp.Ex, mp.Vector3(z=z))
    eps = sim_poyn.get_epsilon_point(mp.Vector3(z=z))
    ex_data.append(ex)
    eps_data.append(eps)
ex_data = np.array(ex_data)
eps_data = np.array(eps_data)
#場分布+介電常數分布
fig, ax1 = plt.subplots(1, 1, figsize=(12, 4))
#電場 Ex
ax1.plot(z_points, np.real(ex_data), 'b-', label='Real(Ex)', linewidth=1)
ax1.set_xlabel('z position')
ax1.set_ylabel('Ex field')
ax1.grid(True, alpha=0.3)
#介電常數
ax2 = ax1.twinx()
ax2.plot(z_points, eps_data, 'r-', label='epsilon(z)', linewidth=1, alpha=0.6)
ax2.set_ylabel('epsilon')
#Source 與 Detector 位置
ax1.axvline(sour_z, color='green', linestyle='--', linewidth=1)
ax1.text(sour_z, np.max(np.real(ex_data))*0.8, 'Source', color='green', 
         rotation=90, verticalalignment='center')
ax1.axvline(tran_z, color='purple', linestyle='--', linewidth=1)
ax1.text(tran_z, np.max(np.real(ex_data))*0.8, 'Detector', color='purple',
         rotation=90, verticalalignment='center')
#繪圖
lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='upper right')
ax1.set_title('Electric Field & Dielectric Distribution with Source/Detector')
plt.show()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000149965 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 17 with resolution 125
# time for set_epsilon = 0.000530005 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=20000.0)
# Meep progress: 942.312/20000.0 = 4.7% done in 4.0s, 80.9s to go
# on time step 235887 (time=943.548), 1.69573e-05 s/step
# Meep progress: 1930.78/20000.0 = 9.7% done in 8.0s, 74.9s to go
# on time step 482964 (time=1931.86), 1.61894e-05 s/step
# Meep progress: 2850.628/20000.0 = 14.3% done in 12.0s, 72.2s to go
# on time step 713027 (time=2852.11), 1.73866e-05 s/step
# Meep progress: 3936.84/20000.0 = 19.7% done in 16.0s, 65.3s to go
# on time step 984752 (time=3939.01), 1.47208e-05 s/step
# Meep progress: 5153.828/20000.0 = 25.8% done in 20.0s, 57.6s to go
# on time step 1289152 (time=5156.61), 1.31406e-05 s/step
# Meep progress: 6370.388/20000.0 = 31.9% done in 24.0s, 51.3s to go
# on time step 1593346 (time=6373.38), 1.31495e-05 s/step
# Meep progress: 7589.128000000001/20000.0 = 37.9% done in 28.0s, 45.8s to go
# on time step 1898174 (time=7592.7), 1.31222e-05 s/step
# Meep progress: 8808.036/20000.0 = 44.0% done in 32.0s, 40.7s to go
# on time step 2203103 (time=8812.41), 1.31178e-05 s/step
# Meep progress: 9703.348/20000.0 = 48.5% done in 36.0s, 38.2s to go
# on time step 2426680 (time=9706.72), 1.7891e-05 s/step
# Meep progress: 10583.816/20000.0 = 52.9% done in 40.0s, 35.6s to go
# on time step 2646882 (time=10587.5), 1.81652e-05 s/step
# Meep progress: 11648.02/20000.0 = 58.2% done in 44.0s, 31.5s to go
# on time step 2913322 (time=11653.3), 1.50128e-05 s/step
# Meep progress: 12870.316/20000.0 = 64.4% done in 48.0s, 26.6s to go
# on time step 3219082 (time=12876.3), 1.30822e-05 s/step
# Meep progress: 14089.036/20000.0 = 70.4% done in 52.0s, 21.8s to go
# on time step 3523718 (time=14094.9), 1.31304e-05 s/step
# Meep progress: 15306.712/20000.0 = 76.5% done in 56.0s, 17.2s to go
# on time step 3828350 (time=15313.4), 1.31306e-05 s/step
# Meep progress: 16526.08/20000.0 = 82.6% done in 60.0s, 12.6s to go
# on time step 4132882 (time=16531.5), 1.31349e-05 s/step
# Meep progress: 17728.736/20000.0 = 88.6% done in 64.0s, 8.2s to go
# on time step 4434043 (time=17736.2), 1.3282e-05 s/step
# Meep progress: 18950.872/20000.0 = 94.8% done in 68.0s, 3.8s to go
# on time step 4739714 (time=18958.9), 1.3086e-05 s/step
# run 0 finished at t = 20000.0 (5000000 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000135183 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 17 with resolution 125
#      block, center = (0,0,-4.15)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-3.9)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-3.65)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-3.4)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-3.15)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-2.9)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-2.65)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-2.4)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-2.15)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-1.9)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      ...(+ 20 objects not shown)...
# time for set_epsilon = 0.000784874 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=20000.0)
# Meep progress: 1182.28/20000.0 = 5.9% done in 4.0s, 63.7s to go
# on time step 296127 (time=1184.51), 1.35078e-05 s/step
# Meep progress: 2382.6040000000003/20000.0 = 11.9% done in 8.0s, 59.2s to go
# on time step 596300 (time=2385.2), 1.33257e-05 s/step
# Meep progress: 3582.8360000000002/20000.0 = 17.9% done in 12.0s, 55.0s to go
# on time step 896434 (time=3585.74), 1.33274e-05 s/step
# Meep progress: 4783.68/20000.0 = 23.9% done in 16.0s, 50.9s to go
# on time step 1196840 (time=4787.36), 1.33153e-05 s/step
# Meep progress: 5984.34/20000.0 = 29.9% done in 20.0s, 46.8s to go
# on time step 1497148 (time=5988.59), 1.33197e-05 s/step
# Meep progress: 7188.7080000000005/20000.0 = 35.9% done in 24.0s, 42.8s to go
# on time step 1798377 (time=7193.51), 1.3279e-05 s/step
# Meep progress: 8421.476/20000.0 = 42.1% done in 28.0s, 38.5s to go
# on time step 2106715 (time=8426.86), 1.29728e-05 s/step
# Meep progress: 9660.024/20000.0 = 48.3% done in 32.0s, 34.3s to go
# on time step 2416478 (time=9665.91), 1.29131e-05 s/step
# Meep progress: 10897.656/20000.0 = 54.5% done in 36.0s, 30.1s to go
# on time step 2725976 (time=10903.9), 1.29242e-05 s/step
# Meep progress: 12132.928/20000.0 = 60.7% done in 40.0s, 25.9s to go
# on time step 3034931 (time=12139.7), 1.29469e-05 s/step
# Meep progress: 13368.792/20000.0 = 66.8% done in 44.0s, 21.8s to go
# on time step 3343948 (time=13375.8), 1.29443e-05 s/step
# Meep progress: 14605.024/20000.0 = 73.0% done in 48.0s, 17.7s to go
# on time step 3653267 (time=14613.1), 1.29317e-05 s/step
# Meep progress: 15844.208/20000.0 = 79.2% done in 52.0s, 13.6s to go
# on time step 3963199 (time=15852.8), 1.29061e-05 s/step
# Meep progress: 17085.752/20000.0 = 85.4% done in 56.0s, 9.6s to go
# on time step 4273691 (time=17094.8), 1.28828e-05 s/step
# Meep progress: 18327.112/20000.0 = 91.6% done in 60.0s, 5.5s to go
# on time step 4584138 (time=18336.6), 1.28847e-05 s/step
# Meep progress: 19566.956000000002/20000.0 = 97.8% done in 64.0s, 1.4s to go
# on time step 4894195 (time=19576.8), 1.29009e-05 s/step
# run 0 finished at t = 20000.0 (5000000 timesteps)
# R = [0.00192097]
# T = [0.99807903]
# /home/xin_314514066/miniconda/envs/mp/lib/python3.9/site-packages/matplotlib/cbook.py:1762: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/xin_314514066/miniconda/envs/mp/lib/python3.9/site-packages/matplotlib/cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
