# %% [markdown]
# Layers A and B have the thicknesses  $d_A = 200 nm$  and  $d_B = 300 nm$ , and the dielectric constants $ϵ_A = 12$ and $ϵ_B = 3$.Compute and plot the single-frequency electric field distribution for structure of 10 repeated AB followed by 10 repeated BA.(300 < ω < 600 THz)

# %% [markdown]
# =========================================
# #在穿透率近似於0的頻率(f=1.2)
# =========================================

# %%
#=======================數值計算=======================
import numpy as np
#頻率相關參數
f = 1.2
omega = 2 * np.pi * f
#結構重複次數
num_pairs = 10
#晶體厚度
d_single = [0.2, 0.3]
d_list = []
for i in range(num_pairs):
    for j in range(len(d_single)-1):
        d_list.append(d_single[0])
        d_list.append(d_single[1])
for i in range(num_pairs):
    for j in range(len(d_single)-1):
        d_list.append(d_single[1])
        d_list.append(d_single[0])
d = sum(d_list)
d_pair = sum(d_single)
#材料介電常數
epsi_single = [12, 3]
epsi_list = []
for i in range(num_pairs):
    for j in range(len(epsi_single)-1):
        epsi_list.append(epsi_single[0])
        epsi_list.append(epsi_single[1])
for i in range(num_pairs):
    for j in range(len(epsi_single)-1):
        epsi_list.append(epsi_single[1])
        epsi_list.append(epsi_single[0])
#材料相位差
delta_list = []
for epsi, a in zip(epsi_list, d_list):
    delta = 2 * omega * a * np.sqrt(epsi)
    delta_list.append(delta)
delta_array = np.array(delta_list)
epsi_all = epsi_list.copy()  
epsi_all.insert(0, 1)
epsi_all.append(1)
epsi_all = epsi_list.copy()  
epsi_all.insert(0, 1)
epsi_all.append(1)
#=======================meep模擬=======================
import meep as mp
resolution = 125
dpml = 1.0
sz = (d_pair * 50.0) + (dpml * 2.0)
cell_size = mp.Vector3(z=sz)
pml_layers = [mp.PML(dpml)]
dimensions = 1
#電磁波源(平面波)
sour_z = - (sz / 4) - 0.3 
sources = [mp.Source(src=mp.ContinuousSource(frequency=f),
                     component=mp.Ex,
                     center=mp.Vector3(z=sour_z))
]
#真空
sim_vac = mp.Simulation(cell_size=cell_size,
                        boundary_layers=pml_layers,
                        sources=sources,
                        dimensions=dimensions,
                        resolution=resolution)
#數據偵測(真空場)
tran_z = -(sz / 4) + d + 0.3
tran_vac_fr = mp.FluxRegion(center=mp.Vector3(z = tran_z))
tran_vac = sim_vac.add_flux(f, 0, 1, tran_vac_fr)
#數據模擬(真空場)
sim_vac.run(until=20000)
#紀錄通量(真空場)
T_vac = np.array(mp.get_fluxes(tran_vac))
#結構
geometry = []
z_start = - (sz / 4)
for i in range(len(epsi_list)-1):
    center_z = z_start + (d_list[i] / 2)
    geometry.append(mp.Block(size=mp.Vector3(mp.inf, mp.inf, d_list[i]),
                             center=mp.Vector3(z=center_z),
                             material=mp.Medium(epsilon=epsi_list[i])
                            )
                 )
    z_start += d_list[i]
#整體模擬流程(結構場)
sim_poyn = mp.Simulation(cell_size=cell_size,
                         geometry=geometry,
                         boundary_layers=pml_layers,
                         sources=sources,
                         dimensions=dimensions,
                         resolution=resolution)
#數據偵測(結構場)
tran_z = -(sz / 4) + d + 0.3
tran_fr = mp.FluxRegion(center=mp.Vector3(z = tran_z))
tran = sim_poyn.add_flux(f, 0, 1, tran_fr)
#數據模擬(結構場)
sim_poyn.run(until=20000)
#紀錄通量(真空場)
T_str = np.array(mp.get_fluxes(tran))
T_meep = T_str / T_vac
print("R =",1-T_meep)
print("T =",T_meep)
#電場分布
from matplotlib import pyplot as plt 
z_points = np.linspace(-sz/2, sz/2, int(resolution * sz))
ex_data = []
eps_data = []
for z in z_points:
    ex = sim_poyn.get_field_point(mp.Ex, mp.Vector3(z=z))
    eps = sim_poyn.get_epsilon_point(mp.Vector3(z=z))
    ex_data.append(ex)
    eps_data.append(eps)
ex_data = np.array(ex_data)
eps_data = np.array(eps_data)
#場分布+介電常數分布
fig, ax1 = plt.subplots(1, 1, figsize=(12, 4))
#電場 Ex
ax1.plot(z_points, np.real(ex_data), 'b-', label='Real(Ex)', linewidth=1)
ax1.set_xlabel('z position')
ax1.set_ylabel('Ex field')
ax1.grid(True, alpha=0.3)
#介電常數
ax2 = ax1.twinx()
ax2.plot(z_points, eps_data, 'r-', label='epsilon(z)', linewidth=1, alpha=0.6)
ax2.set_ylabel('epsilon')
#Source 與 Detector 位置
ax1.axvline(sour_z, color='green', linestyle='--', linewidth=1)
ax1.text(sour_z, np.max(np.real(ex_data))*0.8, 'Source', color='green', 
         rotation=90, verticalalignment='center')
ax1.axvline(tran_z, color='purple', linestyle='--', linewidth=1)
ax1.text(tran_z, np.max(np.real(ex_data))*0.8, 'Detector', color='purple',
         rotation=90, verticalalignment='center')
#繪圖
lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='upper right')
ax1.set_title('Electric Field & Dielectric Distribution with Source/Detector')
plt.show()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000118017 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 27 with resolution 125
# time for set_epsilon = 0.000864029 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=20000.0)
# Meep progress: 1147.6200000000001/20000.0 = 5.7% done in 4.0s, 65.7s to go
# on time step 287335 (time=1149.34), 1.39211e-05 s/step
# Meep progress: 2297.504/20000.0 = 11.5% done in 8.0s, 61.6s to go
# on time step 574848 (time=2299.39), 1.39124e-05 s/step
# Meep progress: 3443.492/20000.0 = 17.2% done in 12.0s, 57.7s to go
# on time step 861380 (time=3445.52), 1.39601e-05 s/step
# Meep progress: 4590.296/20000.0 = 23.0% done in 16.0s, 53.7s to go
# on time step 1148277 (time=4593.11), 1.39423e-05 s/step
# Meep progress: 5735.764/20000.0 = 28.7% done in 20.0s, 49.7s to go
# on time step 1434782 (time=5739.13), 1.39614e-05 s/step
# Meep progress: 6885.976000000001/20000.0 = 34.4% done in 24.0s, 45.7s to go
# on time step 1722451 (time=6889.8), 1.39049e-05 s/step
# Meep progress: 7938.744000000001/20000.0 = 39.7% done in 28.0s, 42.5s to go
# on time step 1985477 (time=7941.91), 1.52076e-05 s/step
# Meep progress: 8807.72/20000.0 = 44.0% done in 32.0s, 40.7s to go
# on time step 2202870 (time=8811.48), 1.83999e-05 s/step
# Meep progress: 9675.728000000001/20000.0 = 48.4% done in 36.0s, 38.4s to go
# on time step 2419899 (time=9679.6), 1.84308e-05 s/step
# Meep progress: 10543.332/20000.0 = 52.7% done in 40.0s, 35.9s to go
# on time step 2636831 (time=10547.3), 1.8439e-05 s/step
# Meep progress: 11411.456/20000.0 = 57.1% done in 44.0s, 33.1s to go
# on time step 2853897 (time=11415.6), 1.84276e-05 s/step
# Meep progress: 12276.44/20000.0 = 61.4% done in 48.0s, 30.2s to go
# on time step 3070149 (time=12280.6), 1.8497e-05 s/step
# Meep progress: 13144.576000000001/20000.0 = 65.7% done in 52.0s, 27.1s to go
# on time step 3287239 (time=13149), 1.84256e-05 s/step
# Meep progress: 14013.532000000001/20000.0 = 70.1% done in 56.0s, 23.9s to go
# on time step 3504515 (time=14018.1), 1.84098e-05 s/step
# Meep progress: 14874.068000000001/20000.0 = 74.4% done in 60.0s, 20.7s to go
# on time step 3719677 (time=14878.7), 1.85907e-05 s/step
# Meep progress: 15742.172/20000.0 = 78.7% done in 64.0s, 17.3s to go
# on time step 3936745 (time=15747), 1.84274e-05 s/step
# Meep progress: 16852.62/20000.0 = 84.3% done in 68.0s, 12.7s to go
# on time step 4214795 (time=16859.2), 1.43859e-05 s/step
# Meep progress: 18003.692/20000.0 = 90.0% done in 72.0s, 8.0s to go
# on time step 4502628 (time=18010.5), 1.3897e-05 s/step
# Meep progress: 19152.412/20000.0 = 95.8% done in 76.0s, 3.4s to go
# on time step 4789867 (time=19159.5), 1.39257e-05 s/step
# run 0 finished at t = 20000.0 (5000000 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000154972 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 27 with resolution 125
#      block, center = (0,0,-6.65)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-6.15)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-5.65)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.4)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-5.15)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-4.9)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-4.65)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-4.4)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      ...(+ 29 objects not shown)...
# time for set_epsilon = 0.00122404 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=20000.0)
# Meep progress: 1117.404/20000.0 = 5.6% done in 4.0s, 67.6s to go
# on time step 279569 (time=1118.28), 1.43078e-05 s/step
# Meep progress: 2262.484/20000.0 = 11.3% done in 8.0s, 62.7s to go
# on time step 565909 (time=2263.64), 1.39694e-05 s/step
# Meep progress: 3409.02/20000.0 = 17.0% done in 12.0s, 58.4s to go
# on time step 852573 (time=3410.29), 1.39536e-05 s/step
# Meep progress: 4551.292/20000.0 = 22.8% done in 16.0s, 54.3s to go
# on time step 1138147 (time=4552.59), 1.40069e-05 s/step
# Meep progress: 5678.392/20000.0 = 28.4% done in 20.0s, 50.4s to go
# on time step 1419986 (time=5679.94), 1.41925e-05 s/step
# Meep progress: 6806.08/20000.0 = 34.0% done in 24.0s, 46.5s to go
# on time step 1701969 (time=6807.88), 1.41853e-05 s/step
# Meep progress: 7934.484/20000.0 = 39.7% done in 28.0s, 42.6s to go
# on time step 1984108 (time=7936.43), 1.41775e-05 s/step
# Meep progress: 9055.804/20000.0 = 45.3% done in 32.0s, 38.7s to go
# on time step 2264563 (time=9058.25), 1.42625e-05 s/step
# Meep progress: 10182.452/20000.0 = 50.9% done in 36.0s, 34.7s to go
# on time step 2546272 (time=10185.1), 1.41991e-05 s/step
# Meep progress: 11306.388/20000.0 = 56.5% done in 40.0s, 30.8s to go
# on time step 2827290 (time=11309.2), 1.4234e-05 s/step
# Meep progress: 12431.552/20000.0 = 62.2% done in 44.0s, 26.8s to go
# on time step 3108621 (time=12434.5), 1.42181e-05 s/step
# Meep progress: 13554.692000000001/20000.0 = 67.8% done in 48.0s, 22.8s to go
# on time step 3389442 (time=13557.8), 1.4244e-05 s/step
# Meep progress: 14678.052/20000.0 = 73.4% done in 52.0s, 18.9s to go
# on time step 3670339 (time=14681.4), 1.42401e-05 s/step
# Meep progress: 15799.136/20000.0 = 79.0% done in 56.0s, 14.9s to go
# on time step 3950679 (time=15802.7), 1.42684e-05 s/step
# Meep progress: 16925.212/20000.0 = 84.6% done in 60.0s, 10.9s to go
# on time step 4232251 (time=16929), 1.4206e-05 s/step
# Meep progress: 18052.008/20000.0 = 90.3% done in 64.0s, 6.9s to go
# on time step 4514002 (time=18056), 1.41969e-05 s/step
# Meep progress: 19179.02/20000.0 = 95.9% done in 68.0s, 2.9s to go
# on time step 4795802 (time=19183.2), 1.41945e-05 s/step
# run 0 finished at t = 20000.0 (5000000 timesteps)
# R = [0.99999999]
# T = [1.04322335e-08]
# /home/xin_314514066/miniconda/envs/mp/lib/python3.9/site-packages/matplotlib/cbook.py:1762: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/xin_314514066/miniconda/envs/mp/lib/python3.9/site-packages/matplotlib/cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# =========================================
# #在穿透率不為0的頻率(f=1.5)
# =========================================

# %%
#=======================數值計算=======================
import numpy as np
#頻率相關參數
f = 1.5
omega = 2 * np.pi * f
#結構重複次數
num_pairs = 10
#晶體厚度
d_single = [0.2, 0.3]
d_list = []
for i in range(num_pairs):
    for j in range(len(d_single)-1):
        d_list.append(d_single[0])
        d_list.append(d_single[1])
for i in range(num_pairs):
    for j in range(len(d_single)-1):
        d_list.append(d_single[1])
        d_list.append(d_single[0])
d = sum(d_list)
d_pair = sum(d_single)
#材料介電常數
epsi_single = [12, 3]
epsi_list = []
for i in range(num_pairs):
    for j in range(len(epsi_single)-1):
        epsi_list.append(epsi_single[0])
        epsi_list.append(epsi_single[1])
for i in range(num_pairs):
    for j in range(len(epsi_single)-1):
        epsi_list.append(epsi_single[1])
        epsi_list.append(epsi_single[0])
#材料相位差
delta_list = []
for epsi, a in zip(epsi_list, d_list):
    delta = 2 * omega * a * np.sqrt(epsi)
    delta_list.append(delta)
delta_array = np.array(delta_list)
epsi_all = epsi_list.copy()  
epsi_all.insert(0, 1)
epsi_all.append(1)
epsi_all = epsi_list.copy()  
epsi_all.insert(0, 1)
epsi_all.append(1)
#=======================meep模擬=======================
import meep as mp
resolution = 125
dpml = 1.0
sz = (d_pair * 50.0) + (dpml * 2.0)
cell_size = mp.Vector3(z=sz)
pml_layers = [mp.PML(dpml)]
dimensions = 1
#電磁波源(平面波)
sour_z = - (sz / 4) - 0.3 
sources = [mp.Source(src=mp.ContinuousSource(frequency=f),
                     component=mp.Ex,
                     center=mp.Vector3(z=sour_z))
]
#真空
sim_vac = mp.Simulation(cell_size=cell_size,
                        boundary_layers=pml_layers,
                        sources=sources,
                        dimensions=dimensions,
                        resolution=resolution)
#數據偵測(真空場)
tran_z = -(sz / 4) + d + 0.3
tran_vac_fr = mp.FluxRegion(center=mp.Vector3(z = tran_z))
tran_vac = sim_vac.add_flux(f, 0, 1, tran_vac_fr)
#數據模擬(真空場)
sim_vac.run(until=20000)
#紀錄通量(真空場)
T_vac = np.array(mp.get_fluxes(tran_vac))
#結構
geometry = []
z_start = - (sz / 4)
for i in range(len(epsi_list)-1):
    center_z = z_start + (d_list[i] / 2)
    geometry.append(mp.Block(size=mp.Vector3(mp.inf, mp.inf, d_list[i]),
                             center=mp.Vector3(z=center_z),
                             material=mp.Medium(epsilon=epsi_list[i])
                            )
                 )
    z_start += d_list[i]
#整體模擬流程(結構場)
sim_poyn = mp.Simulation(cell_size=cell_size,
                         geometry=geometry,
                         boundary_layers=pml_layers,
                         sources=sources,
                         dimensions=dimensions,
                         resolution=resolution)
#數據偵測(結構場)
tran_z = -(sz / 4) + d + 0.3
tran_fr = mp.FluxRegion(center=mp.Vector3(z = tran_z))
tran = sim_poyn.add_flux(f, 0, 1, tran_fr)
#數據模擬(結構場)
sim_poyn.run(until=20000)
#紀錄通量(真空場)
T_str = np.array(mp.get_fluxes(tran))
T_meep = T_str / T_vac
print("R =",1-T_meep)
print("T =",T_meep)
#電場分布
from matplotlib import pyplot as plt 
z_points = np.linspace(-sz/2, sz/2, int(resolution * sz))
ex_data = []
eps_data = []
for z in z_points:
    ex = sim_poyn.get_field_point(mp.Ex, mp.Vector3(z=z))
    eps = sim_poyn.get_epsilon_point(mp.Vector3(z=z))
    ex_data.append(ex)
    eps_data.append(eps)
ex_data = np.array(ex_data)
eps_data = np.array(eps_data)
#場分布+介電常數分布
fig, ax1 = plt.subplots(1, 1, figsize=(12, 4))
#電場 Ex
ax1.plot(z_points, np.real(ex_data), 'b-', label='Real(Ex)', linewidth=1)
ax1.set_xlabel('z position')
ax1.set_ylabel('Ex field')
ax1.grid(True, alpha=0.3)
#介電常數
ax2 = ax1.twinx()
ax2.plot(z_points, eps_data, 'r-', label='epsilon(z)', linewidth=1, alpha=0.6)
ax2.set_ylabel('epsilon')
#Source 與 Detector 位置
ax1.axvline(sour_z, color='green', linestyle='--', linewidth=1)
ax1.text(sour_z, np.max(np.real(ex_data))*0.8, 'Source', color='green', 
         rotation=90, verticalalignment='center')
ax1.axvline(tran_z, color='purple', linestyle='--', linewidth=1)
ax1.text(tran_z, np.max(np.real(ex_data))*0.8, 'Detector', color='purple',
         rotation=90, verticalalignment='center')
#繪圖
lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='upper right')
ax1.set_title('Electric Field & Dielectric Distribution with Source/Detector')
plt.show()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000115871 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 27 with resolution 125
# time for set_epsilon = 0.000551939 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=20000.0)
# Meep progress: 1143.136/20000.0 = 5.7% done in 4.0s, 66.0s to go
# on time step 285930 (time=1143.72), 1.39895e-05 s/step
# Meep progress: 2280.084/20000.0 = 11.4% done in 8.0s, 62.2s to go
# on time step 570206 (time=2280.82), 1.40708e-05 s/step
# Meep progress: 3425.268/20000.0 = 17.1% done in 12.0s, 58.1s to go
# on time step 856542 (time=3426.17), 1.39696e-05 s/step
# Meep progress: 4573.104/20000.0 = 22.9% done in 16.0s, 54.0s to go
# on time step 1143599 (time=4574.4), 1.39346e-05 s/step
# Meep progress: 5722.1720000000005/20000.0 = 28.6% done in 20.0s, 49.9s to go
# on time step 1430903 (time=5723.61), 1.39226e-05 s/step
# Meep progress: 6871.456/20000.0 = 34.4% done in 24.0s, 45.9s to go
# on time step 1718290 (time=6873.16), 1.39186e-05 s/step
# Meep progress: 8020.26/20000.0 = 40.1% done in 28.0s, 41.8s to go
# on time step 2005534 (time=8022.14), 1.39255e-05 s/step
# Meep progress: 9166.844000000001/20000.0 = 45.8% done in 32.0s, 37.8s to go
# on time step 2292228 (time=9168.91), 1.39522e-05 s/step
# Meep progress: 10313.012/20000.0 = 51.6% done in 36.0s, 33.8s to go
# on time step 2578819 (time=10315.3), 1.39572e-05 s/step
# Meep progress: 11457.896/20000.0 = 57.3% done in 40.0s, 29.8s to go
# on time step 2865088 (time=11460.4), 1.39729e-05 s/step
# Meep progress: 12602.632/20000.0 = 63.0% done in 44.0s, 25.8s to go
# on time step 3151308 (time=12605.2), 1.39753e-05 s/step
# Meep progress: 13746.348/20000.0 = 68.7% done in 48.0s, 21.8s to go
# on time step 3437290 (time=13749.2), 1.39869e-05 s/step
# Meep progress: 14889.568000000001/20000.0 = 74.4% done in 52.0s, 17.8s to go
# on time step 3723133 (time=14892.5), 1.39937e-05 s/step
# Meep progress: 16033.792/20000.0 = 80.2% done in 56.0s, 13.9s to go
# on time step 4009231 (time=16036.9), 1.39813e-05 s/step
# Meep progress: 17169.936/20000.0 = 85.8% done in 60.0s, 9.9s to go
# on time step 4293316 (time=17173.3), 1.40803e-05 s/step
# Meep progress: 18313.748/20000.0 = 91.6% done in 64.0s, 5.9s to go
# on time step 4579142 (time=18316.6), 1.39955e-05 s/step
# Meep progress: 19459.04/20000.0 = 97.3% done in 68.0s, 1.9s to go
# on time step 4865736 (time=19462.9), 1.3957e-05 s/step
# run 0 finished at t = 20000.0 (5000000 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000137806 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 27 with resolution 125
#      block, center = (0,0,-6.65)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-6.15)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-5.65)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.4)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-5.15)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-4.9)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-4.65)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-4.4)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      ...(+ 29 objects not shown)...
# time for set_epsilon = 0.00124311 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=20000.0)
# Meep progress: 1131.3600000000001/20000.0 = 5.7% done in 4.0s, 66.7s to go
# on time step 283006 (time=1132.02), 1.4134e-05 s/step
# Meep progress: 2246.188/20000.0 = 11.2% done in 8.0s, 63.2s to go
# on time step 561754 (time=2247.02), 1.43499e-05 s/step
# Meep progress: 3375.416/20000.0 = 16.9% done in 12.0s, 59.1s to go
# on time step 844100 (time=3376.4), 1.4167e-05 s/step
# Meep progress: 4505.676/20000.0 = 22.5% done in 16.0s, 55.0s to go
# on time step 1126716 (time=4506.86), 1.41535e-05 s/step
# Meep progress: 5635.956/20000.0 = 28.2% done in 20.0s, 51.0s to go
# on time step 1409333 (time=5637.33), 1.41534e-05 s/step
# Meep progress: 6762.696/20000.0 = 33.8% done in 24.0s, 47.0s to go
# on time step 1691053 (time=6764.21), 1.41985e-05 s/step
# Meep progress: 7890.924/20000.0 = 39.5% done in 28.0s, 43.0s to go
# on time step 1973131 (time=7892.52), 1.41805e-05 s/step
# Meep progress: 9004.972/20000.0 = 45.0% done in 32.0s, 39.1s to go
# on time step 2251708 (time=9006.83), 1.43587e-05 s/step
# Meep progress: 10132.48/20000.0 = 50.7% done in 36.0s, 35.1s to go
# on time step 2533622 (time=10134.5), 1.41887e-05 s/step
# Meep progress: 11260.94/20000.0 = 56.3% done in 40.0s, 31.0s to go
# on time step 2815785 (time=11263.1), 1.41762e-05 s/step
# Meep progress: 12388.644/20000.0 = 61.9% done in 44.0s, 27.0s to go
# on time step 3097719 (time=12390.9), 1.41877e-05 s/step
# Meep progress: 13517.32/20000.0 = 67.6% done in 48.0s, 23.0s to go
# on time step 3379962 (time=13519.8), 1.41722e-05 s/step
# Meep progress: 14644.128/20000.0 = 73.2% done in 52.0s, 19.0s to go
# on time step 3661720 (time=14646.9), 1.41966e-05 s/step
# Meep progress: 15765.708/20000.0 = 78.8% done in 56.0s, 15.0s to go
# on time step 3942183 (time=15768.7), 1.42621e-05 s/step
# Meep progress: 16892.956000000002/20000.0 = 84.5% done in 60.0s, 11.0s to go
# on time step 4224036 (time=16896.1), 1.41918e-05 s/step
# Meep progress: 18010.4/20000.0 = 90.1% done in 64.0s, 7.1s to go
# on time step 4503425 (time=18013.7), 1.4317e-05 s/step
# Meep progress: 19138.08/20000.0 = 95.7% done in 68.0s, 3.1s to go
# on time step 4785396 (time=19141.6), 1.41859e-05 s/step
# run 0 finished at t = 20000.0 (5000000 timesteps)
# R = [0.26874166]
# T = [0.73125834]
