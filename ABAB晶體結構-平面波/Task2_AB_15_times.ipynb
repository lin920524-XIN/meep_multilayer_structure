# %% [markdown]
# Layers A and B have the thicknesses  $d_A$ = 200 nm  and  $d_B$ = 300 nm , and the dielectric constants $ϵ_A$ = 12 and $ϵ_B$ = 3. Compute and plot the single-frequency electric field distribution for a structure consisting of 15 repeated AB layers (ABABAB…).

# %% [markdown]
# ### 參數設定

# %%
import numpy as np
#頻率相關參數
f = 1.4
omega = 2 * np.pi * f

# %%
#結構重複次數
num_pairs = 15
#結構厚度
d_single = [0.2, 0.3]
d_list = []
for i in range(num_pairs):
    for j in range(len(d_single)-1):
        d_list.append(d_single[0])
        d_list.append(d_single[1])
d = sum(d_list)
d_pair = sum(d_single)
#材料介電常數
epsi_single = [12, 3]
epsi_list = []
for i in range(num_pairs):
    for j in range(len(epsi_single)-1):
        epsi_list.append(epsi_single[0])
        epsi_list.append(epsi_single[1])

# %%
#材料相位差
delta_list = []
for epsi, a in zip(epsi_list, d_list):
    delta = 2 * omega * a * np.sqrt(epsi)
    delta_list.append(delta)
delta_array = np.array(delta_list)

# %%
epsi_all = epsi_list.copy()  
epsi_all.insert(0, 1)
epsi_all.append(1)

# %% [markdown]
# ### 轉移矩陣數值分析

# %%
#介面反射係數
r_list = []
for i in range(len(epsi_all)-1):
    r = (np.sqrt(epsi_all[i]) - np.sqrt(epsi_all[i+1])) / \
        (np.sqrt(epsi_all[i]) + np.sqrt(epsi_all[i+1]))
    r_list.append(r)
r_array = np.array(r_list)
#介面透射係數
t_list = []
for i in range(len(epsi_all)-1):
    t = 2 * (np.sqrt(epsi_all[i])) / \
        (np.sqrt(epsi_all[i]) + np.sqrt(epsi_all[i+1]))
    t_list.append(t)
t_array = np.array(t_list)

# %%
#介面反透射矩陣
i = 1j
D_list = []
for idx, t in enumerate(t_array):
    r_num = r_array[idx]
    D = (1 / t) * np.array([[1, r_num],
                            [r_num, 1]])
    D_list.append(D)
D_array = np.array(D_list)

# %%
#材料傳遞矩陣
P_list = []
for deltas in delta_array:
    P_11 = np.exp(-i * deltas * 0.5)
    P_22 = np.exp(i * deltas * 0.5)
    P = np.array([[P_11, 0],
                  [0, P_22]])
    P_list.append(P)
P_array = np.array(P_list)

# %%
#轉換矩陣
M_temp = np.eye(2, 2)
for k in range(len(epsi_list)):
    M_temp = M_temp @ np.array(D_array[k])
    M_temp = M_temp @ np.array(P_array[k])
M = M_temp @ np.array(D_array[-1])

# %%
#反射與透射
Er = M[1,0] / M[0,0]
R_tmat = np.abs(Er**2)
T_tmat = 1 - R_tmat
print(T_tmat)
# Out:
# 0.8106748116780713

# %% [markdown]
# ### 散射矩陣數值分析

# %%
detM = M[0,0]*M[1,1] - M[0,1]*M[1,0]
S11 = -M[1,0] / M[1,1]
S21 = detM / M[1,1]
R_smat = np.abs(S11)**2
T_smat = np.abs(S21)**2
print(T_smat)
# Out:
# 0.8106748116780729

# %%
import meep as mp
#模擬空間參數
resolution = 500
dpml = 1.0
sz = (d_pair * 30.0) + (dpml * 2.0)
cell_size = mp.Vector3(z=sz)
pml_layers = [mp.PML(dpml)]
dimensions = 1

# %%
#電磁波源(平面波)
sour_z = - (d / 2) - 0.3 
sources = [mp.Source(src=mp.ContinuousSource(frequency=f),
                     component=mp.Ex,
                     center=mp.Vector3(z=sour_z))
          ]

# %%
#整體模擬流程(真空場)
sim_vac = mp.Simulation(cell_size=cell_size,
                        boundary_layers=pml_layers,
                        sources=sources,
                        dimensions=dimensions,
                        resolution=resolution)
#數據偵測(真空場)
tran_z = (d / 2) + 0.3
tran_vac_fr = mp.FluxRegion(center=mp.Vector3(z = tran_z))
tran_vac = sim_vac.add_flux(f, 0, 1, tran_vac_fr)
#數據模擬(真空場)  
sim_vac.run(until=20000)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000405073 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 17 with resolution 500
# time for set_epsilon = 0.00200295 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=20000.0)
# Meep progress: 192.34300000000002/20000.0 = 1.0% done in 4.0s, 411.9s to go
# on time step 192677 (time=192.677), 2.07602e-05 s/step
# Meep progress: 382.595/20000.0 = 1.9% done in 8.0s, 410.2s to go
# on time step 382909 (time=382.909), 2.1027e-05 s/step
# Meep progress: 624.66/20000.0 = 3.1% done in 12.0s, 372.2s to go
# on time step 625254 (time=625.254), 1.65054e-05 s/step
# Meep progress: 869.595/20000.0 = 4.3% done in 16.0s, 352.0s to go
# on time step 870247 (time=870.247), 1.6327e-05 s/step
# Meep progress: 1114.633/20000.0 = 5.6% done in 20.0s, 338.9s to go
# on time step 1115469 (time=1115.47), 1.63118e-05 s/step
# Meep progress: 1359.743/20000.0 = 6.8% done in 24.0s, 329.0s to go
# on time step 1360621 (time=1360.62), 1.63164e-05 s/step
# Meep progress: 1604.801/20000.0 = 8.0% done in 28.0s, 321.0s to go
# on time step 1605848 (time=1605.85), 1.63115e-05 s/step
# Meep progress: 1849.9460000000001/20000.0 = 9.2% done in 32.0s, 314.0s to go
# on time step 1851066 (time=1851.07), 1.63121e-05 s/step
# Meep progress: 2091.401/20000.0 = 10.5% done in 36.0s, 308.3s to go
# on time step 2092546 (time=2092.55), 1.65646e-05 s/step
# Meep progress: 2335.772/20000.0 = 11.7% done in 40.0s, 302.5s to go
# on time step 2337019 (time=2337.02), 1.63618e-05 s/step
# Meep progress: 2580.346/20000.0 = 12.9% done in 44.0s, 297.0s to go
# on time step 2581752 (time=2581.75), 1.63444e-05 s/step
# Meep progress: 2824.099/20000.0 = 14.1% done in 48.0s, 291.9s to go
# on time step 2825623 (time=2825.62), 1.64022e-05 s/step
# Meep progress: 3067.947/20000.0 = 15.3% done in 52.0s, 287.0s to go
# on time step 3069566 (time=3069.57), 1.63973e-05 s/step
# Meep progress: 3311.64/20000.0 = 16.6% done in 56.0s, 282.2s to go
# on time step 3313368 (time=3313.37), 1.64068e-05 s/step
# Meep progress: 3555.257/20000.0 = 17.8% done in 60.0s, 277.5s to go
# on time step 3557029 (time=3557.03), 1.64163e-05 s/step
# Meep progress: 3798.78/20000.0 = 19.0% done in 64.0s, 273.0s to go
# on time step 3800712 (time=3800.71), 1.64148e-05 s/step
# Meep progress: 3965.056/20000.0 = 19.8% done in 68.0s, 275.0s to go
# on time step 3966314 (time=3966.31), 2.41544e-05 s/step
# Meep progress: 4114.087/20000.0 = 20.6% done in 72.0s, 278.0s to go
# on time step 4115421 (time=4115.42), 2.68265e-05 s/step
# Meep progress: 4336.639/20000.0 = 21.7% done in 76.0s, 274.5s to go
# on time step 4338138 (time=4338.14), 1.79601e-05 s/step
# Meep progress: 4482.271/20000.0 = 22.4% done in 80.0s, 277.0s to go
# on time step 4484623 (time=4484.62), 2.73066e-05 s/step
# Meep progress: 4726.111/20000.0 = 23.6% done in 84.0s, 271.5s to go
# on time step 4728617 (time=4728.62), 1.63939e-05 s/step
# Meep progress: 4941.026/20000.0 = 24.7% done in 88.0s, 268.2s to go
# on time step 4942582 (time=4942.58), 1.86947e-05 s/step
# Meep progress: 5154.26/20000.0 = 25.8% done in 92.0s, 265.0s to go
# on time step 5157050 (time=5157.05), 1.86508e-05 s/step
# Meep progress: 5370.336/20000.0 = 26.9% done in 96.0s, 261.5s to go
# on time step 5372994 (time=5372.99), 1.85234e-05 s/step
# Meep progress: 5613.56/20000.0 = 28.1% done in 100.0s, 256.3s to go
# on time step 5616653 (time=5616.65), 1.64164e-05 s/step
# Meep progress: 5858.425/20000.0 = 29.3% done in 104.0s, 251.0s to go
# on time step 5861522 (time=5861.52), 1.63353e-05 s/step
# Meep progress: 6103.045/20000.0 = 30.5% done in 108.0s, 245.9s to go
# on time step 6106329 (time=6106.33), 1.63395e-05 s/step
# Meep progress: 6347.117/20000.0 = 31.7% done in 112.0s, 240.9s to go
# on time step 6350480 (time=6350.48), 1.63833e-05 s/step
# Meep progress: 6590.935/20000.0 = 33.0% done in 116.0s, 236.0s to go
# on time step 6594317 (time=6594.32), 1.64044e-05 s/step
# Meep progress: 6834.762/20000.0 = 34.2% done in 120.0s, 231.1s to go
# on time step 6838326 (time=6838.33), 1.63929e-05 s/step
# Meep progress: 7078.618/20000.0 = 35.4% done in 124.0s, 226.4s to go
# on time step 7082274 (time=7082.27), 1.63969e-05 s/step
# Meep progress: 7322.465/20000.0 = 36.6% done in 128.0s, 221.6s to go
# on time step 7326160 (time=7326.16), 1.64012e-05 s/step
# Meep progress: 7566.4400000000005/20000.0 = 37.8% done in 132.0s, 216.9s to go
# on time step 7570275 (time=7570.28), 1.63858e-05 s/step
# Meep progress: 7810.259/20000.0 = 39.1% done in 136.0s, 212.3s to go
# on time step 7814208 (time=7814.21), 1.6398e-05 s/step
# Meep progress: 8055.0070000000005/20000.0 = 40.3% done in 140.0s, 207.6s to go
# on time step 8059053 (time=8059.05), 1.6337e-05 s/step
# Meep progress: 8297.295/20000.0 = 41.5% done in 144.0s, 203.1s to go
# on time step 8301292 (time=8301.29), 1.65127e-05 s/step
# Meep progress: 8541.396/20000.0 = 42.7% done in 148.0s, 198.5s to go
# on time step 8545523 (time=8545.52), 1.63779e-05 s/step
# Meep progress: 8785.526/20000.0 = 43.9% done in 152.0s, 194.0s to go
# on time step 8789759 (time=8789.76), 1.63776e-05 s/step
# Meep progress: 9029.697/20000.0 = 45.1% done in 156.0s, 189.5s to go
# on time step 9033898 (time=9033.9), 1.63842e-05 s/step
# Meep progress: 9274.368/20000.0 = 46.4% done in 160.0s, 185.0s to go
# on time step 9278770 (time=9278.77), 1.63351e-05 s/step
# Meep progress: 9519.294/20000.0 = 47.6% done in 164.0s, 180.6s to go
# on time step 9523697 (time=9523.7), 1.63314e-05 s/step
# Meep progress: 9763.67/20000.0 = 48.8% done in 168.0s, 176.1s to go
# on time step 9768217 (time=9768.22), 1.63586e-05 s/step
# Meep progress: 10008.038/20000.0 = 50.0% done in 172.0s, 171.7s to go
# on time step 10012702 (time=10012.7), 1.63609e-05 s/step
# Meep progress: 10227.152/20000.0 = 51.1% done in 176.0s, 168.2s to go
# on time step 10231858 (time=10231.9), 1.82519e-05 s/step
# Meep progress: 10472.002/20000.0 = 52.4% done in 180.0s, 163.8s to go
# on time step 10476776 (time=10476.8), 1.6332e-05 s/step
# Meep progress: 10717.152/20000.0 = 53.6% done in 184.0s, 159.4s to go
# on time step 10721939 (time=10721.9), 1.63157e-05 s/step
# Meep progress: 10962.154/20000.0 = 54.8% done in 188.0s, 155.0s to go
# on time step 10967056 (time=10967.1), 1.63188e-05 s/step
# Meep progress: 11207.314/20000.0 = 56.0% done in 192.0s, 150.6s to go
# on time step 11212306 (time=11212.3), 1.631e-05 s/step
# Meep progress: 11452.653/20000.0 = 57.3% done in 196.0s, 146.3s to go
# on time step 11457726 (time=11457.7), 1.62986e-05 s/step
# Meep progress: 11698.051/20000.0 = 58.5% done in 200.0s, 141.9s to go
# on time step 11703190 (time=11703.2), 1.62957e-05 s/step
# Meep progress: 11943.263/20000.0 = 59.7% done in 204.0s, 137.6s to go
# on time step 11948478 (time=11948.5), 1.63074e-05 s/step
# Meep progress: 12188.395/20000.0 = 60.9% done in 208.0s, 133.3s to go
# on time step 12193671 (time=12193.7), 1.63137e-05 s/step
# Meep progress: 12433.516/20000.0 = 62.2% done in 212.0s, 129.0s to go
# on time step 12438796 (time=12438.8), 1.63182e-05 s/step
# Meep progress: 12678.276/20000.0 = 63.4% done in 216.0s, 124.7s to go
# on time step 12683603 (time=12683.6), 1.63394e-05 s/step
# Meep progress: 12922.938/20000.0 = 64.6% done in 220.0s, 120.5s to go
# on time step 12928417 (time=12928.4), 1.6339e-05 s/step
# Meep progress: 13168.018/20000.0 = 65.8% done in 224.0s, 116.2s to go
# on time step 13173592 (time=13173.6), 1.63149e-05 s/step
# Meep progress: 13412.694/20000.0 = 67.1% done in 228.0s, 112.0s to go
# on time step 13418339 (time=13418.3), 1.63435e-05 s/step
# Meep progress: 13657.942000000001/20000.0 = 68.3% done in 232.0s, 107.7s to go
# on time step 13663662 (time=13663.7), 1.63051e-05 s/step
# Meep progress: 13903.161/20000.0 = 69.5% done in 236.0s, 103.5s to go
# on time step 13908932 (time=13908.9), 1.63086e-05 s/step
# Meep progress: 14148.2/20000.0 = 70.7% done in 240.0s, 99.3s to go
# on time step 14154048 (time=14154), 1.63188e-05 s/step
# Meep progress: 14393.356/20000.0 = 72.0% done in 244.0s, 95.0s to go
# on time step 14399207 (time=14399.2), 1.6316e-05 s/step
# Meep progress: 14638.163/20000.0 = 73.2% done in 248.0s, 90.8s to go
# on time step 14644139 (time=14644.1), 1.63311e-05 s/step
# Meep progress: 14883.305/20000.0 = 74.4% done in 252.0s, 86.6s to go
# on time step 14889368 (time=14889.4), 1.63113e-05 s/step
# Meep progress: 15128.428/20000.0 = 75.6% done in 256.0s, 82.4s to go
# on time step 15134550 (time=15134.6), 1.63144e-05 s/step
# Meep progress: 15373.436/20000.0 = 76.9% done in 260.0s, 78.2s to go
# on time step 15379637 (time=15379.6), 1.63208e-05 s/step
# Meep progress: 15618.666000000001/20000.0 = 78.1% done in 264.0s, 74.1s to go
# on time step 15624930 (time=15624.9), 1.6307e-05 s/step
# Meep progress: 15863.786/20000.0 = 79.3% done in 268.0s, 69.9s to go
# on time step 15870121 (time=15870.1), 1.63139e-05 s/step
# Meep progress: 16108.594000000001/20000.0 = 80.5% done in 272.0s, 65.7s to go
# on time step 16114996 (time=16115), 1.63349e-05 s/step
# Meep progress: 16353.707/20000.0 = 81.8% done in 276.0s, 61.5s to go
# on time step 16360055 (time=16360.1), 1.63226e-05 s/step
# Meep progress: 16598.385000000002/20000.0 = 83.0% done in 280.0s, 57.4s to go
# on time step 16604944 (time=16604.9), 1.6334e-05 s/step
# Meep progress: 16843.659/20000.0 = 84.2% done in 284.0s, 53.2s to go
# on time step 16850205 (time=16850.2), 1.63092e-05 s/step
# Meep progress: 17088.746/20000.0 = 85.4% done in 288.0s, 49.1s to go
# on time step 17095417 (time=17095.4), 1.63125e-05 s/step
# Meep progress: 17334.102/20000.0 = 86.7% done in 292.0s, 44.9s to go
# on time step 17340871 (time=17340.9), 1.62964e-05 s/step
# Meep progress: 17579.266/20000.0 = 87.9% done in 296.0s, 40.8s to go
# on time step 17586103 (time=17586.1), 1.63111e-05 s/step
# Meep progress: 17824.352/20000.0 = 89.1% done in 300.0s, 36.6s to go
# on time step 17831254 (time=17831.3), 1.63165e-05 s/step
# Meep progress: 18069.516/20000.0 = 90.3% done in 304.0s, 32.5s to go
# on time step 18076498 (time=18076.5), 1.63103e-05 s/step
# Meep progress: 18314.577/20000.0 = 91.6% done in 308.0s, 28.3s to go
# on time step 18321599 (time=18321.6), 1.63198e-05 s/step
# Meep progress: 18559.698/20000.0 = 92.8% done in 312.0s, 24.2s to go
# on time step 18566823 (time=18566.8), 1.63117e-05 s/step
# Meep progress: 18804.682/20000.0 = 94.0% done in 316.0s, 20.1s to go
# on time step 18811874 (time=18811.9), 1.63231e-05 s/step
# Meep progress: 19049.783/20000.0 = 95.2% done in 320.0s, 16.0s to go
# on time step 19057044 (time=19057), 1.63152e-05 s/step
# Meep progress: 19284.646/20000.0 = 96.4% done in 324.0s, 12.0s to go
# on time step 19291963 (time=19292), 1.70272e-05 s/step
# Meep progress: 19529.182/20000.0 = 97.6% done in 328.0s, 7.9s to go
# on time step 19536574 (time=19536.6), 1.63525e-05 s/step
# Meep progress: 19774.243000000002/20000.0 = 98.9% done in 332.0s, 3.8s to go
# on time step 19781637 (time=19781.6), 1.63223e-05 s/step
# run 0 finished at t = 20000.0 (20000000 timesteps)

# %%
#紀錄通量(真空場)
T_vac = np.array(mp.get_fluxes(tran_vac))

# %%
#晶體(結構場)
geometry = []
z_start = - (d / 2)
for i in range(len(epsi_list)):
    center_z = z_start + (d_list[i] / 2)
    geometry.append(mp.Block(size=mp.Vector3(mp.inf, mp.inf, d_list[i]),
                             center=mp.Vector3(z=center_z),
                             material=mp.Medium(epsilon=epsi_list[i])
                            )
                 )
    z_start += d_list[i]

# %%
#整體模擬流程(結構場)
sim_poyn = mp.Simulation(cell_size=cell_size,
                         geometry=geometry,
                         boundary_layers=pml_layers,
                         sources=sources,
                         dimensions=dimensions,
                         resolution=resolution)
#數據偵測(結構場)
tran_z = (d / 2) + 0.3
tran_fr = mp.FluxRegion(center=mp.Vector3(z = tran_z))
tran = sim_poyn.add_flux(f, 0, 1, tran_fr)
#數據模擬(結構場)  
sim_poyn.run(until=20000)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000277996 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 17 with resolution 500
#      block, center = (0,0,-3.65)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-3.4)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-3.15)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-2.9)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-2.65)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-2.4)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-2.15)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-1.9)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-1.65)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-1.4)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      ...(+ 20 objects not shown)...
# time for set_epsilon = 0.00253606 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=20000.0)
# Meep progress: 237.622/20000.0 = 1.2% done in 4.0s, 332.7s to go
# on time step 237904 (time=237.904), 1.68135e-05 s/step
# Meep progress: 475.248/20000.0 = 2.4% done in 8.0s, 328.7s to go
# on time step 475602 (time=475.602), 1.68281e-05 s/step
# Meep progress: 713.299/20000.0 = 3.6% done in 12.0s, 324.5s to go
# on time step 713742 (time=713.742), 1.67969e-05 s/step
# Meep progress: 950.962/20000.0 = 4.8% done in 16.0s, 320.5s to go
# on time step 951494 (time=951.494), 1.68243e-05 s/step
# Meep progress: 1188.978/20000.0 = 5.9% done in 20.0s, 316.4s to go
# on time step 1189605 (time=1189.61), 1.6799e-05 s/step
# Meep progress: 1426.659/20000.0 = 7.1% done in 24.0s, 312.5s to go
# on time step 1427390 (time=1427.39), 1.68219e-05 s/step
# Meep progress: 1665.345/20000.0 = 8.3% done in 28.0s, 308.3s to go
# on time step 1666164 (time=1666.16), 1.67523e-05 s/step
# Meep progress: 1903.864/20000.0 = 9.5% done in 32.0s, 304.2s to go
# on time step 1904775 (time=1904.78), 1.67637e-05 s/step
# Meep progress: 2142.1040000000003/20000.0 = 10.7% done in 36.0s, 300.1s to go
# on time step 2143093 (time=2143.09), 1.67843e-05 s/step
# Meep progress: 2379.86/20000.0 = 11.9% done in 40.0s, 296.2s to go
# on time step 2380925 (time=2380.93), 1.68186e-05 s/step
# Meep progress: 2615.576/20000.0 = 13.1% done in 44.0s, 292.4s to go
# on time step 2616741 (time=2616.74), 1.69624e-05 s/step
# Meep progress: 2853.623/20000.0 = 14.3% done in 48.0s, 288.4s to go
# on time step 2854911 (time=2854.91), 1.67948e-05 s/step
# Meep progress: 3091.736/20000.0 = 15.5% done in 52.0s, 284.4s to go
# on time step 3093076 (time=3093.08), 1.67951e-05 s/step
# Meep progress: 3329.7110000000002/20000.0 = 16.6% done in 56.0s, 280.4s to go
# on time step 3331169 (time=3331.17), 1.68002e-05 s/step
# Meep progress: 3567.957/20000.0 = 17.8% done in 60.0s, 276.3s to go
# on time step 3569530 (time=3569.53), 1.67813e-05 s/step
# Meep progress: 3805.79/20000.0 = 19.0% done in 64.0s, 272.3s to go
# on time step 3807456 (time=3807.46), 1.6812e-05 s/step
# Meep progress: 4043.983/20000.0 = 20.2% done in 68.0s, 268.3s to go
# on time step 4045732 (time=4045.73), 1.67873e-05 s/step
# Meep progress: 4282.419/20000.0 = 21.4% done in 72.0s, 264.3s to go
# on time step 4284256 (time=4284.26), 1.67699e-05 s/step
# Meep progress: 4520.537/20000.0 = 22.6% done in 76.0s, 260.2s to go
# on time step 4522463 (time=4522.46), 1.67921e-05 s/step
# Meep progress: 4759.216/20000.0 = 23.8% done in 80.0s, 256.2s to go
# on time step 4761226 (time=4761.23), 1.67531e-05 s/step
# Meep progress: 4997.3730000000005/20000.0 = 25.0% done in 84.0s, 252.2s to go
# on time step 4999472 (time=4999.47), 1.67894e-05 s/step
# Meep progress: 5235.664/20000.0 = 26.2% done in 88.0s, 248.2s to go
# on time step 5237843 (time=5237.84), 1.67806e-05 s/step
# Meep progress: 5474.447/20000.0 = 27.4% done in 92.0s, 244.1s to go
# on time step 5476713 (time=5476.71), 1.67456e-05 s/step
# Meep progress: 5712.711/20000.0 = 28.6% done in 96.0s, 240.1s to go
# on time step 5715069 (time=5715.07), 1.67817e-05 s/step
# Meep progress: 5951.119/20000.0 = 29.8% done in 100.0s, 236.1s to go
# on time step 5953555 (time=5953.56), 1.67725e-05 s/step
# Meep progress: 6189.475/20000.0 = 30.9% done in 104.0s, 232.1s to go
# on time step 6191992 (time=6191.99), 1.6776e-05 s/step
# Meep progress: 6427.4890000000005/20000.0 = 32.1% done in 108.0s, 228.1s to go
# on time step 6430093 (time=6430.09), 1.67997e-05 s/step
# Meep progress: 6665.669/20000.0 = 33.3% done in 112.0s, 224.1s to go
# on time step 6668348 (time=6668.35), 1.67888e-05 s/step
# Meep progress: 6904.0960000000005/20000.0 = 34.5% done in 116.0s, 220.0s to go
# on time step 6906810 (time=6906.81), 1.67742e-05 s/step
# Meep progress: 7142.117/20000.0 = 35.7% done in 120.0s, 216.0s to go
# on time step 7144983 (time=7144.98), 1.67946e-05 s/step
# Meep progress: 7380.279/20000.0 = 36.9% done in 124.0s, 212.0s to go
# on time step 7383228 (time=7383.23), 1.67895e-05 s/step
# Meep progress: 7618.51/20000.0 = 38.1% done in 128.0s, 208.0s to go
# on time step 7621523 (time=7621.52), 1.6786e-05 s/step
# Meep progress: 7856.459/20000.0 = 39.3% done in 132.0s, 204.0s to go
# on time step 7859577 (time=7859.58), 1.6803e-05 s/step
# Meep progress: 8094.816/20000.0 = 40.5% done in 136.0s, 200.0s to go
# on time step 8098016 (time=8098.02), 1.67758e-05 s/step
# Meep progress: 8333.237000000001/20000.0 = 41.7% done in 140.0s, 196.0s to go
# on time step 8336516 (time=8336.52), 1.67715e-05 s/step
# Meep progress: 8571.66/20000.0 = 42.9% done in 144.0s, 192.0s to go
# on time step 8575016 (time=8575.02), 1.67716e-05 s/step
# Meep progress: 8809.799/20000.0 = 44.0% done in 148.0s, 188.0s to go
# on time step 8813233 (time=8813.23), 1.67915e-05 s/step
# Meep progress: 9047.875/20000.0 = 45.2% done in 152.0s, 184.0s to go
# on time step 9051401 (time=9051.4), 1.67949e-05 s/step
# Meep progress: 9285.943/20000.0 = 46.4% done in 156.0s, 180.0s to go
# on time step 9289549 (time=9289.55), 1.67963e-05 s/step
# Meep progress: 9524.493/20000.0 = 47.6% done in 160.0s, 176.0s to go
# on time step 9528175 (time=9528.18), 1.67627e-05 s/step
# Meep progress: 9762.791000000001/20000.0 = 48.8% done in 164.0s, 172.0s to go
# on time step 9766549 (time=9766.55), 1.67804e-05 s/step
# Meep progress: 10001.029/20000.0 = 50.0% done in 168.0s, 168.0s to go
# on time step 10004855 (time=10004.9), 1.67852e-05 s/step
# Meep progress: 10239.641/20000.0 = 51.2% done in 172.0s, 163.9s to go
# on time step 10243554 (time=10243.6), 1.67575e-05 s/step
# Meep progress: 10477.825/20000.0 = 52.4% done in 176.0s, 159.9s to go
# on time step 10481824 (time=10481.8), 1.67877e-05 s/step
# Meep progress: 10716.315/20000.0 = 53.6% done in 180.0s, 155.9s to go
# on time step 10720391 (time=10720.4), 1.67668e-05 s/step
# Meep progress: 10954.566/20000.0 = 54.8% done in 184.0s, 151.9s to go
# on time step 10958721 (time=10958.7), 1.67835e-05 s/step
# Meep progress: 11192.72/20000.0 = 56.0% done in 188.0s, 147.9s to go
# on time step 11196957 (time=11197), 1.67901e-05 s/step
# Meep progress: 11431.032000000001/20000.0 = 57.2% done in 192.0s, 143.9s to go
# on time step 11435349 (time=11435.3), 1.67791e-05 s/step
# Meep progress: 11669.599/20000.0 = 58.3% done in 196.0s, 139.9s to go
# on time step 11673988 (time=11674), 1.67617e-05 s/step
# Meep progress: 11907.847/20000.0 = 59.5% done in 200.0s, 135.9s to go
# on time step 11912296 (time=11912.3), 1.6785e-05 s/step
# Meep progress: 12146.054/20000.0 = 60.7% done in 204.0s, 131.9s to go
# on time step 12150598 (time=12150.6), 1.67854e-05 s/step
# Meep progress: 12384.244/20000.0 = 61.9% done in 208.0s, 127.9s to go
# on time step 12388807 (time=12388.8), 1.6792e-05 s/step
# Meep progress: 12622.535/20000.0 = 63.1% done in 212.0s, 123.9s to go
# on time step 12627191 (time=12627.2), 1.67797e-05 s/step
# Meep progress: 12860.737000000001/20000.0 = 64.3% done in 216.0s, 119.9s to go
# on time step 12865457 (time=12865.5), 1.6788e-05 s/step
# Meep progress: 13098.871000000001/20000.0 = 65.5% done in 220.0s, 115.9s to go
# on time step 13103665 (time=13103.7), 1.67921e-05 s/step
# Meep progress: 13336.914/20000.0 = 66.7% done in 224.0s, 111.9s to go
# on time step 13341764 (time=13341.8), 1.67998e-05 s/step
# Meep progress: 13575.403/20000.0 = 67.9% done in 228.0s, 107.9s to go
# on time step 13580328 (time=13580.3), 1.67671e-05 s/step
# Meep progress: 13813.913/20000.0 = 69.1% done in 232.0s, 103.9s to go
# on time step 13818910 (time=13818.9), 1.67658e-05 s/step
# Meep progress: 14052.156/20000.0 = 70.3% done in 236.0s, 99.9s to go
# on time step 14057208 (time=14057.2), 1.67857e-05 s/step
# Meep progress: 14290.235/20000.0 = 71.5% done in 240.0s, 95.9s to go
# on time step 14295366 (time=14295.4), 1.67956e-05 s/step
# Meep progress: 14528.418/20000.0 = 72.6% done in 244.0s, 91.9s to go
# on time step 14533606 (time=14533.6), 1.67899e-05 s/step
# Meep progress: 14766.185/20000.0 = 73.8% done in 248.0s, 87.9s to go
# on time step 14771442 (time=14771.4), 1.68184e-05 s/step
# Meep progress: 15004.311/20000.0 = 75.0% done in 252.0s, 83.9s to go
# on time step 15009639 (time=15009.6), 1.67928e-05 s/step
# Meep progress: 15242.631000000001/20000.0 = 76.2% done in 256.0s, 79.9s to go
# on time step 15248019 (time=15248), 1.67799e-05 s/step
# Meep progress: 15481.058/20000.0 = 77.4% done in 260.0s, 75.9s to go
# on time step 15486520 (time=15486.5), 1.67715e-05 s/step
# Meep progress: 15719.315/20000.0 = 78.6% done in 264.0s, 71.9s to go
# on time step 15724843 (time=15724.8), 1.6784e-05 s/step
# Meep progress: 15956.947/20000.0 = 79.8% done in 268.0s, 67.9s to go
# on time step 15962543 (time=15962.5), 1.6828e-05 s/step
# Meep progress: 16194.995/20000.0 = 81.0% done in 272.0s, 63.9s to go
# on time step 16200659 (time=16200.7), 1.67985e-05 s/step
# Meep progress: 16433.274/20000.0 = 82.2% done in 276.0s, 59.9s to go
# on time step 16439014 (time=16439), 1.67818e-05 s/step
# Meep progress: 16671.414/20000.0 = 83.4% done in 280.0s, 55.9s to go
# on time step 16677215 (time=16677.2), 1.67926e-05 s/step
# Meep progress: 16909.981/20000.0 = 84.5% done in 284.0s, 51.9s to go
# on time step 16915865 (time=16915.9), 1.6761e-05 s/step
# Meep progress: 17148.632/20000.0 = 85.7% done in 288.0s, 47.9s to go
# on time step 17154575 (time=17154.6), 1.67568e-05 s/step
# Meep progress: 17387.062/20000.0 = 86.9% done in 292.0s, 43.9s to go
# on time step 17393076 (time=17393.1), 1.67715e-05 s/step
# Meep progress: 17625.542/20000.0 = 88.1% done in 296.0s, 39.9s to go
# on time step 17631541 (time=17631.5), 1.6774e-05 s/step
# Meep progress: 17863.639/20000.0 = 89.3% done in 300.0s, 35.9s to go
# on time step 17869768 (time=17869.8), 1.67907e-05 s/step
# Meep progress: 18102.122/20000.0 = 90.5% done in 304.0s, 31.9s to go
# on time step 18108331 (time=18108.3), 1.67671e-05 s/step
# Meep progress: 18340.595/20000.0 = 91.7% done in 308.0s, 27.9s to go
# on time step 18346851 (time=18346.9), 1.67701e-05 s/step
# Meep progress: 18578.79/20000.0 = 92.9% done in 312.0s, 23.9s to go
# on time step 18585140 (time=18585.1), 1.67864e-05 s/step
# Meep progress: 18817.169/20000.0 = 94.1% done in 316.0s, 19.9s to go
# on time step 18823589 (time=18823.6), 1.67751e-05 s/step
# Meep progress: 19055.306/20000.0 = 95.3% done in 320.0s, 15.9s to go
# on time step 19061787 (time=19061.8), 1.67928e-05 s/step
# Meep progress: 19293.864/20000.0 = 96.5% done in 324.0s, 11.9s to go
# on time step 19300411 (time=19300.4), 1.67628e-05 s/step
# Meep progress: 19532.153000000002/20000.0 = 97.7% done in 328.0s, 7.9s to go
# on time step 19538793 (time=19538.8), 1.67798e-05 s/step
# Meep progress: 19770.453/20000.0 = 98.9% done in 332.0s, 3.9s to go
# on time step 19777127 (time=19777.1), 1.67832e-05 s/step
# run 0 finished at t = 20000.0 (20000000 timesteps)

# %%
#紀錄通量(真空場)
T_str = np.array(mp.get_fluxes(tran))
T_meep = T_str / T_vac
print(T_meep)
# Out:
# [0.81407745]

# %%
#電場分布
from matplotlib import pyplot as plt 
z_points = np.linspace(-sz/2, sz/2, int(resolution * sz))
ex_data = []
eps_data = []
for z in z_points:
    ex = sim_poyn.get_field_point(mp.Ex, mp.Vector3(z=z))
    eps = sim_poyn.get_epsilon_point(mp.Vector3(z=z))
    ex_data.append(ex)
    eps_data.append(eps)
ex_data = np.array(ex_data)
eps_data = np.array(eps_data)
#場分布+介電常數分布
fig, ax1 = plt.subplots(1, 1, figsize=(12, 4))
#電場 Ex
ax1.plot(z_points, np.real(ex_data), 'b-', label='Real(Ex)', linewidth=1)
ax1.set_xlabel('z position')
ax1.set_ylabel('Ex field')
ax1.grid(True, alpha=0.3)
#介電常數
ax2 = ax1.twinx()
ax2.plot(z_points, eps_data, 'r-', label='epsilon(z)', linewidth=1, alpha=0.6)
ax2.set_ylabel('epsilon')
#Source 與 Detector 位置
ax1.axvline(sour_z, color='green', linestyle='--', linewidth=1)
ax1.text(sour_z, np.max(np.real(ex_data))*0.8, 'Source', color='green', 
         rotation=90, verticalalignment='center')
ax1.axvline(tran_z, color='purple', linestyle='--', linewidth=1)
ax1.text(tran_z, np.max(np.real(ex_data))*0.8, 'Detector', color='purple',
         rotation=90, verticalalignment='center')
#繪圖
lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='upper right')
ax1.set_title('Electric Field & Dielectric Distribution with Source/Detector')
plt.show()
# Out:
# /home/xin_314514066/miniconda/envs/mp/lib/python3.9/site-packages/matplotlib/cbook.py:1762: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/xin_314514066/miniconda/envs/mp/lib/python3.9/site-packages/matplotlib/cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
