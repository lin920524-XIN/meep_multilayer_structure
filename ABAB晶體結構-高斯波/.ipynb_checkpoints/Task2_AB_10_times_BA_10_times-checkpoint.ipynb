# %% [markdown]
# Layers A and B have the thicknesses  $d_A$ = 200 nm  and  $d_B$ = 300 nm , and the dielectric constants $ϵ_A$ = 12 and $ϵ_B$ = 3. Compute and plot T vs ω for a structure of 15 repeated AB, i.e., ABABABAB....(300 < ω < 600 THz)

# %% [markdown]
# 矩陣數值分析

# %%
import numpy as np
#頻率相關參數
Nf = 500
fmin = 1
fmax = 2
fre = np.linspace(fmin, fmax, Nf)
fcen = (fmin+fmax)/2
df = (fmax-fmin)
omega = 2 * np.pi * fre

# %%
#結構重複次數
num_pairs = 15
#etalon厚度
d_single = [0.2, 0.3]
d_list = []
for i in range(num_pairs):
    for j in range(len(d_single)-1):
        d_list.append(d_single[0])
        d_list.append(d_single[1])
d = sum(d_list)
#材料介電常數
epsi_single = [12, 3]
epsi_list = []
for i in range(num_pairs):
    for j in range(len(epsi_single)-1):
        epsi_list.append(epsi_single[0])
        epsi_list.append(epsi_single[1])

# %%
#材料相位差
delta_list = []
for o in omega:
    delta_each_o = []
    for epsi, d in zip(epsi_list, d_list):
        delta = 2 * o * d * np.sqrt(epsi)
        delta_each_o.append(delta)
    delta_list.append(delta_each_o)
delta_array = np.array(delta_list)

# %%
epsi_all = epsi_list.copy()  
epsi_all.insert(0, 1)
epsi_all.append(1)
#介面反射係數
r_array = np.array([])
for i in range(len(epsi_all)-1):
    r = (np.sqrt(epsi_all[i]) - np.sqrt(epsi_all[i+1])) / \
        (np.sqrt(epsi_all[i]) + np.sqrt(epsi_all[i+1]))
    r_array = np.append(r_array,r)
#介面透射係數
t_array = np.array([])
for i in range(len(epsi_all)-1):
    t = 2 * (np.sqrt(epsi_all[i])) / \
        (np.sqrt(epsi_all[i]) + np.sqrt(epsi_all[i+1]))
    t_array = np.append(t_array,t)

# %%
#介面反透射矩陣
i = 1j
D_list = []
for idx, t in enumerate(t_array):
    r_num = r_array[idx]
    D = (1 / t) * np.array([[1, r_num],
                            [r_num, 1]])
    D_list.append(D)
D_array = np.array(D_list)

# %%
#材料傳遞矩陣
P_list = []
for deltas in delta_array:
    P_temp = []
    for delta in deltas:
        P_11 = np.exp(-i * delta * 0.5)
        P_22 = np.exp(i * delta * 0.5)
        P = np.array([[P_11, 0],
                      [0, P_22]])
        P_temp.append(P)
    P_list.append(P_temp)
P_array = np.array(P_list)

# %%
#轉換矩陣
M_end_per_freq = np.zeros((Nf, 2, 2), dtype=complex)
for idx in range(Nf):
    P_array_per_freq = P_array[idx]
    M_temp = np.array(D_array[0])
    for k in range(len(epsi_list)):
        M_temp = M_temp @ np.array(P_array_per_freq[k])
        M_temp = M_temp @ np.array(D_array[k+1])
    M_end_per_freq[idx] = M_temp

# %% [markdown]
# Transfer Matrix

# %%
#反射與透射
R_array = np.array([])
T_array = np.array([])
for i in range(len(fre)):
    Er = M_end_per_freq[i,0,1] / M_end_per_freq[i,0,0]
    R = np.abs(Er**2)
    T = 1 - R
    R_array = np.append(R_array,R)
    T_array = np.append(T_array,T)
T_tmat = T_array.tolist()

# %% [markdown]
# S-matrix

# %%
R_smat = []
T_smat = []
for M in M_end_per_freq:
    M11, M12, M21, M22 = M[0,0], M[0,1], M[1,0], M[1,1]
    detM = M11*M22 - M12*M21
    # M -> S
    S11 = -M21 / M22
    S21 = detM / M22
    r = S11
    t = S21
    R_smat.append(np.abs(r)**2)
    T_smat.append(np.abs(t)**2)
R_smat = np.array(R_smat)
T_smat = np.array(T_smat)

# %% [markdown]
# meep模擬

# %%
import meep as mp
#模擬空間參數
resolution = 500
dpml = 1.0
sz = (d * 50.0) + (dpml * 2.0)
cell_size = mp.Vector3(z=sz)
pml_layers = [mp.PML(dpml)]
dimensions = 1

# %%
#電磁波源(高斯)
sour_z = - (d / 2) - 0.3 
sources = [mp.Source(mp.GaussianSource(fcen,fwidth=df), component=mp.Ex, 
                     center=mp.Vector3(z=sour_z))]

# %%
#整體模擬流程(真空場)
sim_vac = mp.Simulation(cell_size=cell_size,
                        boundary_layers=pml_layers,
                        sources=sources,
                        dimensions=dimensions,
                        resolution=resolution)
#數據偵測(真空場)
tran_z = (d / 2) + 0.3
tran_vac_fr = mp.FluxRegion(center=mp.Vector3(z = tran_z))
tran_vac = sim_vac.add_flux(fcen, df, Nf, tran_vac_fr)
#數據模擬(真空場)  
sim_vac.run(until_after_sources=mp.stop_after_walltime(300))
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000441074 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 17 with resolution 500
# time for set_epsilon = 0.0019269 s
# -----------
# on time step 158165 (time=158.165), 2.52902e-05 s/step
# on time step 375454 (time=375.454), 1.84087e-05 s/step
# on time step 633340 (time=633.34), 1.55107e-05 s/step
# on time step 891469 (time=891.469), 1.54962e-05 s/step
# on time step 1150111 (time=1150.11), 1.54654e-05 s/step
# on time step 1407751 (time=1407.75), 1.55256e-05 s/step
# on time step 1666201 (time=1666.2), 1.54769e-05 s/step
# on time step 1922991 (time=1922.99), 1.55769e-05 s/step
# on time step 2181128 (time=2181.13), 1.54957e-05 s/step
# on time step 2439634 (time=2439.63), 1.54736e-05 s/step
# on time step 2697980 (time=2697.98), 1.54831e-05 s/step
# on time step 2955848 (time=2955.85), 1.55118e-05 s/step
# on time step 3213625 (time=3213.62), 1.55173e-05 s/step
# on time step 3470135 (time=3470.14), 1.55939e-05 s/step
# on time step 3724921 (time=3724.92), 1.56995e-05 s/step
# on time step 3983868 (time=3983.87), 1.54472e-05 s/step
# on time step 4241189 (time=4241.19), 1.55448e-05 s/step
# on time step 4496610 (time=4496.61), 1.56605e-05 s/step
# on time step 4752471 (time=4752.47), 1.56335e-05 s/step
# on time step 5007985 (time=5007.98), 1.56548e-05 s/step
# on time step 5261612 (time=5261.61), 1.57712e-05 s/step
# on time step 5515437 (time=5515.44), 1.57589e-05 s/step
# on time step 5770009 (time=5770.01), 1.57127e-05 s/step
# on time step 6025452 (time=6025.45), 1.56591e-05 s/step
# on time step 6280289 (time=6280.29), 1.56964e-05 s/step
# on time step 6535791 (time=6535.79), 1.56555e-05 s/step
# on time step 6792561 (time=6792.56), 1.55782e-05 s/step
# on time step 7050524 (time=7050.52), 1.55061e-05 s/step
# on time step 7309224 (time=7309.22), 1.54619e-05 s/step
# on time step 7567483 (time=7567.48), 1.54884e-05 s/step
# on time step 7823951 (time=7823.95), 1.55965e-05 s/step
# on time step 8081819 (time=8081.82), 1.55118e-05 s/step
# on time step 8340839 (time=8340.84), 1.54429e-05 s/step
# on time step 8598215 (time=8598.22), 1.55415e-05 s/step
# on time step 8854740 (time=8854.74), 1.55931e-05 s/step
# on time step 9113261 (time=9113.26), 1.54727e-05 s/step
# on time step 9371681 (time=9371.68), 1.54787e-05 s/step
# on time step 9630205 (time=9630.2), 1.54725e-05 s/step
# on time step 9886674 (time=9886.67), 1.55965e-05 s/step
# on time step 10143692 (time=10143.7), 1.55631e-05 s/step
# on time step 10402109 (time=10402.1), 1.54789e-05 s/step
# on time step 10660176 (time=10660.2), 1.54999e-05 s/step
# on time step 10918793 (time=10918.8), 1.54669e-05 s/step
# on time step 11175887 (time=11175.9), 1.55585e-05 s/step
# on time step 11432704 (time=11432.7), 1.55754e-05 s/step
# on time step 11691256 (time=11691.3), 1.54708e-05 s/step
# on time step 11949939 (time=11949.9), 1.5463e-05 s/step
# on time step 12205039 (time=12205), 1.56801e-05 s/step
# on time step 12463652 (time=12463.7), 1.54672e-05 s/step
# on time step 12719304 (time=12719.3), 1.56463e-05 s/step
# on time step 12972555 (time=12972.6), 1.57947e-05 s/step
# on time step 13231385 (time=13231.4), 1.54542e-05 s/step
# on time step 13486902 (time=13486.9), 1.56546e-05 s/step
# on time step 13745359 (time=13745.4), 1.54765e-05 s/step
# on time step 14003629 (time=14003.6), 1.54877e-05 s/step
# on time step 14262282 (time=14262.3), 1.54648e-05 s/step
# on time step 14520695 (time=14520.7), 1.54792e-05 s/step
# on time step 14777461 (time=14777.5), 1.55784e-05 s/step
# on time step 15032780 (time=15032.8), 1.56667e-05 s/step
# on time step 15291390 (time=15291.4), 1.54673e-05 s/step
# on time step 15550408 (time=15550.4), 1.5443e-05 s/step
# on time step 15807090 (time=15807.1), 1.55835e-05 s/step
# on time step 16065879 (time=16065.9), 1.54567e-05 s/step
# on time step 16324707 (time=16324.7), 1.54543e-05 s/step
# on time step 16581431 (time=16581.4), 1.55809e-05 s/step
# on time step 16839757 (time=16839.8), 1.54843e-05 s/step
# on time step 17098631 (time=17098.6), 1.54516e-05 s/step
# on time step 17355391 (time=17355.4), 1.55788e-05 s/step
# on time step 17614028 (time=17614), 1.54657e-05 s/step
# on time step 17870726 (time=17870.7), 1.55825e-05 s/step
# on time step 18127633 (time=18127.6), 1.55698e-05 s/step
# on time step 18386119 (time=18386.1), 1.54748e-05 s/step
# on time step 18642676 (time=18642.7), 1.55911e-05 s/step
# on time step 18900674 (time=18900.7), 1.5504e-05 s/step
# run 0 finished at t = 19149.542 (19149542 timesteps)

# %%
#紀錄通量(真空場)
T_vac = np.array(mp.get_fluxes(tran_vac))

# %%
#晶體(結構場)
geometry = []
z_start = - (d / 2)
for i in range(num_pairs * 2):
    center_z = z_start + (d_list[i] / 2)
    geometry.append(mp.Block(size=mp.Vector3(mp.inf, mp.inf, d_list[i]),
                             center=mp.Vector3(z=center_z),
                             material=mp.Medium(epsilon=epsi_list[i])
                            )
                 )
    z_start += d_list[i]

# %%
#整體模擬流程(結構場)
sim_poyn = mp.Simulation(cell_size=cell_size,
                         geometry=geometry,
                         boundary_layers=pml_layers,
                         sources=sources,
                         dimensions=dimensions,
                         resolution=resolution)
#數據偵測(結構場)
tran_z = (d / 2) + 0.3
tran_fr = mp.FluxRegion(center=mp.Vector3(z = tran_z))
tran = sim_poyn.add_flux(fcen, df, Nf, tran_fr)
#數據模擬(結構場)  
sim_poyn.run(until_after_sources=mp.stop_after_walltime(300))
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000298977 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 17 with resolution 500
#      block, center = (0,0,-0.05)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,0.2)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,0.45)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,0.7)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,0.95)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,1.2)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,1.45)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,1.7)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,1.95)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,2.2)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      ...(+ 20 objects not shown)...
# time for set_epsilon = 0.00710416 s
# -----------
# on time step 244654 (time=244.654), 1.63497e-05 s/step
# on time step 495021 (time=495.021), 1.59766e-05 s/step
# on time step 745243 (time=745.243), 1.59858e-05 s/step
# on time step 995656 (time=995.656), 1.59737e-05 s/step
# on time step 1245698 (time=1245.7), 1.59973e-05 s/step
# on time step 1494547 (time=1494.55), 1.6074e-05 s/step
# on time step 1744944 (time=1744.94), 1.59747e-05 s/step
# on time step 1995463 (time=1995.46), 1.59669e-05 s/step
# on time step 2240140 (time=2240.14), 1.63481e-05 s/step
# on time step 2488605 (time=2488.61), 1.60989e-05 s/step
# on time step 2735908 (time=2735.91), 1.61745e-05 s/step
# on time step 2985836 (time=2985.84), 1.60046e-05 s/step
# on time step 3235104 (time=3235.1), 1.6047e-05 s/step
# on time step 3485950 (time=3485.95), 1.59461e-05 s/step
# on time step 3735380 (time=3735.38), 1.60366e-05 s/step
# on time step 3985785 (time=3985.79), 1.59742e-05 s/step
# on time step 4236025 (time=4236.02), 1.59847e-05 s/step
# on time step 4485313 (time=4485.31), 1.60457e-05 s/step
# on time step 4735320 (time=4735.32), 1.59996e-05 s/step
# on time step 4983638 (time=4983.64), 1.61084e-05 s/step
# on time step 5234275 (time=5234.28), 1.59594e-05 s/step
# on time step 5483919 (time=5483.92), 1.60228e-05 s/step
# on time step 5733849 (time=5733.85), 1.60045e-05 s/step
# on time step 5984170 (time=5984.17), 1.59795e-05 s/step
# on time step 6233963 (time=6233.96), 1.60133e-05 s/step
# on time step 6484461 (time=6484.46), 1.59682e-05 s/step
# on time step 6731415 (time=6731.41), 1.61974e-05 s/step
# on time step 6981325 (time=6981.32), 1.60058e-05 s/step
# on time step 7231472 (time=7231.47), 1.59906e-05 s/step
# on time step 7482370 (time=7482.37), 1.59428e-05 s/step
# on time step 7733214 (time=7733.21), 1.59462e-05 s/step
# on time step 7983848 (time=7983.85), 1.59596e-05 s/step
# on time step 8233653 (time=8233.65), 1.60125e-05 s/step
# on time step 8484265 (time=8484.26), 1.5961e-05 s/step
# on time step 8735065 (time=8735.07), 1.5949e-05 s/step
# on time step 8983925 (time=8983.93), 1.60733e-05 s/step
# on time step 9230333 (time=9230.33), 1.62333e-05 s/step
# on time step 9478349 (time=9478.35), 1.6128e-05 s/step
# on time step 9726059 (time=9726.06), 1.6148e-05 s/step
# on time step 9974372 (time=9974.37), 1.61088e-05 s/step
# on time step 10223417 (time=10223.4), 1.60614e-05 s/step
# on time step 10469897 (time=10469.9), 1.62285e-05 s/step
# on time step 10720014 (time=10720), 1.59925e-05 s/step
# on time step 10970837 (time=10970.8), 1.59476e-05 s/step
# on time step 11221725 (time=11221.7), 1.59434e-05 s/step
# on time step 11471891 (time=11471.9), 1.59894e-05 s/step
# on time step 11722466 (time=11722.5), 1.59633e-05 s/step
# on time step 11973383 (time=11973.4), 1.59415e-05 s/step
# on time step 12223999 (time=12224), 1.59607e-05 s/step
# on time step 12474959 (time=12475), 1.59388e-05 s/step
# on time step 12725327 (time=12725.3), 1.59765e-05 s/step
# on time step 12975835 (time=12975.8), 1.59676e-05 s/step
# on time step 13226056 (time=13226.1), 1.59859e-05 s/step
# on time step 13476217 (time=13476.2), 1.59897e-05 s/step
# on time step 13726690 (time=13726.7), 1.59699e-05 s/step
# on time step 13977555 (time=13977.6), 1.59449e-05 s/step
# on time step 14228163 (time=14228.2), 1.59612e-05 s/step
# on time step 14478081 (time=14478.1), 1.60053e-05 s/step
# on time step 14728882 (time=14728.9), 1.59489e-05 s/step
# on time step 14979521 (time=14979.5), 1.59593e-05 s/step
# on time step 15230155 (time=15230.2), 1.59596e-05 s/step
# on time step 15480662 (time=15480.7), 1.59677e-05 s/step
# on time step 15731275 (time=15731.3), 1.59609e-05 s/step
# on time step 15981904 (time=15981.9), 1.59599e-05 s/step
# on time step 16232746 (time=16232.7), 1.59463e-05 s/step
# on time step 16483713 (time=16483.7), 1.59384e-05 s/step
# on time step 16731856 (time=16731.9), 1.61198e-05 s/step
# on time step 16980092 (time=16980.1), 1.61137e-05 s/step
# on time step 17228726 (time=17228.7), 1.6088e-05 s/step
# on time step 17475810 (time=17475.8), 1.61889e-05 s/step
# on time step 17723746 (time=17723.7), 1.61333e-05 s/step
# on time step 17971869 (time=17971.9), 1.61211e-05 s/step
# on time step 18222250 (time=18222.2), 1.59757e-05 s/step
# on time step 18470148 (time=18470.1), 1.61357e-05 s/step
# run 0 finished at t = 18707.427 (18707427 timesteps)

# %%
#紀錄通量(真空場)
T_str = np.array(mp.get_fluxes(tran))
T_meep = T_str / T_vac

# %%
#繪圖比較(數值與實驗)
from matplotlib import pyplot as plt 
plt.figure(dpi=150)
plt.plot(omega/2/np.pi, T_tmat, label='$T_{tmatrix}$')
#plt.plot(omega/2/np.pi, T_meep, label='$T_{meep}$')
plt.plot(omega/2/np.pi, T_smat, '--', label='$T_{smatrix}$')
plt.xlabel("$\omega$ ($2\pi$/μm)")
plt.ylabel("$T$")
plt.legend(loc="upper right")
plt.xlim([1,2])
plt.ylim([0,1])
plt.grid()
plt.show()
