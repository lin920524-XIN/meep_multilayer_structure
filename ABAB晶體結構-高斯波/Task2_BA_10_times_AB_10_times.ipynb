# %% [markdown]
# Layers A and B have the thicknesses  $d_A = 200 nm$  and  $d_B = 300 nm$ , and the dielectric constants $ϵ_A = 12$ and $ϵ_B = 3$. Compute and plot T vs ω for structure of 10 repeated AB followed by 10 repeated BA.(300 < ω < 600 THz)

# %% [markdown]
# ### 參數設定

# %%
import numpy as np
#頻率相關參數
Nf = 500
fmin = 1
fmax = 2
fre = np.linspace(fmin, fmax, Nf)
fcen = (fmin+fmax)/2
df = (fmax-fmin)
omega = 2 * np.pi * fre

# %%
#結構重複次數
num_pairs = 10
#晶體厚度
d_single = [0.2, 0.3]
d_list = []
for i in range(num_pairs):
    for j in range(len(d_single)-1):
        d_list.append(d_single[1])
        d_list.append(d_single[0])
for i in range(num_pairs):
    for j in range(len(d_single)-1):
        d_list.append(d_single[0])
        d_list.append(d_single[1])
d = sum(d_list)
d_pair = sum(d_single)
#材料介電常數
epsi_single = [12, 3]
epsi_list = []
for i in range(num_pairs):
    for j in range(len(epsi_single)-1):
        epsi_list.append(epsi_single[1])
        epsi_list.append(epsi_single[0])
for i in range(num_pairs):
    for j in range(len(epsi_single)-1):
        epsi_list.append(epsi_single[0])
        epsi_list.append(epsi_single[1])

# %%
#材料相位差
delta_list = []
for o in omega:
    delta_each_o = []
    for epsi, a in zip(epsi_list, d_list):
        delta = 2 * o * a * np.sqrt(epsi)
        delta_each_o.append(delta)
    delta_list.append(delta_each_o)
delta_array = np.array(delta_list)

# %%
epsi_all = epsi_list.copy()  
epsi_all.insert(0, 1)
epsi_all.append(1)

# %% [markdown]
# ### 轉移矩陣數值分析

# %%
#介面反射係數
r_list = []
for i in range(len(epsi_all)-1):
    r = (np.sqrt(epsi_all[i]) - np.sqrt(epsi_all[i+1])) / \
        (np.sqrt(epsi_all[i]) + np.sqrt(epsi_all[i+1]))
    r_list.append(r)
r_array = np.array(r_list)
#介面透射係數
t_list = []
for i in range(len(epsi_all)-1):
    t = 2 * (np.sqrt(epsi_all[i])) / \
        (np.sqrt(epsi_all[i]) + np.sqrt(epsi_all[i+1]))
    t_list.append(t)
t_array = np.array(t_list)

# %%
#介面反透射矩陣
i = 1j
D_list = []
for idx, t in enumerate(t_array):
    r_num = r_array[idx]
    D = (1 / t) * np.array([[1, r_num],
                            [r_num, 1]])
    D_list.append(D)
D_array = np.array(D_list)

# %%
#材料傳遞矩陣
P_list = []
for deltas in delta_array:
    P_temp = []
    for delta in deltas:
        P_11 = np.exp(-i * delta * 0.5)
        P_22 = np.exp(i * delta * 0.5)
        P = np.array([[P_11, 0],
                      [0, P_22]])
        P_temp.append(P)
    P_list.append(P_temp)
P_array = np.array(P_list)

# %%
#轉換矩陣
M_end_per_freq = np.zeros((Nf, 2, 2), dtype=complex)
for idx in range(Nf):
    P_array_per_freq = P_array[idx]
    M_temp = np.eye(2, 2)
    for k in range(len(epsi_list)):
        M_temp = M_temp @ np.array(D_array[k])
        M_temp = M_temp @ np.array(P_array_per_freq[k])
    M_temp = M_temp @ np.array(D_array[-1])
    M_end_per_freq[idx] = M_temp

# %%
#反射與透射
R_array = np.array([])
T_array = np.array([])
for i in range(Nf):
    Er = M_end_per_freq[i,1,0] / M_end_per_freq[i,0,0]
    R = np.abs(Er**2)
    T = 1 - R
    R_array = np.append(R_array,R)
    T_array = np.append(T_array,T)
T_tmat = T_array.tolist()

# %% [markdown]
# ### 散射矩陣數值分析

# %%
R_smat = []
T_smat = []
for M in M_end_per_freq:
    detM = M[0,0]*M[1,1] - M[0,1]*M[1,0]
    S11 = -M[1,0] / M[1,1]
    S21 = detM / M[1,1]
    R = np.abs(S11)**2
    T = np.abs(S21)**2
    R_smat.append(R)
    T_smat.append(T)
R_smat = np.array(R_smat)
T_smat = np.array(T_smat)

# %%
#繪圖比較(數值與實驗)
from matplotlib import pyplot as plt 
plt.figure(dpi=150)
plt.plot(omega/2/np.pi, T_tmat, label='$T_{tmatrix}$')
plt.plot(omega/2/np.pi, T_smat, '--', label='$T_{smatrix}$')
plt.xlabel("$\omega$ ($2\pi$/μm)")
plt.ylabel("$T$")
plt.legend(loc="upper right")
plt.xlim([1,2])
plt.ylim([0,1])
plt.grid()
plt.show()

# %% [markdown]
# ### meep模擬

# %%
import meep as mp
#模擬空間參數
resolution = 500
dpml = 1.0
sz = (d_pair * 30.0) + (dpml * 2.0)
cell_size = mp.Vector3(z=sz)
pml_layers = [mp.PML(dpml)]
dimensions = 1

# %%
#電磁波源(高斯)
sour_z = - (d / 2) - 0.3 
sources = [mp.Source(mp.GaussianSource(fcen,fwidth=df), component=mp.Ex, 
                     center=mp.Vector3(z=sour_z))]

# %%
#整體模擬流程(真空場)
sim_vac = mp.Simulation(cell_size=cell_size,
                        boundary_layers=pml_layers,
                        sources=sources,
                        dimensions=dimensions,
                        resolution=resolution)
#數據偵測(真空場)
tran_z = (d / 2) + 0.3
tran_vac_fr = mp.FluxRegion(center=mp.Vector3(z = tran_z))
tran_vac = sim_vac.add_flux(fcen, df, Nf, tran_vac_fr)
#數據模擬(真空場)  
sim_vac.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ex, mp.Vector3(z=tran_z), 1e-10))
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000476122 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 17 with resolution 500
# time for set_epsilon = 0.00204086 s
# -----------
# field decay(t = 50.001): 0.2500178432540746 / 0.2500178432540746 = 1.0
# field decay(t = 100.002): 2.1417864476034766e-16 / 0.2500178432540746 = 8.566534371016623e-16
# run 0 finished at t = 100.002 (100002 timesteps)

# %%
#紀錄通量(真空場)
T_vac = np.array(mp.get_fluxes(tran_vac))

# %%
#晶體(結構場)
geometry = []
z_start = - (d / 2)
for i in range(len(epsi_list)):
    center_z = z_start + (d_list[i] / 2)
    geometry.append(mp.Block(size=mp.Vector3(mp.inf, mp.inf, d_list[i]),
                             center=mp.Vector3(z=center_z),
                             material=mp.Medium(epsilon=epsi_list[i])
                            )
                 )
    z_start += d_list[i]

# %%
#整體模擬流程(結構場)
sim_poyn = mp.Simulation(cell_size=cell_size,
                         geometry=geometry,
                         boundary_layers=pml_layers,
                         sources=sources,
                         dimensions=dimensions,
                         resolution=resolution)
#數據偵測(結構場)
tran_z = (d / 2) + 0.3
tran_fr = mp.FluxRegion(center=mp.Vector3(z = tran_z))
tran = sim_poyn.add_flux(fcen, df, Nf, tran_fr)
#數據模擬(結構場)  
sim_poyn.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ex, mp.Vector3(z=tran_z), 1e-10))
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000332117 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 17 with resolution 500
#      block, center = (0,0,-4.85)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-4.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-4.35)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-4.1)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-3.85)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-3.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-3.35)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-3.1)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-2.85)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,-2.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      ...(+ 30 objects not shown)...
# time for set_epsilon = 0.00318003 s
# -----------
# field decay(t = 50.001): 0.05602198844519505 / 0.05602198844519505 = 1.0
# field decay(t = 100.002): 0.0009824402990010475 / 0.05602198844519505 = 0.017536690972012624
# field decay(t = 150.00300000000001): 0.00020868743252714161 / 0.05602198844519505 = 0.0037250986321432605
# on time step 153709 (time=153.709), 2.60232e-05 s/step
# field decay(t = 200.004): 3.212375356687107e-05 / 0.05602198844519505 = 0.0005734133053541461
# field decay(t = 250.005): 5.701950392257711e-06 / 0.05602198844519505 = 0.0001017805784926001
# field decay(t = 300.00600000000003): 4.843126079443356e-06 / 0.05602198844519505 = 8.645044943703255e-05
# on time step 307574 (time=307.574), 2.59969e-05 s/step
# field decay(t = 350.007): 2.5171558136825734e-06 / 0.05602198844519505 = 4.4931568541967154e-05
# field decay(t = 400.008): 8.158572057426407e-07 / 0.05602198844519505 = 1.4563160437276766e-05
# field decay(t = 450.009): 2.071828590830681e-07 / 0.05602198844519505 = 3.6982417945723234e-06
# on time step 461531 (time=461.531), 2.59814e-05 s/step
# field decay(t = 500.01): 2.0836110337058877e-07 / 0.05602198844519505 = 3.719273612974723e-06
# field decay(t = 550.011): 1.4873385414156865e-07 / 0.05602198844519505 = 2.6549192249231097e-06
# field decay(t = 600.0120000000001): 5.1464431512837294e-08 / 0.05602198844519505 = 9.186469981011777e-07
# on time step 615677 (time=615.677), 2.59496e-05 s/step
# field decay(t = 650.013): 2.6451197167184977e-08 / 0.05602198844519505 = 4.721574135673806e-07
# field decay(t = 700.014): 2.4371357503937403e-08 / 0.05602198844519505 = 4.3503199690563126e-07
# field decay(t = 750.015): 1.6969756555759338e-08 / 0.05602198844519505 = 3.029124282577088e-07
# on time step 769991 (time=769.991), 2.59213e-05 s/step
# field decay(t = 800.016): 8.458822027630729e-09 / 0.05602198844519505 = 1.509911065706957e-07
# field decay(t = 850.017): 6.597799902575538e-09 / 0.05602198844519505 = 1.1777161228452299e-07
# field decay(t = 900.018): 6.078981447847616e-09 / 0.05602198844519505 = 1.0851063335237619e-07
# on time step 923542 (time=923.542), 2.60501e-05 s/step
# field decay(t = 950.019): 5.397931557660751e-09 / 0.05602198844519505 = 9.635380156028229e-08
# field decay(t = 1000.02): 4.237617096617079e-09 / 0.05602198844519505 = 7.5642032962872e-08
# field decay(t = 1050.021): 4.0111116406419654e-09 / 0.05602198844519505 = 7.159888022478778e-08
# on time step 1076920 (time=1076.92), 2.60794e-05 s/step
# field decay(t = 1100.022): 3.756436459609842e-09 / 0.05602198844519505 = 6.705289412004132e-08
# field decay(t = 1150.023): 3.3664759482348835e-09 / 0.05602198844519505 = 6.009204674211493e-08
# field decay(t = 1200.0240000000001): 3.1494560721379923e-09 / 0.05602198844519505 = 5.62182128758073e-08
# on time step 1231054 (time=1231.05), 2.59515e-05 s/step
# field decay(t = 1250.025): 3.030547397215895e-09 / 0.05602198844519505 = 5.409567709615673e-08
# field decay(t = 1300.026): 2.891272331339092e-09 / 0.05602198844519505 = 5.160959850912028e-08
# field decay(t = 1350.027): 2.7324909591839e-09 / 0.05602198844519505 = 4.8775329741410904e-08
# on time step 1384924 (time=1384.92), 2.5996e-05 s/step
# field decay(t = 1400.028): 2.6891535215289287e-09 / 0.05602198844519505 = 4.800175067258925e-08
# field decay(t = 1450.029): 2.610597646072838e-09 / 0.05602198844519505 = 4.659951777018273e-08
# field decay(t = 1500.03): 2.543761479711334e-09 / 0.05602198844519505 = 4.540648324541058e-08
# on time step 1538611 (time=1538.61), 2.6027e-05 s/step
# field decay(t = 1550.031): 2.4763074902172014e-09 / 0.05602198844519505 = 4.420242049494035e-08
# field decay(t = 1600.032): 2.4609822521780776e-09 / 0.05602198844519505 = 4.392886294254972e-08
# field decay(t = 1650.0330000000001): 2.426600156513917e-09 / 0.05602198844519505 = 4.3315137928169064e-08
# on time step 1692179 (time=1692.18), 2.60472e-05 s/step
# field decay(t = 1700.034): 2.3973936595400598e-09 / 0.05602198844519505 = 4.27937980438765e-08
# field decay(t = 1750.035): 2.38183505629741e-09 / 0.05602198844519505 = 4.251607489133488e-08
# field decay(t = 1800.036): 2.341539848490023e-09 / 0.05602198844519505 = 4.1796800032913764e-08
# on time step 1845130 (time=1845.13), 2.61523e-05 s/step
# field decay(t = 1850.037): 2.3104929897600885e-09 / 0.05602198844519505 = 4.124260944468952e-08
# field decay(t = 1900.038): 2.298385262414098e-09 / 0.05602198844519505 = 4.1026484889277936e-08
# field decay(t = 1950.039): 2.2773289828779678e-09 / 0.05602198844519505 = 4.0650627478277095e-08
# on time step 1998910 (time=1998.91), 2.60113e-05 s/step
# field decay(t = 2000.04): 2.2469631048623364e-09 / 0.05602198844519505 = 4.010859248704615e-08
# field decay(t = 2050.041): 2.2338102565860536e-09 / 0.05602198844519505 = 3.987381238299558e-08
# field decay(t = 2100.042): 2.2149702221469026e-09 / 0.05602198844519505 = 3.9537515243925233e-08
# field decay(t = 2150.043): 2.2020543312265028e-09 / 0.05602198844519505 = 3.930696486042653e-08
# on time step 2153007 (time=2153.01), 2.59578e-05 s/step
# field decay(t = 2200.044): 2.1901401287920516e-09 / 0.05602198844519505 = 3.909429475061587e-08
# field decay(t = 2250.045): 2.1751093356272353e-09 / 0.05602198844519505 = 3.88259930786836e-08
# field decay(t = 2300.046): 2.156547279069265e-09 / 0.05602198844519505 = 3.849465788203792e-08
# on time step 2306925 (time=2306.93), 2.59879e-05 s/step
# field decay(t = 2350.047): 2.144360165682106e-09 / 0.05602198844519505 = 3.827711627515474e-08
# field decay(t = 2400.0480000000002): 2.128464253504202e-09 / 0.05602198844519505 = 3.799337211292361e-08
# field decay(t = 2450.049): 2.11023557335437e-09 / 0.05602198844519505 = 3.766798772983151e-08
# on time step 2460724 (time=2460.72), 2.6008e-05 s/step
# field decay(t = 2500.05): 2.09814703673428e-09 / 0.05602198844519505 = 3.745220573144858e-08
# field decay(t = 2550.051): 2.081619721308029e-09 / 0.05602198844519505 = 3.715719093663423e-08
# field decay(t = 2600.052): 2.066215788361335e-09 / 0.05602198844519505 = 3.688222866959932e-08
# on time step 2614893 (time=2614.89), 2.59456e-05 s/step
# field decay(t = 2650.053): 2.05457270080494e-09 / 0.05602198844519505 = 3.667439799668801e-08
# field decay(t = 2700.054): 2.0447479745109805e-09 / 0.05602198844519505 = 3.649902531594907e-08
# field decay(t = 2750.055): 2.0308609075450296e-09 / 0.05602198844519505 = 3.6251139309911706e-08
# on time step 2769234 (time=2769.23), 2.59167e-05 s/step
# field decay(t = 2800.056): 2.014468527474219e-09 / 0.05602198844519505 = 3.595853312927164e-08
# field decay(t = 2850.0570000000002): 2.002652613547119e-09 / 0.05602198844519505 = 3.574761748248664e-08
# field decay(t = 2900.058): 1.9874060133723745e-09 / 0.05602198844519505 = 3.5475463626511675e-08
# on time step 2923196 (time=2923.2), 2.59806e-05 s/step
# field decay(t = 2950.059): 1.9755571765016816e-09 / 0.05602198844519505 = 3.526396030077228e-08
# field decay(t = 3000.06): 1.9620321458796603e-09 / 0.05602198844519505 = 3.502253669198245e-08
# field decay(t = 3050.061): 1.9474453843544397e-09 / 0.05602198844519505 = 3.47621610443117e-08
# on time step 3077338 (time=3077.34), 2.59502e-05 s/step
# field decay(t = 3100.062): 1.936494389935854e-09 / 0.05602198844519505 = 3.4566684326642195e-08
# field decay(t = 3150.063): 1.9250932001118996e-09 / 0.05602198844519505 = 3.436317156066625e-08
# field decay(t = 3200.064): 1.914605021503495e-09 / 0.05602198844519505 = 3.417595616722007e-08
# on time step 3231662 (time=3231.66), 2.59196e-05 s/step
# field decay(t = 3250.065): 1.900131857596048e-09 / 0.05602198844519505 = 3.391760825224725e-08
# field decay(t = 3300.0660000000003): 1.89087495803087e-09 / 0.05602198844519505 = 3.3752371354698824e-08
# field decay(t = 3350.067): 1.8779413436491945e-09 / 0.05602198844519505 = 3.3521504605041624e-08
# on time step 3385889 (time=3385.89), 2.59358e-05 s/step
# field decay(t = 3400.068): 1.8644624469144574e-09 / 0.05602198844519505 = 3.3280904492321186e-08
# field decay(t = 3450.069): 1.8532799639443417e-09 / 0.05602198844519505 = 3.308129567299027e-08
# field decay(t = 3500.07): 1.839015760210957e-09 / 0.05602198844519505 = 3.2826677725122545e-08
# on time step 3539962 (time=3539.96), 2.59618e-05 s/step
# field decay(t = 3550.071): 1.8284204163089108e-09 / 0.05602198844519505 = 3.263754941682604e-08
# field decay(t = 3600.072): 1.8157703642765237e-09 / 0.05602198844519505 = 3.2411744293097484e-08
# field decay(t = 3650.073): 1.80590138334889e-09 / 0.05602198844519505 = 3.223558166121789e-08
# on time step 3694017 (time=3694.02), 2.59648e-05 s/step
# field decay(t = 3700.074): 1.7946655217981691e-09 / 0.05602198844519505 = 3.20350200270711e-08
# field decay(t = 3750.0750000000003): 1.7833455361497714e-09 / 0.05602198844519505 = 3.183295676650919e-08
# field decay(t = 3800.076): 1.7733837739844124e-09 / 0.05602198844519505 = 3.165513797710466e-08
# on time step 3847743 (time=3847.74), 2.60205e-05 s/step
# field decay(t = 3850.077): 1.759778990058554e-09 / 0.05602198844519505 = 3.1412290761155384e-08
# field decay(t = 3900.078): 1.7504831128978858e-09 / 0.05602198844519505 = 3.124635810830494e-08
# field decay(t = 3950.079): 1.737504511128969e-09 / 0.05602198844519505 = 3.101468832775773e-08
# field decay(t = 4000.08): 1.725604022577569e-09 / 0.05602198844519505 = 3.080226301259702e-08
# on time step 4001716 (time=4001.72), 2.59787e-05 s/step
# field decay(t = 4050.081): 1.7158215073715975e-09 / 0.05602198844519505 = 3.0627643805434435e-08
# field decay(t = 4100.082): 1.7029522793632848e-09 / 0.05602198844519505 = 3.0397926361168736e-08
# field decay(t = 4150.0830000000005): 1.6944539014782159e-09 / 0.05602198844519505 = 3.024622917724277e-08
# on time step 4156154 (time=4156.15), 2.59005e-05 s/step
# field decay(t = 4200.084): 1.6824920691579957e-09 / 0.05602198844519505 = 3.003270886758932e-08
# field decay(t = 4250.085): 1.6734558169957893e-09 / 0.05602198844519505 = 2.987141055574795e-08
# field decay(t = 4300.086): 1.6627483405893907e-09 / 0.05602198844519505 = 2.9680280667224388e-08
# on time step 4307769 (time=4307.77), 2.63827e-05 s/step
# field decay(t = 4350.087): 1.6517150066342144e-09 / 0.05602198844519505 = 2.948333417779426e-08
# field decay(t = 4400.088): 1.6423005983015424e-09 / 0.05602198844519505 = 2.9315285727641836e-08
# field decay(t = 4450.089): 1.6299136569833068e-09 / 0.05602198844519505 = 2.9094177165414466e-08
# on time step 4461384 (time=4461.38), 2.60392e-05 s/step
# field decay(t = 4500.09): 1.6196961051254502e-09 / 0.05602198844519505 = 2.8911792495726202e-08
# field decay(t = 4550.091): 1.6091535799512476e-09 / 0.05602198844519505 = 2.872360700879876e-08
# field decay(t = 4600.092): 1.5988382811291444e-09 / 0.05602198844519505 = 2.853947754270181e-08
# on time step 4615607 (time=4615.61), 2.59366e-05 s/step
# field decay(t = 4650.093): 1.5895261562521766e-09 / 0.05602198844519505 = 2.8373254865938425e-08
# field decay(t = 4700.094): 1.5780993456405687e-09 / 0.05602198844519505 = 2.816928476546999e-08
# field decay(t = 4750.095): 1.5700053041193596e-09 / 0.05602198844519505 = 2.8024805039814994e-08
# on time step 4769863 (time=4769.86), 2.5931e-05 s/step
# field decay(t = 4800.0960000000005): 1.558667351846552e-09 / 0.05602198844519505 = 2.7822421072600065e-08
# field decay(t = 4850.097): 1.550250618224041e-09 / 0.05602198844519505 = 2.7672181249700078e-08
# field decay(t = 4900.098): 1.5400976109110205e-09 / 0.05602198844519505 = 2.7490948708785313e-08
# on time step 4923685 (time=4923.69), 2.60042e-05 s/step
# field decay(t = 4950.099): 1.5302608280079198e-09 / 0.05602198844519505 = 2.731536081595777e-08
# field decay(t = 5000.1): 1.5196712031100359e-09 / 0.05602198844519505 = 2.7126334592651835e-08
# field decay(t = 5050.101): 1.5084679060390672e-09 / 0.05602198844519505 = 2.692635423883186e-08
# on time step 5077628 (time=5077.63), 2.59838e-05 s/step
# field decay(t = 5100.102): 1.500553334866311e-09 / 0.05602198844519505 = 2.6785078082943557e-08
# field decay(t = 5150.103): 1.4905537883205232e-09 / 0.05602198844519505 = 2.6606584837285733e-08
# field decay(t = 5200.104): 1.4814219099541542e-09 / 0.05602198844519505 = 2.6443579584887337e-08
# on time step 5231522 (time=5231.52), 2.5992e-05 s/step
# field decay(t = 5250.1050000000005): 1.4725500209110478e-09 / 0.05602198844519505 = 2.6285215176744534e-08
# field decay(t = 5300.106): 1.4621380748361275e-09 / 0.05602198844519505 = 2.6099360544235265e-08
# field decay(t = 5350.107): 1.4544688678691443e-09 / 0.05602198844519505 = 2.5962464172295773e-08
# on time step 5385243 (time=5385.24), 2.60212e-05 s/step
# field decay(t = 5400.108): 1.4437343507108793e-09 / 0.05602198844519505 = 2.577085160272827e-08
# field decay(t = 5450.109): 1.4361948507457245e-09 / 0.05602198844519505 = 2.5636270518150547e-08
# field decay(t = 5500.11): 1.4253126419103092e-09 / 0.05602198844519505 = 2.544202163235705e-08
# on time step 5539351 (time=5539.35), 2.59559e-05 s/step
# field decay(t = 5550.111): 1.4154576514765747e-09 / 0.05602198844519505 = 2.526610873266811e-08
# field decay(t = 5600.112): 1.4077864578895712e-09 / 0.05602198844519505 = 2.5129176899295078e-08
# field decay(t = 5650.113): 1.3972269193911616e-09 / 0.05602198844519505 = 2.4940687722250966e-08
# on time step 5693348 (time=5693.35), 2.59747e-05 s/step
# field decay(t = 5700.1140000000005): 1.390225951280265e-09 / 0.05602198844519505 = 2.4815719503428363e-08
# field decay(t = 5750.115): 1.380736153397049e-09 / 0.05602198844519505 = 2.4646325339697457e-08
# field decay(t = 5800.116): 1.3725282677092947e-09 / 0.05602198844519505 = 2.4499813480415923e-08
# on time step 5847423 (time=5847.42), 2.59614e-05 s/step
# field decay(t = 5850.117): 1.3641375957557922e-09 / 0.05602198844519505 = 2.435003886179968e-08
# field decay(t = 5900.118): 1.3547235473776682e-09 / 0.05602198844519505 = 2.4181996836884172e-08
# field decay(t = 5950.119): 1.3474175116310035e-09 / 0.05602198844519505 = 2.4051583119887814e-08
# field decay(t = 6000.12): 1.3368548844589446e-09 / 0.05602198844519505 = 2.386303880960522e-08
# on time step 6001689 (time=6001.69), 2.59293e-05 s/step
# field decay(t = 6050.121): 1.3286420226490351e-09 / 0.05602198844519505 = 2.3716438125876474e-08
# field decay(t = 6100.122): 1.3203160584633142e-09 / 0.05602198844519505 = 2.3567818549585173e-08
# field decay(t = 6150.1230000000005): 1.3114570790781392e-09 / 0.05602198844519505 = 2.340968458056618e-08
# on time step 6156252 (time=6156.25), 2.58795e-05 s/step
# field decay(t = 6200.124): 1.3041955570632195e-09 / 0.05602198844519505 = 2.3280065439645763e-08
# field decay(t = 6250.125): 1.2942258047091859e-09 / 0.05602198844519505 = 2.3102104024302805e-08
# field decay(t = 6300.126): 1.2879739709992424e-09 / 0.05602198844519505 = 2.2990507954911956e-08
# on time step 6310733 (time=6310.73), 2.58932e-05 s/step
# field decay(t = 6350.127): 1.2789779560486129e-09 / 0.05602198844519505 = 2.2829927882688528e-08
# field decay(t = 6400.128): 1.2716090767160085e-09 / 0.05602198844519505 = 2.2698392399262888e-08
# field decay(t = 6450.129): 1.2636857796113955e-09 / 0.05602198844519505 = 2.255696048432177e-08
# on time step 6465209 (time=6465.21), 2.5894e-05 s/step
# field decay(t = 6500.13): 1.2552083574550421e-09 / 0.05602198844519505 = 2.2405637362961187e-08
# field decay(t = 6550.131): 1.246714890783274e-09 / 0.05602198844519505 = 2.2254027844850687e-08
# field decay(t = 6600.1320000000005): 1.2378538291907437e-09 / 0.05602198844519505 = 2.209585670815141e-08
# on time step 6619676 (time=6619.68), 2.58955e-05 s/step
# field decay(t = 6650.133): 1.2309588522356586e-09 / 0.05602198844519505 = 2.197278044566154e-08
# field decay(t = 6700.134): 1.223068887809863e-09 / 0.05602198844519505 = 2.183194352350348e-08
# field decay(t = 6750.135): 1.2151003323522627e-09 / 0.05602198844519505 = 2.1689703740897485e-08
# on time step 6773625 (time=6773.62), 2.59827e-05 s/step
# field decay(t = 6800.136): 1.2082107814000636e-09 / 0.05602198844519505 = 2.1566724333286152e-08
# field decay(t = 6850.137): 1.1991978816463093e-09 / 0.05602198844519505 = 2.1405842865064587e-08
# field decay(t = 6900.138): 1.1932185153127734e-09 / 0.05602198844519505 = 2.1299110374849868e-08
# on time step 6928236 (time=6928.24), 2.58715e-05 s/step
# field decay(t = 6950.139): 1.1847400277440912e-09 / 0.05602198844519505 = 2.1147768235736466e-08
# field decay(t = 7000.14): 1.1781410652570175e-09 / 0.05602198844519505 = 2.102997587116288e-08
# field decay(t = 7050.1410000000005): 1.1694308254323988e-09 / 0.05602198844519505 = 2.0874496923229075e-08
# on time step 7082829 (time=7082.83), 2.58745e-05 s/step
# field decay(t = 7100.142): 1.1609250234814957e-09 / 0.05602198844519505 = 2.0722667218733238e-08
# field decay(t = 7150.143): 1.1549987555215946e-09 / 0.05602198844519505 = 2.0616882541602426e-08
# field decay(t = 7200.144): 1.1466022185636473e-09 / 0.05602198844519505 = 2.0467003231871006e-08
# on time step 7237180 (time=7237.18), 2.5915e-05 s/step
# field decay(t = 7250.145): 1.1404405761451697e-09 / 0.05602198844519505 = 2.035701708911734e-08
# field decay(t = 7300.146): 1.1329957149680317e-09 / 0.05602198844519505 = 2.0224125319586146e-08
# field decay(t = 7350.147): 1.125830245125433e-09 / 0.05602198844519505 = 2.0096220722811463e-08
# on time step 7391600 (time=7391.6), 2.59035e-05 s/step
# field decay(t = 7400.148): 1.1192706925228616e-09 / 0.05602198844519505 = 1.9979131829956676e-08
# field decay(t = 7450.149): 1.1111313497300315e-09 / 0.05602198844519505 = 1.9833843470533437e-08
# field decay(t = 7500.150000000001): 1.1054215627566468e-09 / 0.05602198844519505 = 1.9731923008017716e-08
# on time step 7546036 (time=7546.04), 2.59008e-05 s/step
# field decay(t = 7550.151): 1.09655735104435e-09 / 0.05602198844519505 = 1.957369564125853e-08
# field decay(t = 7600.152): 1.0898348919748884e-09 / 0.05602198844519505 = 1.9453698846142302e-08
# field decay(t = 7650.153): 1.0833483256730056e-09 / 0.05602198844519505 = 1.9337912768534072e-08
# field decay(t = 7700.154): 1.0756759571195813e-09 / 0.05602198844519505 = 1.9200959961852996e-08
# on time step 7700647 (time=7700.65), 2.58714e-05 s/step
# field decay(t = 7750.155): 1.0700139259573802e-09 / 0.05602198844519505 = 1.909989194696559e-08
# field decay(t = 7800.156): 1.0620896592352779e-09 / 0.05602198844519505 = 1.8958442724222373e-08
# field decay(t = 7850.157): 1.0565857249824946e-09 / 0.05602198844519505 = 1.8860196760351104e-08
# on time step 7855308 (time=7855.31), 2.58631e-05 s/step
# field decay(t = 7900.158): 1.0495394454139085e-09 / 0.05602198844519505 = 1.8734419725937566e-08
# field decay(t = 7950.159000000001): 1.0431055951536919e-09 / 0.05602198844519505 = 1.8619574636736372e-08
# field decay(t = 8000.16): 1.0368624097977807e-09 / 0.05602198844519505 = 1.850813294162377e-08
# on time step 8009875 (time=8009.88), 2.58788e-05 s/step
# field decay(t = 8050.161): 1.029521265897541e-09 / 0.05602198844519505 = 1.8377092539382044e-08
# field decay(t = 8100.162): 1.0227696912401704e-09 / 0.05602198844519505 = 1.8256576027120516e-08
# field decay(t = 8150.1630000000005): 1.015787499890545e-09 / 0.05602198844519505 = 1.8131942976002456e-08
# on time step 8164529 (time=8164.53), 2.58643e-05 s/step
# field decay(t = 8200.164): 1.0097530745630845e-09 / 0.05602198844519505 = 1.8024227675368958e-08
# field decay(t = 8250.165): 1.0035865886365466e-09 / 0.05602198844519505 = 1.791415507534744e-08
# field decay(t = 8300.166000000001): 9.966732293640308e-10 / 0.05602198844519505 = 1.7790750686028435e-08
# on time step 8318893 (time=8318.89), 2.59129e-05 s/step
# field decay(t = 8350.167): 9.912697758561335e-10 / 0.05602198844519505 = 1.7694298316916555e-08
# field decay(t = 8400.168): 9.838077489836075e-10 / 0.05602198844519505 = 1.7561100137422695e-08
# field decay(t = 8450.169): 9.789015807921e-10 / 0.05602198844519505 = 1.7473524377838457e-08
# on time step 8470208 (time=8470.21), 2.6435e-05 s/step
# field decay(t = 8500.17): 9.722148921465494e-10 / 0.05602198844519505 = 1.7354166089581835e-08
# field decay(t = 8550.171): 9.664451270072224e-10 / 0.05602198844519505 = 1.7251175008767714e-08
# field decay(t = 8600.172): 9.59501743216663e-10 / 0.05602198844519505 = 1.712723467777871e-08
# on time step 8624408 (time=8624.41), 2.59404e-05 s/step
# field decay(t = 8650.173): 9.521614299526678e-10 / 0.05602198844519505 = 1.6996209102505246e-08
# field decay(t = 8700.174): 9.475391690795133e-10 / 0.05602198844519505 = 1.6913701126593672e-08
# field decay(t = 8750.175000000001): 9.409519262254358e-10 / 0.05602198844519505 = 1.6796117959039354e-08
# on time step 8778718 (time=8778.72), 2.5922e-05 s/step
# field decay(t = 8800.176): 9.355476298622272e-10 / 0.05602198844519505 = 1.6699650544847238e-08
# field decay(t = 8850.177): 9.296843915435584e-10 / 0.05602198844519505 = 1.6594990955257613e-08
# field decay(t = 8900.178): 9.234594449363065e-10 / 0.05602198844519505 = 1.6483874824252347e-08
# on time step 8932937 (time=8932.94), 2.59372e-05 s/step
# field decay(t = 8950.179): 9.183300735568974e-10 / 0.05602198844519505 = 1.6392314857857598e-08
# field decay(t = 9000.18): 9.113031638340866e-10 / 0.05602198844519505 = 1.6266883577786467e-08
# field decay(t = 9050.181): 9.069159071549905e-10 / 0.05602198844519505 = 1.6188570458226493e-08
# on time step 9082071 (time=9082.07), 2.68216e-05 s/step
# field decay(t = 9100.182): 8.998275573670018e-10 / 0.05602198844519505 = 1.606204246475973e-08
# field decay(t = 9150.183): 8.939743692795177e-10 / 0.05602198844519505 = 1.595756227314336e-08
# field decay(t = 9200.184): 8.888784587676773e-10 / 0.05602198844519505 = 1.5866599587718053e-08
# on time step 9236214 (time=9236.21), 2.59501e-05 s/step
# field decay(t = 9250.185): 8.822502483158969e-10 / 0.05602198844519505 = 1.5748285143055584e-08
# field decay(t = 9300.186): 8.778641721610476e-10 / 0.05602198844519505 = 1.566999309601159e-08
# field decay(t = 9350.187): 8.716161790679441e-10 / 0.05602198844519505 = 1.555846558214593e-08
# on time step 9390862 (time=9390.86), 2.58653e-05 s/step
# field decay(t = 9400.188): 8.667809836838403e-10 / 0.05602198844519505 = 1.5472156696683323e-08
# field decay(t = 9450.189): 8.612089161737649e-10 / 0.05602198844519505 = 1.5372694545040376e-08
# field decay(t = 9500.19): 8.556109753329799e-10 / 0.05602198844519505 = 1.5272770550977558e-08
# on time step 9545404 (time=9545.4), 2.58831e-05 s/step
# field decay(t = 9550.191): 8.497326204015493e-10 / 0.05602198844519505 = 1.5167841127824693e-08
# field decay(t = 9600.192000000001): 8.44411315013243e-10 / 0.05602198844519505 = 1.5072855113654347e-08
# field decay(t = 9650.193): 8.390527760051129e-10 / 0.05602198844519505 = 1.4977204474381303e-08
# on time step 9699744 (time=9699.74), 2.59169e-05 s/step
# field decay(t = 9700.194): 8.335543722549607e-10 / 0.05602198844519505 = 1.4879057230723017e-08
# field decay(t = 9750.195): 8.28294147657968e-10 / 0.05602198844519505 = 1.4785161516861688e-08
# field decay(t = 9800.196): 8.23447925714602e-10 / 0.05602198844519505 = 1.4698655805838829e-08
# field decay(t = 9850.197): 8.174624228582582e-10 / 0.05602198844519505 = 1.459181377786977e-08
# on time step 9853728 (time=9853.73), 2.59768e-05 s/step
# field decay(t = 9900.198): 8.132990559419049e-10 / 0.05602198844519505 = 1.4517497120573213e-08
# field decay(t = 9950.199): 8.073780651075495e-10 / 0.05602198844519505 = 1.441180664084046e-08
# field decay(t = 10000.2): 8.03059362939965e-10 / 0.05602198844519505 = 1.4334717228496423e-08
# on time step 10007974 (time=10008), 2.59327e-05 s/step
# field decay(t = 10050.201000000001): 7.970335779462807e-10 / 0.05602198844519505 = 1.422715615897853e-08
# field decay(t = 10100.202): 7.927587017114456e-10 / 0.05602198844519505 = 1.4150849045406202e-08
# field decay(t = 10150.203): 7.872271859182217e-10 / 0.05602198844519505 = 1.4052110747342483e-08
# on time step 10162182 (time=10162.2), 2.59391e-05 s/step
# field decay(t = 10200.204): 7.814003814334206e-10 / 0.05602198844519505 = 1.3948101506569079e-08
# field decay(t = 10250.205): 7.773717167223533e-10 / 0.05602198844519505 = 1.3876189301685305e-08
# field decay(t = 10300.206): 7.721521124628306e-10 / 0.05602198844519505 = 1.3783018666290437e-08
# on time step 10316512 (time=10316.5), 2.59185e-05 s/step
# field decay(t = 10350.207): 7.674307218125607e-10 / 0.05602198844519505 = 1.3698741210575192e-08
# field decay(t = 10400.208): 7.628467239089919e-10 / 0.05602198844519505 = 1.361691623379749e-08
# field decay(t = 10450.209): 7.574495275611326e-10 / 0.05602198844519505 = 1.3520575555830672e-08
# on time step 10465668 (time=10465.7), 2.68177e-05 s/step
# field decay(t = 10500.210000000001): 7.534727060222675e-10 / 0.05602198844519505 = 1.3449588758517052e-08
# field decay(t = 10550.211): 7.474198040714994e-10 / 0.05602198844519505 = 1.3341543647681875e-08
# field decay(t = 10600.212): 7.429141476453611e-10 / 0.05602198844519505 = 1.3261117076773094e-08
# on time step 10619934 (time=10619.9), 2.59293e-05 s/step
# field decay(t = 10650.213): 7.383488080679776e-10 / 0.05602198844519505 = 1.3179625153617785e-08
# field decay(t = 10700.214): 7.332699840981452e-10 / 0.05602198844519505 = 1.3088967465256707e-08
# field decay(t = 10750.215): 7.293189270557248e-10 / 0.05602198844519505 = 1.3018440567656748e-08
# on time step 10773711 (time=10773.7), 2.60118e-05 s/step
# field decay(t = 10800.216): 7.238008472393688e-10 / 0.05602198844519505 = 1.2919942103580374e-08
# field decay(t = 10850.217): 7.202139527666931e-10 / 0.05602198844519505 = 1.2855915556643637e-08
# field decay(t = 10900.218): 7.152746777354523e-10 / 0.05602198844519505 = 1.276774883553425e-08
# on time step 10927755 (time=10927.8), 2.59667e-05 s/step
# field decay(t = 10950.219000000001): 7.110360030510503e-10 / 0.05602198844519505 = 1.2692087924487715e-08
# field decay(t = 11000.22): 7.06695155633811e-10 / 0.05602198844519505 = 1.2614603216470149e-08
# field decay(t = 11050.221): 7.018313806506415e-10 / 0.05602198844519505 = 1.2527784181334908e-08
# on time step 11081420 (time=11081.4), 2.60307e-05 s/step
# field decay(t = 11100.222): 6.971585705758268e-10 / 0.05602198844519505 = 1.2444373895400734e-08
# field decay(t = 11150.223): 6.922787680535202e-10 / 0.05602198844519505 = 1.2357268766544401e-08
# field decay(t = 11200.224): 6.883170223279474e-10 / 0.05602198844519505 = 1.2286551074518022e-08
# on time step 11235185 (time=11235.2), 2.60139e-05 s/step
# field decay(t = 11250.225): 6.83999250776533e-10 / 0.05602198844519505 = 1.2209478273797313e-08
# field decay(t = 11300.226): 6.794216751993308e-10 / 0.05602198844519505 = 1.2127767936405766e-08
# field decay(t = 11350.227): 6.756616761509708e-10 / 0.05602198844519505 = 1.2060651449599191e-08
# on time step 11388906 (time=11388.9), 2.60213e-05 s/step
# field decay(t = 11400.228000000001): 6.704924783706173e-10 / 0.05602198844519505 = 1.1968380576611338e-08
# field decay(t = 11450.229): 6.672474776046928e-10 / 0.05602198844519505 = 1.1910456878149636e-08
# field decay(t = 11500.23): 6.6259041109693e-10 / 0.05602198844519505 = 1.182732761699678e-08
# on time step 11542711 (time=11542.7), 2.6007e-05 s/step
# field decay(t = 11550.231): 6.587968003006452e-10 / 0.05602198844519505 = 1.175961115598619e-08
# field decay(t = 11600.232): 6.539905853352581e-10 / 0.05602198844519505 = 1.1673819574880695e-08
# field decay(t = 11650.233): 6.491108971202553e-10 / 0.05602198844519505 = 1.1586716486425053e-08
# on time step 11696544 (time=11696.5), 2.60023e-05 s/step
# field decay(t = 11700.234): 6.458912291954112e-10 / 0.05602198844519505 = 1.1529244982570921e-08
# field decay(t = 11750.235): 6.412658645127827e-10 / 0.05602198844519505 = 1.1446681603244369e-08
# field decay(t = 11800.236): 6.377211386678607e-10 / 0.05602198844519505 = 1.1383407771963108e-08
# on time step 11850135 (time=11850.1), 2.60433e-05 s/step
# field decay(t = 11850.237000000001): 6.336430320982765e-10 / 0.05602198844519505 = 1.131061302328021e-08
# field decay(t = 11900.238): 6.295279200049079e-10 / 0.05602198844519505 = 1.1237157721039477e-08
# field decay(t = 11950.239): 6.259428284474254e-10 / 0.05602198844519505 = 1.1173163356380506e-08
# field decay(t = 12000.24): 6.212754805046795e-10 / 0.05602198844519505 = 1.1089850570235619e-08
# on time step 12004190 (time=12004.2), 2.59648e-05 s/step
# field decay(t = 12050.241): 6.181798975129098e-10 / 0.05602198844519505 = 1.103459399906271e-08
# field decay(t = 12100.242): 6.132774756214838e-10 / 0.05602198844519505 = 1.0947085111436883e-08
# field decay(t = 12150.243): 6.094118170530095e-10 / 0.05602198844519505 = 1.08780825880392e-08
# on time step 12158046 (time=12158), 2.59984e-05 s/step
# field decay(t = 12200.244): 6.058667084972324e-10 / 0.05602198844519505 = 1.0814801925317897e-08
# field decay(t = 12250.245): 6.014645983289786e-10 / 0.05602198844519505 = 1.0736223668986272e-08
# field decay(t = 12300.246000000001): 5.983849146884957e-10 / 0.05602198844519505 = 1.0681250903364152e-08
# on time step 12312312 (time=12312.3), 2.59292e-05 s/step
# field decay(t = 12350.247): 5.940250846970518e-10 / 0.05602198844519505 = 1.0603427353853605e-08
# field decay(t = 12400.248): 5.908569457703192e-10 / 0.05602198844519505 = 1.0546875649520013e-08
# field decay(t = 12450.249): 5.869845326459746e-10 / 0.05602198844519505 = 1.0477752556395019e-08
# on time step 12466284 (time=12466.3), 2.59789e-05 s/step
# field decay(t = 12500.25): 5.832893860646583e-10 / 0.05602198844519505 = 1.0411793694814601e-08
# field decay(t = 12550.251): 5.798731553047491e-10 / 0.05602198844519505 = 1.0350813518017572e-08
# field decay(t = 12600.252): 5.756631443725223e-10 / 0.05602198844519505 = 1.027566425878795e-08
# on time step 12620614 (time=12620.6), 2.59186e-05 s/step
# field decay(t = 12650.253): 5.719522288243696e-10 / 0.05602198844519505 = 1.0209423919036659e-08
# field decay(t = 12700.254): 5.681203507625793e-10 / 0.05602198844519505 = 1.0141024382209453e-08
# field decay(t = 12750.255000000001): 5.646528574076149e-10 / 0.05602198844519505 = 1.0079129161222134e-08
# on time step 12774642 (time=12774.6), 2.59693e-05 s/step
# field decay(t = 12800.256): 5.612768650633765e-10 / 0.05602198844519505 = 1.0018867245536277e-08
# field decay(t = 12850.257): 5.573095818577757e-10 / 0.05602198844519505 = 9.948050708749442e-09
# field decay(t = 12900.258): 5.543658303961978e-10 / 0.05602198844519505 = 9.895504350734005e-09
# on time step 12929021 (time=12929), 2.59103e-05 s/step
# field decay(t = 12950.259): 5.502560483680113e-10 / 0.05602198844519505 = 9.822144190870937e-09
# field decay(t = 13000.26): 5.474318842510225e-10 / 0.05602198844519505 = 9.77173248297964e-09
# field decay(t = 13050.261): 5.437535298246583e-10 / 0.05602198844519505 = 9.706073363615059e-09
# on time step 13083073 (time=13083.1), 2.59654e-05 s/step
# field decay(t = 13100.262): 5.404386099880167e-10 / 0.05602198844519505 = 9.646901600372766e-09
# field decay(t = 13150.263): 5.36610794116245e-10 / 0.05602198844519505 = 9.578574574181677e-09
# field decay(t = 13200.264000000001): 5.325371739524831e-10 / 0.05602198844519505 = 9.50585990844383e-09
# on time step 13237155 (time=13237.2), 2.59603e-05 s/step
# field decay(t = 13250.265): 5.299061518197747e-10 / 0.05602198844519505 = 9.458895810850574e-09
# field decay(t = 13300.266): 5.262805993887217e-10 / 0.05602198844519505 = 9.394179214177114e-09
# field decay(t = 13350.267): 5.231737334119677e-10 / 0.05602198844519505 = 9.338721240210455e-09
# on time step 13391450 (time=13391.5), 2.59244e-05 s/step
# field decay(t = 13400.268): 5.199594298768892e-10 / 0.05602198844519505 = 9.281345491432402e-09
# field decay(t = 13450.269): 5.163867600151596e-10 / 0.05602198844519505 = 9.217572855706973e-09
# field decay(t = 13500.27): 5.135969889502769e-10 / 0.05602198844519505 = 9.167775068404013e-09
# on time step 13545944 (time=13545.9), 2.5891e-05 s/step
# field decay(t = 13550.271): 5.097036468780789e-10 / 0.05602198844519505 = 9.098278390755614e-09
# field decay(t = 13600.272): 5.071913549597115e-10 / 0.05602198844519505 = 9.053433643396725e-09
# field decay(t = 13650.273000000001): 5.032728682760425e-10 / 0.05602198844519505 = 8.983488131064503e-09
# field decay(t = 13700.274): 4.99911418385581e-10 / 0.05602198844519505 = 8.923485800127072e-09
# on time step 13700379 (time=13700.4), 2.59009e-05 s/step
# field decay(t = 13750.275): 4.971284588624911e-10 / 0.05602198844519505 = 8.873809599757778e-09
# field decay(t = 13800.276): 4.933282345214027e-10 / 0.05602198844519505 = 8.805975086086309e-09
# field decay(t = 13850.277): 4.909549572830129e-10 / 0.05602198844519505 = 8.763611769391267e-09
# on time step 13854150 (time=13854.1), 2.60128e-05 s/step
# field decay(t = 13900.278): 4.875139279787325e-10 / 0.05602198844519505 = 8.702188935254512e-09
# field decay(t = 13950.279): 4.847338572384276e-10 / 0.05602198844519505 = 8.65256430004499e-09
# field decay(t = 14000.28): 4.816821134795909e-10 / 0.05602198844519505 = 8.598090265053852e-09
# on time step 14008045 (time=14008), 2.59918e-05 s/step
# field decay(t = 14050.281): 4.784634273364255e-10 / 0.05602198844519505 = 8.540636286134231e-09
# field decay(t = 14100.282000000001): 4.758197683270916e-10 / 0.05602198844519505 = 8.493446618600025e-09
# field decay(t = 14150.283): 4.72178770738228e-10 / 0.05602198844519505 = 8.428454323790185e-09
# on time step 14162366 (time=14162.4), 2.59201e-05 s/step
# field decay(t = 14200.284): 4.692372879383771e-10 / 0.05602198844519505 = 8.375948461690546e-09
# field decay(t = 14250.285): 4.662198312280684e-10 / 0.05602198844519505 = 8.322086455109674e-09
# field decay(t = 14300.286): 4.631985818941712e-10 / 0.05602198844519505 = 8.268156749689582e-09
# on time step 14316156 (time=14316.2), 2.60097e-05 s/step
# field decay(t = 14350.287): 4.6055667338383336e-10 / 0.05602198844519505 = 8.220998328797e-09
# field decay(t = 14400.288): 4.5712065806429977e-10 / 0.05602198844519505 = 8.159664994959787e-09
# field decay(t = 14450.289): 4.548607161444794e-10 / 0.05602198844519505 = 8.119324728886741e-09
# on time step 14470156 (time=14470.2), 2.59741e-05 s/step
# field decay(t = 14500.29): 4.5159699418443794e-10 / 0.05602198844519505 = 8.061066854601641e-09
# field decay(t = 14550.291000000001): 4.4911229338615636e-10 / 0.05602198844519505 = 8.016714612433152e-09
# field decay(t = 14600.292): 4.4622887963133914e-10 / 0.05602198844519505 = 7.965245290567899e-09
# on time step 14624134 (time=14624.1), 2.59779e-05 s/step
# field decay(t = 14650.293): 4.433352626564519e-10 / 0.05602198844519505 = 7.913593839857291e-09
# field decay(t = 14700.294): 4.4028952886292993e-10 / 0.05602198844519505 = 7.859227083552282e-09
# field decay(t = 14750.295): 4.370760042266078e-10 / 0.05602198844519505 = 7.801865238221393e-09
# on time step 14778070 (time=14778.1), 2.5985e-05 s/step
# field decay(t = 14800.296): 4.347566521328854e-10 / 0.05602198844519505 = 7.760464492583966e-09
# field decay(t = 14850.297): 4.3188786863735557e-10 / 0.05602198844519505 = 7.709256322807267e-09
# field decay(t = 14900.298): 4.291762056767374e-10 / 0.05602198844519505 = 7.660852775630949e-09
# on time step 14931717 (time=14931.7), 2.60338e-05 s/step
# field decay(t = 14950.299): 4.2667505176399517e-10 / 0.05602198844519505 = 7.616206843164822e-09
# field decay(t = 15000.300000000001): 4.2357637110966384e-10 / 0.05602198844519505 = 7.560894978300143e-09
# field decay(t = 15050.301): 4.2141313837783324e-10 / 0.05602198844519505 = 7.522280984190547e-09
# on time step 15085493 (time=15085.5), 2.6012e-05 s/step
# field decay(t = 15100.302): 4.1832831464647684e-10 / 0.05602198844519505 = 7.467216467257625e-09
# field decay(t = 15150.303): 4.1610556442564323e-10 / 0.05602198844519505 = 7.427540077994718e-09
# field decay(t = 15200.304): 4.129792196385481e-10 / 0.05602198844519505 = 7.371734404653552e-09
# on time step 15239527 (time=15239.5), 2.59683e-05 s/step
# field decay(t = 15250.305): 4.100608622655724e-10 / 0.05602198844519505 = 7.319641334522158e-09
# field decay(t = 15300.306): 4.0791501213977084e-10 / 0.05602198844519505 = 7.281337622259235e-09
# field decay(t = 15350.307): 4.0486889017696003e-10 / 0.05602198844519505 = 7.22696393708041e-09
# on time step 15393352 (time=15393.4), 2.60036e-05 s/step
# field decay(t = 15400.308): 4.028029761315681e-10 / 0.05602198844519505 = 7.190087094563244e-09
# field decay(t = 15450.309000000001): 4.0009327950855705e-10 / 0.05602198844519505 = 7.141718646776677e-09
# field decay(t = 15500.31): 3.976559730112659e-10 / 0.05602198844519505 = 7.098212399231118e-09
# on time step 15547476 (time=15547.5), 2.59532e-05 s/step
# field decay(t = 15550.311): 3.9527937616138765e-10 / 0.05602198844519505 = 7.0557898270262195e-09
# field decay(t = 15600.312): 3.9248748579839237e-10 / 0.05602198844519505 = 7.005954209967991e-09
# field decay(t = 15650.313): 3.9041914392813616e-10 / 0.05602198844519505 = 6.969034030451699e-09
# field decay(t = 15700.314): 3.872822543484277e-10 / 0.05602198844519505 = 6.913040131149513e-09
# on time step 15701663 (time=15701.7), 2.59425e-05 s/step
# field decay(t = 15750.315): 3.8495424756089724e-10 / 0.05602198844519505 = 6.8714848980679905e-09
# field decay(t = 15800.316): 3.8259295103714726e-10 / 0.05602198844519505 = 6.829335438734536e-09
# field decay(t = 15850.317000000001): 3.7996343026763907e-10 / 0.05602198844519505 = 6.782398140675568e-09
# on time step 15855829 (time=15855.8), 2.59461e-05 s/step
# field decay(t = 15900.318000000001): 3.7791460610006293e-10 / 0.05602198844519505 = 6.745826354767247e-09
# field decay(t = 15950.319): 3.750317146980128e-10 / 0.05602198844519505 = 6.694366356968875e-09
# field decay(t = 16000.32): 3.7319215677770866e-10 / 0.05602198844519505 = 6.661530001613447e-09
# on time step 16009759 (time=16009.8), 2.59859e-05 s/step
# field decay(t = 16050.321): 3.7063447000231605e-10 / 0.05602198844519505 = 6.615874949974308e-09
# field decay(t = 16100.322): 3.6845232431322603e-10 / 0.05602198844519505 = 6.576923357043529e-09
# field decay(t = 16150.323): 3.6618892887596003e-10 / 0.05602198844519505 = 6.536521445221348e-09
# on time step 16163609 (time=16163.6), 2.59995e-05 s/step
# field decay(t = 16200.324): 3.6367554297132387e-10 / 0.05602198844519505 = 6.491657170060981e-09
# field decay(t = 16250.325): 3.61255369156944e-10 / 0.05602198844519505 = 6.448456743200955e-09
# field decay(t = 16300.326000000001): 3.5871447281075497e-10 / 0.05602198844519505 = 6.40310140297281e-09
# on time step 16317631 (time=16317.6), 2.59704e-05 s/step
# field decay(t = 16350.327000000001): 3.5667198888427293e-10 / 0.05602198844519505 = 6.366642791217532e-09
# field decay(t = 16400.328): 3.5443699311952903e-10 / 0.05602198844519505 = 6.326747817355076e-09
# field decay(t = 16450.33): 3.520728215500244e-10 / 0.05602198844519505 = 6.28454703806968e-09
# on time step 16471367 (time=16471.4), 2.60188e-05 s/step
# field decay(t = 16500.332000000002): 3.50115787007176e-10 / 0.05602198844519505 = 6.2496137092614225e-09
# field decay(t = 16550.334): 3.4743894580437943e-10 / 0.05602198844519505 = 6.201831735127905e-09
# field decay(t = 16600.335): 3.4576446354765597e-10 / 0.05602198844519505 = 6.171942002485487e-09
# on time step 16625249 (time=16625.2), 2.5994e-05 s/step
# field decay(t = 16650.337): 3.433393253785922e-10 / 0.05602198844519505 = 6.128652961229192e-09
# field decay(t = 16700.339): 3.413880810092768e-10 / 0.05602198844519505 = 6.0938229877943095e-09
# field decay(t = 16750.341): 3.388948888894979e-10 / 0.05602198844519505 = 6.0493191743993615e-09
# on time step 16779555 (time=16779.6), 2.59226e-05 s/step
# field decay(t = 16800.343): 3.363680259610688e-10 / 0.05602198844519505 = 6.004214332558535e-09
# field decay(t = 16850.345): 3.3469470014192673e-10 / 0.05602198844519505 = 5.974345242481895e-09
# field decay(t = 16900.347): 3.32297638895049e-10 / 0.05602198844519505 = 5.9315573780485805e-09
# on time step 16933634 (time=16933.6), 2.59609e-05 s/step
# field decay(t = 16950.349000000002): 3.304738390541511e-10 / 0.05602198844519505 = 5.899002306521941e-09
# field decay(t = 17000.351): 3.28347884427143e-10 / 0.05602198844519505 = 5.861053731578231e-09
# field decay(t = 17050.353): 3.26224105908475e-10 / 0.05602198844519505 = 5.823144000459964e-09
# on time step 17085106 (time=17085.1), 2.64076e-05 s/step
# field decay(t = 17100.355): 3.2435732058544815e-10 / 0.05602198844519505 = 5.7898216323178e-09
# field decay(t = 17150.357): 3.2194120113895113e-10 / 0.05602198844519505 = 5.746693576467718e-09
# field decay(t = 17200.359): 3.2035005257078723e-10 / 0.05602198844519505 = 5.718291361331773e-09
# on time step 17237948 (time=17237.9), 2.61709e-05 s/step
# field decay(t = 17250.361): 3.178024142072328e-10 / 0.05602198844519505 = 5.672815675190309e-09
# field decay(t = 17300.363): 3.1580885278241986e-10 / 0.05602198844519505 = 5.637230336644833e-09
# field decay(t = 17350.365): 3.139624673577574e-10 / 0.05602198844519505 = 5.604272109421808e-09
# on time step 17391062 (time=17391.1), 2.61244e-05 s/step
# field decay(t = 17400.367000000002): 3.116847448975309e-10 / 0.05602198844519505 = 5.563614458320138e-09
# field decay(t = 17450.369): 3.1008759248968086e-10 / 0.05602198844519505 = 5.5351050738413545e-09
# field decay(t = 17500.371): 3.0782105778208274e-10 / 0.05602198844519505 = 5.494647125623122e-09
# on time step 17543641 (time=17543.6), 2.62161e-05 s/step
# field decay(t = 17550.373): 3.0619497835022043e-10 / 0.05602198844519505 = 5.465621389889856e-09
# field decay(t = 17600.375): 3.041740045479247e-10 / 0.05602198844519505 = 5.429546736733394e-09
# field decay(t = 17650.376): 3.022690843479877e-10 / 0.05602198844519505 = 5.395543655928782e-09
# on time step 17696350 (time=17696.4), 2.61937e-05 s/step
# field decay(t = 17700.378): 3.0015902080490273e-10 / 0.05602198844519505 = 5.35787873896231e-09
# field decay(t = 17750.38): 2.9831921835230756e-10 / 0.05602198844519505 = 5.325038018672722e-09
# field decay(t = 17800.382): 2.963993301601382e-10 / 0.05602198844519505 = 5.290767757201236e-09
# on time step 17848879 (time=17848.9), 2.62246e-05 s/step
# field decay(t = 17850.384000000002): 2.944056570353634e-10 / 0.05602198844519505 = 5.255180424796476e-09
# field decay(t = 17900.386): 2.92618649988542e-10 / 0.05602198844519505 = 5.2232821095738815e-09
# field decay(t = 17950.388): 2.9085888622963253e-10 / 0.05602198844519505 = 5.191870090690778e-09
# field decay(t = 18000.39): 2.8880833677584245e-10 / 0.05602198844519505 = 5.155267508192371e-09
# on time step 18001648 (time=18001.6), 2.61834e-05 s/step
# field decay(t = 18050.392): 2.8729283265011105e-10 / 0.05602198844519505 = 5.128215556489264e-09
# field decay(t = 18100.394): 2.851435292921819e-10 / 0.05602198844519505 = 5.0898502035701725e-09
# field decay(t = 18150.396): 2.8369600054323503e-10 / 0.05602198844519505 = 5.06401162145053e-09
# on time step 18154711 (time=18154.7), 2.61331e-05 s/step
# field decay(t = 18200.398): 2.815310424052355e-10 / 0.05602198844519505 = 5.025366828609636e-09
# field decay(t = 18250.4): 2.8006839716137567e-10 / 0.05602198844519505 = 4.999258415030373e-09
# field decay(t = 18300.402000000002): 2.7808274951671873e-10 / 0.05602198844519505 = 4.963814338521031e-09
# on time step 18307911 (time=18307.9), 2.61097e-05 s/step
# field decay(t = 18350.404): 2.759682983544035e-10 / 0.05602198844519505 = 4.926071101963412e-09
# field decay(t = 18400.406): 2.746210538971018e-10 / 0.05602198844519505 = 4.902022607886489e-09
# field decay(t = 18450.408): 2.727274813449795e-10 / 0.05602198844519505 = 4.8682220841158135e-09
# on time step 18462001 (time=18462), 2.5959e-05 s/step
# field decay(t = 18500.41): 2.711280693655334e-10 / 0.05602198844519505 = 4.839672365981286e-09
# field decay(t = 18550.412): 2.694593066425378e-10 / 0.05602198844519505 = 4.809884727782258e-09
# field decay(t = 18600.414): 2.6760942651659697e-10 / 0.05602198844519505 = 4.776864119673167e-09
# on time step 18616044 (time=18616), 2.59669e-05 s/step
# field decay(t = 18650.416): 2.661690927250762e-10 / 0.05602198844519505 = 4.751153968507615e-09
# field decay(t = 18700.417): 2.640794441334137e-10 / 0.05602198844519505 = 4.713853461159383e-09
# field decay(t = 18750.419): 2.624669683923871e-10 / 0.05602198844519505 = 4.685070553130262e-09
# on time step 18769895 (time=18769.9), 2.59993e-05 s/step
# field decay(t = 18800.421000000002): 2.608111306984603e-10 / 0.05602198844519505 = 4.655513628431906e-09
# field decay(t = 18850.423): 2.590758675270167e-10 / 0.05602198844519505 = 4.624538948317843e-09
# field decay(t = 18900.425): 2.5763709273828067e-10 / 0.05602198844519505 = 4.598856625560886e-09
# on time step 18923782 (time=18923.8), 2.59932e-05 s/step
# field decay(t = 18950.427): 2.556644305932272e-10 / 0.05602198844519505 = 4.563644341959363e-09
# field decay(t = 19000.429): 2.5443951527344126e-10 / 0.05602198844519505 = 4.541779439377688e-09
# field decay(t = 19050.431): 2.5264179930275005e-10 / 0.05602198844519505 = 4.509689968429153e-09
# on time step 19077755 (time=19077.8), 2.59787e-05 s/step
# field decay(t = 19100.433): 2.512118423022802e-10 / 0.05602198844519505 = 4.484165044374222e-09
# field decay(t = 19150.435): 2.4963327102096466e-10 / 0.05602198844519505 = 4.45598733549372e-09
# field decay(t = 19200.437): 2.4797042387516326e-10 / 0.05602198844519505 = 4.426305291140222e-09
# on time step 19231527 (time=19231.5), 2.60126e-05 s/step
# field decay(t = 19250.439000000002): 2.462944840348435e-10 / 0.05602198844519505 = 4.396389540435313e-09
# field decay(t = 19300.441): 2.445234627774139e-10 / 0.05602198844519505 = 4.36477657369526e-09
# field decay(t = 19350.443): 2.431877046195379e-10 / 0.05602198844519505 = 4.340933111602108e-09
# on time step 19385275 (time=19385.3), 2.60167e-05 s/step
# field decay(t = 19400.445): 2.41615767825839e-10 / 0.05602198844519505 = 4.312873829214503e-09
# field decay(t = 19450.447): 2.400544222069705e-10 / 0.05602198844519505 = 4.285003600716707e-09
# field decay(t = 19500.449): 2.386907163932828e-10 / 0.05602198844519505 = 4.260661269222676e-09
# on time step 19539120 (time=19539.1), 2.60003e-05 s/step
# field decay(t = 19550.451): 2.3691107270510464e-10 / 0.05602198844519505 = 4.228894390938461e-09
# field decay(t = 19600.453): 2.357367529917017e-10 / 0.05602198844519505 = 4.207932626709908e-09
# field decay(t = 19650.455): 2.340407991820866e-10 / 0.05602198844519505 = 4.177659623971453e-09
# on time step 19693206 (time=19693.2), 2.59595e-05 s/step
# field decay(t = 19700.457000000002): 2.3276043326911175e-10 / 0.05602198844519505 = 4.154804920871662e-09
# field decay(t = 19750.459): 2.310343763636852e-10 / 0.05602198844519505 = 4.12399457383953e-09
# field decay(t = 19800.46): 2.2935684055553037e-10 / 0.05602198844519505 = 4.094050334894924e-09
# on time step 19847129 (time=19847.1), 2.59871e-05 s/step
# field decay(t = 19850.462): 2.2819128966059383e-10 / 0.05602198844519505 = 4.073245095250909e-09
# field decay(t = 19900.464): 2.2651105262097872e-10 / 0.05602198844519505 = 4.043252638962806e-09
# field decay(t = 19950.466): 2.2532115077140073e-10 / 0.05602198844519505 = 4.022012731515715e-09
# field decay(t = 20000.468): 2.2383559394817e-10 / 0.05602198844519505 = 3.995495343174813e-09
# ...
# field decay(t = 42151.698000000004): 1.3278060912649259e-11 / 0.05602198844519505 = 2.370151663866566e-10
# field decay(t = 42201.702): 1.3179306177495075e-11 / 0.05602198844519505 = 2.3525238113224187e-10
# field decay(t = 42251.706): 1.3114469307500664e-11 / 0.05602198844519505 = 2.340950343155033e-10
# on time step 42283425 (time=42283.4), 2.59734e-05 s/step
# field decay(t = 42301.709): 1.3017955607438181e-11 / 0.05602198844519505 = 2.3237225183774635e-10
# field decay(t = 42351.713): 1.294930244813954e-11 / 0.05602198844519505 = 2.3114678374559176e-10
# field decay(t = 42401.717000000004): 1.2864694475274901e-11 / 0.05602198844519505 = 2.2963652009353647e-10
# on time step 42437088 (time=42437.1), 2.6031e-05 s/step
# field decay(t = 42451.721): 1.2783137616332977e-11 / 0.05602198844519505 = 2.2818071923381316e-10
# field decay(t = 42501.725): 1.2709537251747054e-11 / 0.05602198844519505 = 2.2686694286441627e-10
# field decay(t = 42551.729): 1.2615454718152697e-11 / 0.05602198844519505 = 2.2518755703386163e-10
# on time step 42590703 (time=42590.7), 2.60392e-05 s/step
# field decay(t = 42601.733): 1.2553267584368533e-11 / 0.05602198844519505 = 2.2407750836350783e-10
# field decay(t = 42651.737): 1.2452101685198396e-11 / 0.05602198844519505 = 2.2227168350834216e-10
# field decay(t = 42701.741): 1.2375661868337129e-11 / 0.05602198844519505 = 2.209072225353789e-10
# on time step 42744069 (time=42744.1), 2.60815e-05 s/step
# field decay(t = 42751.745): 1.2302802768715253e-11 / 0.05602198844519505 = 2.196066778449106e-10
# field decay(t = 42801.749): 1.2214175677509196e-11 / 0.05602198844519505 = 2.1802467239194888e-10
# field decay(t = 42851.752): 1.2151831874511336e-11 / 0.05602198844519505 = 2.169118271551389e-10
# on time step 42898074 (time=42898.1), 2.59734e-05 s/step
# field decay(t = 42901.756): 1.2060563251300352e-11 / 0.05602198844519505 = 2.1528267000195663e-10
# field decay(t = 42951.76): 1.1999808396256785e-11 / 0.05602198844519505 = 2.141981876990301e-10
# field decay(t = 43001.764): 1.1919120874316873e-11 / 0.05602198844519505 = 2.1275790462127313e-10
# field decay(t = 43051.768000000004): 1.1846310295152165e-11 / 0.05602198844519505 = 2.1145822602746639e-10
# on time step 43051852 (time=43051.9), 2.60116e-05 s/step
# field decay(t = 43101.772000000004): 1.1776265587220271e-11 / 0.05602198844519505 = 2.102079186057579e-10
# field decay(t = 43151.776): 1.1691407787315288e-11 / 0.05602198844519505 = 2.0869319550755874e-10
# field decay(t = 43201.78): 1.1616514266367898e-11 / 0.05602198844519505 = 2.0735633612384272e-10
# on time step 43205668 (time=43205.7), 2.60052e-05 s/step
# field decay(t = 43251.784): 1.1536883518356096e-11 / 0.05602198844519505 = 2.0593491660229714e-10
# field decay(t = 43301.788): 1.1468721388760551e-11 / 0.05602198844519505 = 2.047182134561347e-10
# field decay(t = 43351.792): 1.1399028769018393e-11 / 0.05602198844519505 = 2.0347419085578847e-10
# on time step 43359216 (time=43359.2), 2.60506e-05 s/step
# field decay(t = 43401.795): 1.1319572720485648e-11 / 0.05602198844519505 = 2.020558897433516e-10
# field decay(t = 43451.799): 1.1260054765710848e-11 / 0.05602198844519505 = 2.009934862759519e-10
# field decay(t = 43501.803): 1.1173373889182739e-11 / 0.05602198844519505 = 1.9944622101576025e-10
# on time step 43513249 (time=43513.2), 2.59685e-05 s/step
# field decay(t = 43551.807): 1.111974751356597e-11 / 0.05602198844519505 = 1.9848898302573012e-10
# field decay(t = 43601.811): 1.1043011536159026e-11 / 0.05602198844519505 = 1.971192355473447e-10
# field decay(t = 43651.815): 1.0977956511662801e-11 / 0.05602198844519505 = 1.9595799464351876e-10
# on time step 43667013 (time=43667), 2.6014e-05 s/step
# field decay(t = 43701.819): 1.0899802351418495e-11 / 0.05602198844519505 = 1.9456293241146746e-10
# field decay(t = 43751.823000000004): 1.0814342163691143e-11 / 0.05602198844519505 = 1.930374566099265e-10
# field decay(t = 43801.827): 1.076458901230723e-11 / 0.05602198844519505 = 1.92149356191417e-10
# on time step 43820978 (time=43821), 2.59799e-05 s/step
# field decay(t = 43851.831): 1.0688736545476227e-11 / 0.05602198844519505 = 1.9079537949519157e-10
# field decay(t = 43901.834): 1.0628105348906598e-11 / 0.05602198844519505 = 1.8971310451259358e-10
# field decay(t = 43951.838): 1.056172136121203e-11 / 0.05602198844519505 = 1.885281414376126e-10
# on time step 43974805 (time=43974.8), 2.60034e-05 s/step
# field decay(t = 44001.842000000004): 1.0490310331001276e-11 / 0.05602198844519505 = 1.8725344498015616e-10
# field decay(t = 44051.846): 1.0433581696774916e-11 / 0.05602198844519505 = 1.862408312582806e-10
# field decay(t = 44101.85): 1.0351494844946453e-11 / 0.05602198844519505 = 1.8477556995452008e-10
# on time step 44128586 (time=44128.6), 2.60111e-05 s/step
# field decay(t = 44151.854): 1.0304046070587739e-11 / 0.05602198844519505 = 1.8392860297466838e-10
# field decay(t = 44201.858): 1.0223273966018607e-11 / 0.05602198844519505 = 1.8248681008564679e-10
# field decay(t = 44251.862): 1.0156454711197218e-11 / 0.05602198844519505 = 1.8129407743413163e-10
# on time step 44282219 (time=44282.2), 2.60361e-05 s/step
# field decay(t = 44301.866): 1.0099665178869865e-11 / 0.05602198844519505 = 1.8028037667299371e-10
# field decay(t = 44351.87): 1.0022511583568471e-11 / 0.05602198844519505 = 1.7890317465923672e-10
# field decay(t = 44401.874): 9.974979610779751e-12 / 0.05602198844519505 = 1.7805472257626183e-10
# on time step 44435917 (time=44435.9), 2.60252e-05 s/step
# field decay(t = 44451.877): 9.902784938723848e-12 / 0.05602198844519505 = 1.767660380068712e-10
# field decay(t = 44501.881): 9.848931075246028e-12 / 0.05602198844519505 = 1.7580473932804076e-10
# field decay(t = 44551.885): 9.785955439324813e-12 / 0.05602198844519505 = 1.746806157888911e-10
# on time step 44589763 (time=44589.8), 2.60001e-05 s/step
# field decay(t = 44601.889): 9.721681109651701e-12 / 0.05602198844519505 = 1.7353331039226117e-10
# field decay(t = 44651.893000000004): 9.667641493333042e-12 / 0.05602198844519505 = 1.7256869600033317e-10
# field decay(t = 44701.897000000004): 9.593794110130609e-12 / 0.05602198844519505 = 1.7125051031553415e-10
# on time step 44743708 (time=44743.7), 2.59833e-05 s/step
# field decay(t = 44751.901): 9.534797735376093e-12 / 0.05602198844519505 = 1.701974171213818e-10
# field decay(t = 44801.905): 9.472088928249686e-12 / 0.05602198844519505 = 1.690780565119712e-10
# field decay(t = 44851.909): 9.412294443109648e-12 / 0.05602198844519505 = 1.6801071694050037e-10
# on time step 44897562 (time=44897.6), 2.59988e-05 s/step
# field decay(t = 44901.913): 9.358265401687137e-12 / 0.05602198844519505 = 1.6704629131188552e-10
# field decay(t = 44951.917): 9.288639250780274e-12 / 0.05602198844519505 = 1.6580345518915532e-10
# field decay(t = 45001.92): 9.243116606857907e-12 / 0.05602198844519505 = 1.6499086989567005e-10
# on time step 45051250 (time=45051.2), 2.60269e-05 s/step
# field decay(t = 45051.924): 9.174837855834098e-12 / 0.05602198844519505 = 1.6377208504138726e-10
# field decay(t = 45101.928): 9.126743775469795e-12 / 0.05602198844519505 = 1.6291359926287278e-10
# field decay(t = 45151.932): 9.066989221882373e-12 / 0.05602198844519505 = 1.6184697247496646e-10
# field decay(t = 45201.936): 9.009573342763602e-12 / 0.05602198844519505 = 1.6082209133967905e-10
# on time step 45204896 (time=45204.9), 2.60339e-05 s/step
# field decay(t = 45251.94): 8.947714187644396e-12 / 0.05602198844519505 = 1.5971789713243982e-10
# field decay(t = 45301.944): 8.879963440490497e-12 / 0.05602198844519505 = 1.5850853721798092e-10
# field decay(t = 45351.948000000004): 8.835637840113144e-12 / 0.05602198844519505 = 1.5771731931216319e-10
# on time step 45358756 (time=45358.8), 2.59978e-05 s/step
# field decay(t = 45401.952): 8.776193860024084e-12 / 0.05602198844519505 = 1.5665623630281565e-10
# field decay(t = 45451.956): 8.722458821304062e-12 / 0.05602198844519505 = 1.5569705866183296e-10
# field decay(t = 45501.959): 8.671116882791831e-12 / 0.05602198844519505 = 1.5478059818020515e-10
# on time step 45512303 (time=45512.3), 2.60507e-05 s/step
# field decay(t = 45551.963): 8.608640883192805e-12 / 0.05602198844519505 = 1.5366539321635164e-10
# field decay(t = 45601.967000000004): 8.564782146599689e-12 / 0.05602198844519505 = 1.5288250889163648e-10
# field decay(t = 45651.971): 8.494480152211156e-12 / 0.05602198844519505 = 1.516276088722038e-10
# on time step 45664484 (time=45664.5), 2.62847e-05 s/step
# field decay(t = 45701.975): 8.457589468576168e-12 / 0.05602198844519505 = 1.5096910522642414e-10
# field decay(t = 45751.979): 8.393410349565315e-12 / 0.05602198844519505 = 1.4982349935287258e-10
# field decay(t = 45801.983): 8.334657451880699e-12 / 0.05602198844519505 = 1.4877475225704087e-10
# on time step 45816654 (time=45816.7), 2.62864e-05 s/step
# field decay(t = 45851.987): 8.291105026148957e-12 / 0.05602198844519505 = 1.479973356222431e-10
# field decay(t = 45901.991): 8.227029066888874e-12 / 0.05602198844519505 = 1.4685357116406493e-10
# field decay(t = 45951.995): 8.187646035388151e-12 / 0.05602198844519505 = 1.461505787749381e-10
# on time step 45970431 (time=45970.4), 2.60117e-05 s/step
# field decay(t = 46001.999): 8.131266257230943e-12 / 0.05602198844519505 = 1.4514419218063926e-10
# field decay(t = 46052.002): 8.08337503034667e-12 / 0.05602198844519505 = 1.4428932736392316e-10
# field decay(t = 46102.006): 8.034317042060673e-12 / 0.05602198844519505 = 1.4341363569985473e-10
# on time step 46124106 (time=46124.1), 2.6029e-05 s/step
# field decay(t = 46152.01): 7.978310767104572e-12 / 0.05602198844519505 = 1.4241391618774044e-10
# field decay(t = 46202.014): 7.93625248566358e-12 / 0.05602198844519505 = 1.4166317022872946e-10
# field decay(t = 46252.018000000004): 7.87225642322227e-12 / 0.05602198844519505 = 1.4052083193947154e-10
# on time step 46277817 (time=46277.8), 2.6023e-05 s/step
# field decay(t = 46302.022000000004): 7.825678571942816e-12 / 0.05602198844519505 = 1.3968941105327753e-10
# field decay(t = 46352.026): 7.77699650899492e-12 / 0.05602198844519505 = 1.3882042970686352e-10
# field decay(t = 46402.03): 7.72435913102312e-12 / 0.05602198844519505 = 1.3788084545730958e-10
# on time step 46431629 (time=46431.6), 2.60058e-05 s/step
# field decay(t = 46452.034): 7.682539370524876e-12 / 0.05602198844519505 = 1.3713435712908546e-10
# field decay(t = 46502.038): 7.622250745679365e-12 / 0.05602198844519505 = 1.360581970976633e-10
# field decay(t = 46552.042): 7.587169736278787e-12 / 0.05602198844519505 = 1.3543199637944182e-10
# on time step 46585487 (time=46585.5), 2.59981e-05 s/step
# field decay(t = 46602.045): 7.533615420526335e-12 / 0.05602198844519505 = 1.3447604466764487e-10
# field decay(t = 46652.049): 7.491048253662167e-12 / 0.05602198844519505 = 1.3371621503564582e-10
# field decay(t = 46702.053): 7.436840285818067e-12 / 0.05602198844519505 = 1.327485955464317e-10
# on time step 46739111 (time=46739.1), 2.60377e-05 s/step
# field decay(t = 46752.057): 7.393972849868557e-12 / 0.05602198844519505 = 1.3198340607102693e-10
# field decay(t = 46802.061): 7.344885548612275e-12 / 0.05602198844519505 = 1.3110719116651132e-10
# field decay(t = 46852.065): 7.291847597161467e-12 / 0.05602198844519505 = 1.3016045662668516e-10
# on time step 46892671 (time=46892.7), 2.60486e-05 s/step
# field decay(t = 46902.069): 7.252094614616083e-12 / 0.05602198844519505 = 1.2945086056184228e-10
# field decay(t = 46952.073000000004): 7.205744709067708e-12 / 0.05602198844519505 = 1.2862350853748994e-10
# field decay(t = 47002.077): 7.1586699230051285e-12 / 0.05602198844519505 = 1.2778321729883403e-10
# on time step 47046472 (time=47046.5), 2.60077e-05 s/step
# field decay(t = 47052.081): 7.118560779486108e-12 / 0.05602198844519505 = 1.2706726371289058e-10
# field decay(t = 47102.084): 7.064342355198946e-12 / 0.05602198844519505 = 1.2609945757476676e-10
# field decay(t = 47152.088): 7.030758700211835e-12 / 0.05602198844519505 = 1.2549998483345258e-10
# on time step 47200054 (time=47200.1), 2.60447e-05 s/step
# field decay(t = 47202.092000000004): 6.974796499307989e-12 / 0.05602198844519505 = 1.2450105204907647e-10
# field decay(t = 47252.096): 6.930667387752468e-12 / 0.05602198844519505 = 1.237133414950555e-10
# field decay(t = 47302.1): 6.890868633600648e-12 / 0.05602198844519505 = 1.230029284009049e-10
# field decay(t = 47352.104): 6.839836068374503e-12 / 0.05602198844519505 = 1.220919902738859e-10
# on time step 47353690 (time=47353.7), 2.60357e-05 s/step
# field decay(t = 47402.108): 6.80605411920006e-12 / 0.05602198844519505 = 1.214889779547589e-10
# field decay(t = 47452.112): 6.755798392368668e-12 / 0.05602198844519505 = 1.20591906497173e-10
# field decay(t = 47502.116): 6.720604445409159e-12 / 0.05602198844519505 = 1.1996368982839235e-10
# on time step 47507238 (time=47507.2), 2.60505e-05 s/step
# field decay(t = 47552.12): 6.676289967548477e-12 / 0.05602198844519505 = 1.1917267046098746e-10
# field decay(t = 47602.124): 6.634271616656139e-12 / 0.05602198844519505 = 1.1842263726762013e-10
# field decay(t = 47652.127): 6.596114633690013e-12 / 0.05602198844519505 = 1.1774153000911118e-10
# on time step 47661248 (time=47661.2), 2.59724e-05 s/step
# field decay(t = 47702.131): 6.547148288679293e-12 / 0.05602198844519505 = 1.1686747418978548e-10
# field decay(t = 47752.135): 6.5060998774278e-12 / 0.05602198844519505 = 1.1613475454896715e-10
# field decay(t = 47802.139): 6.4623563750453005e-12 / 0.05602198844519505 = 1.1535392717035146e-10
# on time step 47814950 (time=47815), 2.60245e-05 s/step
# field decay(t = 47852.143000000004): 6.422995227188318e-12 / 0.05602198844519505 = 1.1465132540719753e-10
# field decay(t = 47902.147000000004): 6.384883712949352e-12 / 0.05602198844519505 = 1.1397102977156065e-10
# field decay(t = 47952.151): 6.339092249283345e-12 / 0.05602198844519505 = 1.131536460096329e-10
# on time step 47968826 (time=47968.8), 2.59951e-05 s/step
# field decay(t = 48002.155): 6.306837588608626e-12 / 0.05602198844519505 = 1.1257789599486373e-10
# field decay(t = 48052.159): 6.2590182803833705e-12 / 0.05602198844519505 = 1.117243149358473e-10
# field decay(t = 48102.163): 6.227959965376039e-12 / 0.05602198844519505 = 1.1116991985153652e-10
# on time step 48122676 (time=48122.7), 2.59995e-05 s/step
# field decay(t = 48152.167): 6.185851216914381e-12 / 0.05602198844519505 = 1.1041827304944467e-10
# field decay(t = 48202.17): 6.148218430545005e-12 / 0.05602198844519505 = 1.0974652277042358e-10
# field decay(t = 48252.174): 6.105131735222014e-12 / 0.05602198844519505 = 1.0897741948582415e-10
# on time step 48276284 (time=48276.3), 2.60403e-05 s/step
# field decay(t = 48302.178): 6.05801814987364e-12 / 0.05602198844519505 = 1.0813643567471819e-10
# field decay(t = 48352.182): 6.029187622876637e-12 / 0.05602198844519505 = 1.076218069048878e-10
# field decay(t = 48402.186): 5.987441870259312e-12 / 0.05602198844519505 = 1.0687663962725423e-10
# on time step 48430093 (time=48430.1), 2.60064e-05 s/step
# field decay(t = 48452.19): 5.952413531131129e-12 / 0.05602198844519505 = 1.0625137908045215e-10
# field decay(t = 48502.194): 5.91617676447112e-12 / 0.05602198844519505 = 1.0560454794029262e-10
# field decay(t = 48552.198000000004): 5.874909923251197e-12 / 0.05602198844519505 = 1.0486792929527088e-10
# on time step 48583801 (time=48583.8), 2.60234e-05 s/step
# field decay(t = 48602.202): 5.844147981600271e-12 / 0.05602198844519505 = 1.043188245150823e-10
# field decay(t = 48652.206): 5.7988081885173976e-12 / 0.05602198844519505 = 1.0350950313358175e-10
# field decay(t = 48702.209): 5.7713057604151045e-12 / 0.05602198844519505 = 1.0301858110697075e-10
# on time step 48737831 (time=48737.8), 2.59691e-05 s/step
# field decay(t = 48752.213): 5.726623932325599e-12 / 0.05602198844519505 = 1.0222100448876099e-10
# field decay(t = 48802.217000000004): 5.6880972668406925e-12 / 0.05602198844519505 = 1.0153329834775893e-10
# field decay(t = 48852.221): 5.6572198700306066e-12 / 0.05602198844519505 = 1.0098213267750979e-10
# on time step 48891895 (time=48891.9), 2.59633e-05 s/step
# field decay(t = 48902.225): 5.612753215185774e-12 / 0.05602198844519505 = 1.0018839693054798e-10
# field decay(t = 48952.229): 5.587118497859685e-12 / 0.05602198844519505 = 9.973081379154235e-11
# run 0 finished at t = 48952.229 (48952229 timesteps)

# %%
#紀錄通量(真空場)
T_str = np.array(mp.get_fluxes(tran))
T_meep = T_str / T_vac

# %%
#繪圖比較(數值與實驗)
from matplotlib import pyplot as plt 
plt.figure(dpi=150)
plt.plot(omega/2/np.pi, T_tmat, label='$T_{tmatrix}$')
plt.plot(omega/2/np.pi, T_meep, label='$T_{meep}$')
plt.xlabel("$\omega$ ($2\pi$/μm)")
plt.ylabel("$T$")
plt.legend(loc="upper right")
plt.xlim([1,2])
plt.ylim([0,1])
plt.grid()
plt.show()
